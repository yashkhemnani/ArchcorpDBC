# %% [markdown]
# # Topic Extraction Pipeline

# %% [markdown]
# ## Importing Libraries

# %%
from operator import itemgetter
import fitz
import pandas as pd 
import re

# %% [markdown]
# ## Loading Document PDF (DBC)

# %%
doc = fitz.open('Dubai Building Code_English_2021 Edition_compressed.pdf')

# %% [markdown]
# ## Identify paragraphs, headers, and subscripts

# %%
def fonts(doc, granularity=False):
    """Extracts fonts and their usage in PDF documents.
    :param doc: PDF document to iterate through
    :type doc: <class 'fitz.fitz.Document'>
    :param granularity: also use 'font', 'flags' and 'color' to discriminate text
    :type granularity: bool
    :rtype: [(font_size, count), (font_size, count}], dict
    :return: most used fonts sorted by count, font style information
    """
    styles = {}
    font_counts = {}

    for page in doc:
        blocks = page.get_text("dict", flags = 20)["blocks"]
        for b in blocks:  # iterate through the text blocks
            if b['type'] == 0:  # block contains text
                for l in b["lines"]:  # iterate through the text lines
                    for s in l["spans"]:  # iterate through the text spans
                        if s['color'] != 20:
                            if granularity:
                                identifier = "{0}_{1}_{2}_{3}".format(s['size'], s['flags'], s['font'], s['color'])
                                styles[identifier] = {'size': s['size'], 'flags': s['flags'], 'font': s['font'],
                                                        'color': s['color']}
                            else:
                                identifier = "{0}".format(s['size'])
                                styles[identifier] = {'size': s['size'], 'font': s['font']}

                        font_counts[identifier] = font_counts.get(identifier, 0) + 1  # count the fonts usage

    font_counts = sorted(font_counts.items(), key=itemgetter(1), reverse=True)

    if len(font_counts) < 1:
        raise ValueError("Zero discriminating fonts found!")

    return font_counts, styles

# %%
font_counts, styles = fonts(doc)

# %%
font_counts
# Out:
# [('10.5', 28686),
#  ('8.5', 12054),
#  ('8.0', 4586),
#  ('12.0', 919),
#  ('4.95550012588501', 284),
#  ('6.121500015258789', 259),
#  ('13.0', 254),
#  ('7.800000190734863', 243),
#  ('9.0', 210),
#  ('9.779999732971191', 206),
#  ('18.0', 203),
#  ('9.779500007629395', 161),
#  ('4.07480001449585', 83),
#  ('8.884200096130371', 76),
#  ('8.757599830627441', 70),
#  ('7.0', 68),
#  ('8.639100074768066', 63),
#  ('6.826000213623047', 62),
#  ('6.061299800872803', 59),
#  ('7.795300006866455', 57),
#  ('14.0', 54),
#  ('6.014599800109863', 44),
#  ('6.0808000564575195', 44),
#  ('6.879700183868408', 42),
#  ('7.679200172424316', 42),
#  ('5.807499885559082', 39),
#  ('8.936400413513184', 39),
#  ('8.285900115966797', 36),
#  ('7.160900115966797', 36),
#  ('8.96679973602295', 33),
#  ('7.124899864196777', 30),
#  ('4.405200004577637', 29),
#  ('9.820734024047852', 28),
#  ('6.417399883270264', 28),
#  ('9.325900077819824', 27),
#  ('9.291000366210938', 25),
#  ('5.5', 25),
#  ('9.335399627685547', 24),
#  ('8.788299560546875', 24),
#  ('9.434599876403809', 23),
#  ('8.235199928283691', 23),
#  ('7.090000152587891', 23),
#  ('6.9517998695373535', 22),
#  ('7.7845001220703125', 22),
#  ('8.770700454711914', 22),
#  ('7.461299896240234', 21),
#  ('6.846499919891357', 21),
#  ('8.068300247192383', 21),
#  ('10.0', 20),
#  ('6.804200172424316', 20),
#  ('8.89210033416748', 19),
#  ('7.605899810791016', 19),
#  ('8.382833480834961', 19),
#  ('7.328700065612793', 19),
#  ('8.142800331115723', 18),
#  ('7.019999980926514', 18),
#  ('9.786600112915039', 3),
#  ('6.159299850463867', 3),
#  ('9.80270004272461', 3),
#  ('7.97189998626709', 3),
#  ('10.182930946350098', 3),
#  ('10.182958602905273', 3),
#  ('10.799099922180176', 3),
#  ('10.561562538146973', 3),
#  ('6.408299922943115', 3),
#  ('6.85699987411499', 3),
#  ('9.535699844360352', 3),
#  ('9.692999839782715', 3),
#  ('7.809800148010254', 3),
#  ('5.824999809265137', 3),
#  ('7.23199987411499', 3),
#  ('6.457099914550781', 3),
#  ('8.324299812316895', 3),
#  ('8.966791152954102', 3),
#  ('8.102800369262695', 3),
#  ('4.76200008392334', 3),
#  ('9.826899528503418', 3),
#  ('5.247000217437744', 3),
#  ('7.615300178527832', 3),
#  ('7.575699806213379', 3),
#  ('5.583099842071533', 3),
#  ('48.0', 2),
#  ('9.388299942016602', 2),
#  ('7.48799991607666', 2),
#  ('9.47599983215332', 2),
#  ('8.275199890136719', 2),
#  ('9.77996826171875', 2),
#  ('9.779946327209473', 2),
#  ('7.438300132751465', 2),
#  ('9.484700202941895', 2),
#  ('7.564499855041504', 2),
#  ('9.780030250549316', 2),
#  ('8.440299987792969', 2),
#  ('6.731500148773193', 2),
#  ('8.381799697875977', 2),
#  ('9.339699745178223', 2),
#  ('9.531399726867676', 2),
#  ('7.6016998291015625', 2),
#  ('9.744999885559082', 2),
#  ('8.892127990722656', 2),
#  ('8.543389320373535', 2),
#  ('7.44350004196167', 2),
#  ('8.90356159210205', 2),
#  ('8.913820266723633', 2),
#  ('7.112100124359131', 2),
#  ('9.575599670410156', 2),
#  ('9.773500442504883', 2),
#  ('9.052399635314941', 2),
#  ('8.923399925231934', 2),
#  ('8.185400009155273', 2),
#  ('8.17240047454834', 2),
#  ('9.780799865722656', 2),
#  ('9.784600257873535', 2),
#  ('9.779499053955078', 2),
#  ('9.77949047088623', 2),
#  ('9.335363388061523', 2),
#  ('9.782646179199219', 2),
#  ('9.782624244689941', 2),
#  ('9.782630920410156', 2),
#  ('9.782633781433105', 2),
#  ('6.845664024353027', 2),
#  ('6.845650672912598', 2),
#  ('9.63029956817627', 2),
#  ('9.785799980163574', 2),
#  ('9.785818099975586', 2),
#  ('9.785762786865234', 2),
#  ('9.785599708557129', 2),
#  ('9.431938171386719', 2),
#  ('9.431900024414062', 2),
#  ('8.705330848693848', 2),
#  ('8.70529842376709', 2),
#  ('6.379199981689453', 2),
#  ('9.786999702453613', 2),
#  ('8.552146911621094', 2),
#  ('8.55210018157959', 2),
#  ('9.77970027923584', 2),
#  ('8.801600456237793', 2),
#  ('13.894518852233887', 2),
#  ('8.972999572753906', 2),
#  ('7.26200008392334', 2),
#  ('6.0', 2),
#  ('9.223199844360352', 2),
#  ('7.94320011138916', 2),
#  ('3.8268001079559326', 2),
#  ('3.4440999031066895', 2),
#  ('8.735199928283691', 2),
#  ('7.764599800109863', 2),
#  ('7.59119987487793', 2),
#  ('6.577600002288818', 2),
#  ('5.131899833679199', 2),
#  ('7.817500114440918', 2),
#  ('9.779570579528809', 2),
#  ('7.587500095367432', 2),
#  ('7.784800052642822', 2),
#  ('8.101200103759766', 2),
#  ('6.556399822235107', 2),
#  ('6.854100227355957', 1),
#  ('9.722299575805664', 1),
#  ('7.526500225067139', 1),
#  ('9.77991771697998', 1),
#  ('9.77993106842041', 1),
#  ('40.0', 1),
#  ('7.338699817657471', 1),
#  ('9.739899635314941', 1),
#  ('9.748499870300293', 1),
#  ('9.554332733154297', 1),
#  ('9.83409309387207', 1),
#  ('9.834266662597656', 1),
#  ('9.834213256835938', 1),
#  ('9.834295272827148', 1),
#  ('9.834251403808594', 1),
#  ('9.83423137664795', 1),
#  ('9.834272384643555', 1),
#  ('8.892159461975098', 1),
#  ('8.89212703704834', 1),
#  ('9.434410095214844', 1),
#  ('7.594200134277344', 1),
#  ('14.777600288391113', 1),
#  ('9.706199645996094', 1),
#  ('9.729710578918457', 1),
#  ('9.741395950317383', 1),
#  ('9.89109992980957', 1),
#  ('11.169095993041992', 1),
#  ('11.16909122467041', 1),
#  ('11.938801765441895', 1),
#  ('9.681260108947754', 1),
#  ('7.709299087524414', 1),
#  ('7.7093915939331055', 1),
#  ('7.85161828994751', 1),
#  ('7.851696014404297', 1),
#  ('7.727099418640137', 1),
#  ('8.31470012664795', 1),
#  ('8.95934009552002', 1),
#  ('5.631186008453369', 1),
#  ('12.514846801757812', 1),
#  ('7.999084949493408', 1),
#  ('7.999100208282471', 1),
#  ('7.99916410446167', 1),
#  ('8.560002326965332', 1),
#  ('8.560074806213379', 1),
#  ('9.779315948486328', 1),
#  ('10.5615873336792', 1),
#  ('13.894481658935547', 1),
#  ('10.549200057983398', 1),
#  ('8.597599983215332', 1),
#  ('8.171299934387207', 1),
#  ('6.517000198364258', 1),
#  ('6.304178714752197', 1),
#  ('9.772100448608398', 1),
#  ('6.514699935913086', 1),
#  ('6.619699954986572', 1),
#  ('8.745280265808105', 1),
#  ('6.253300189971924', 1),
#  ('5.895400047302246', 1),
#  ('5.782700061798096', 1),
#  ('8.999957084655762', 1),
#  ('8.99998950958252', 1),
#  ('6.3735527992248535', 1)]

# %%
styles
# Out:
# {'48.0': {'size': 48.0, 'font': 'Dubai-Bold'},
#  '12.0': {'size': 12.0, 'font': 'Dubai-Medium'},
#  '10.5': {'size': 10.5, 'font': 'Dubai-Regular'},
#  '18.0': {'size': 18.0, 'font': 'Dubai-Regular'},
#  '13.0': {'size': 13.0, 'font': 'Dubai-Regular'},
#  '14.0': {'size': 14.0, 'font': 'Wingdings2'},
#  '36.0': {'size': 36.0, 'font': 'Dubai-Regular'},
#  '8.5': {'size': 8.5, 'font': 'Dubai-Regular'},
#  '8.0': {'size': 8.0, 'font': 'Dubai-Regular'},
#  '7.795300006866455': {'size': 7.795300006866455,
#   'font': 'GothamOffice-Regular'},
#  '7.800000190734863': {'size': 7.800000190734863,
#   'font': 'GothamOffice-Regular'},
#  '4.95550012588501': {'size': 4.95550012588501, 'font': 'Dubai-Medium'},
#  '6.854100227355957': {'size': 6.854100227355957,
#   'font': 'GothamOffice-Regular'},
#  '8.101200103759766': {'size': 8.101200103759766,
#   'font': 'GothamOffice-Regular'},
#  '6.556399822235107': {'size': 6.556399822235107,
#   'font': 'GothamOffice-Regular'},
#  '6.949399948120117': {'size': 6.949399948120117,
#   'font': 'GothamOffice-Regular'},
#  '6.0808000564575195': {'size': 6.0808000564575195,
#   'font': 'GothamOffice-Regular'},
#  '6.3735527992248535': {'size': 6.3735527992248535,
#   'font': 'GothamOffice-Regular'},
#  '5.5': {'size': 5.5, 'font': 'GothamOffice-Regular'},
#  '6.5': {'size': 6.5, 'font': 'GothamOffice-Regular'},
#  '6.806399822235107': {'size': 6.806399822235107,
#   'font': 'GothamOffice-Regular'},
#  '7.575699806213379': {'size': 7.575699806213379,
#   'font': 'GothamOffice-Regular'},
#  '8.067500114440918': {'size': 8.067500114440918,
#   'font': 'GothamOffice-Regular'},
#  '8.068300247192383': {'size': 8.068300247192383,
#   'font': 'GothamOffice-Regular'},
#  '8.06879997253418': {'size': 8.06879997253418,
#   'font': 'GothamOffice-Regular'},
#  '7.599999904632568': {'size': 7.599999904632568,
#   'font': 'GothamOffice-Regular'},
#  '6.7667999267578125': {'size': 6.7667999267578125,
#   'font': 'GothamOffice-Regular'},
#  '5.583099842071533': {'size': 5.583099842071533,
#   'font': 'GothamOffice-Regular'},
#  '7.979800224304199': {'size': 7.979800224304199,
#   'font': 'GothamOffice-Regular'},
#  '8.97719955444336': {'size': 8.97719955444336,
#   'font': 'GothamOffice-Regular'}}

# %% [markdown]
# ## Creating Element Tag Dictionary

# %%
def font_tags(font_counts, styles):
    """Returns dictionary with font sizes as keys and tags as value.
    :param font_counts: (font_size, count) for all fonts occuring in document
    :type font_counts: list
    :param styles: all styles found in the document
    :type styles: dict
    :rtype: dict
    :return: all element tags based on font-sizes
    """
    p_style = styles[font_counts[0][0]]  # get style for most used font by count (paragraph)
    p_size = p_style['size']  # get the paragraph's size

    # sorting the font sizes high to low, so that we can append the right integer to each tag 
    font_sizes = []
    for (font_size, count) in font_counts:
        font_sizes.append(float(font_size))
    font_sizes.sort(reverse=True)

    # aggregating the tags for each font size
    idx = 0
    size_tag = {}
    for size in font_sizes:
        idx += 1
        if size == p_size:
            idx = 0
            size_tag[size] = '<p>'
        if size > p_size:
            size_tag[size] = '<h{0}>'.format(idx)
        elif size < p_size:
            size_tag[size] = '<s{0}>'.format(idx)

    return size_tag

# %%
size_tag = font_tags(font_counts, styles)
print(size_tag)
# Out:
# {48.0: '<h1>', 40.0: '<h2>', 36.0: '<h3>', 18.0: '<h4>', 14.777600288391113: '<h5>', 14.0: '<h6>', 13.894518852233887: '<h7>', 13.894499778747559: '<h8>', 13.894481658935547: '<h9>', 13.240099906921387: '<h10>', 13.0: '<h11>', 12.514846801757812: '<h12>', 12.225199699401855: '<h13>', 12.0: '<h14>', 11.938801765441895: '<h15>', 11.169095993041992: '<h16>', 11.16909122467041: '<h17>', 11.032400131225586: '<h18>', 10.994600296020508: '<h19>', 10.991999626159668: '<h20>', 10.979999542236328: '<h21>', 10.799099922
: '<s98>', 9.438699722290039: '<s99>', 9.437000274658203: '<s100>', 9.434599876403809: '<s101>', 9.434410095214844: '<s102>', 9.431938171386719: '<s103>', 9.43190860748291: '<s104>', 9.431900024414062: '<s105>', 9.388299942016602: '<s106>', 9.385199546813965: '<s107>', 9.35420036315918: '<s108>', 9.339699745178223: '<s109>', 9.335399627685547: '<s110>', 9.335363388061523: '<s111>', 9.333399772644043: '<s112>', 9.333000183105469: '<s113>', 9.328200340270996: '<s114>', 9.326499938964844: '<s115>', 9.325900077819824: '<s116>', 9.291000366210938: '<s117>', 9.290499687194824: '<s118>', 9.247400283813477: '<s119>', 9.223199844360352: '<s120>',  ...

# %% [markdown]
# ## Extracting headers and paragraphs

# %%
def headers_para(doc, size_tag):
    """Scrapes headers & paragraphs from PDF and return texts with element tags.
    :param doc: PDF document to iterate through
    :type doc: <class 'fitz.fitz.Document'>
    :param size_tag: textual element tags for each size
    :type size_tag: dict
    :rtype: list
    :return: texts with pre-prended element tags
    """
    header_para = []  # list with headers and paragraphs
    first = True  # boolean operator for first header
    previous_s = {}  # previous span

    for page in doc:
        blocks = page.get_text("dict")["blocks"]
        for b in blocks:  # iterate through the text blocks
            if b['type'] == 0:  # this block contains text

                # REMEMBER: multiple fonts and sizes are possible IN one block

                block_string = ""  # text found in block
                for l in b["lines"]:  # iterate through the text lines
                    for s in l["spans"]:  # iterate through the text spans
                        if s['text'].strip():  # removing whitespaces:
                            if s['size'] in size_tag and s['color'] != 3488054:
                                if first:
                                    previous_s = s
                                    first = False
                                    block_string = size_tag[s['size']] + s['text']
                                else:
                                    if s['size'] == previous_s['size']:

                                        if block_string and all((c == "|") for c in block_string):
                                            # block_string only contains pipes
                                            block_string = size_tag[s['size']] + s['text']
                                        if block_string == "":
                                            # new block has started, so append size tag
                                            block_string = size_tag[s['size']] + s['text']
                                        else:  # in the same block, so concatenate strings
                                            block_string += " " + s['text']

                                    else:
                                        header_para.append(block_string)
    #                                        print(size_tag[s['size']])
                                        block_string = size_tag[s['size']] + s['text']

                                    previous_s = s

                    # new block started, indicating with a pipe
                    block_string += "|"

                header_para.append(block_string)

    return header_para

# %%
list1 = headers_para(doc, size_tag)

# %% [markdown]
# ## Text Cleaning

# %%
subheadings = []
subheadings = [i for i in list1 if i.startswith('<p>')]
subheadings = [i[3:] for i in subheadings]
r = re.compile("[a-zA-Z]\.([0-9]+(\.[0-9]+)+)\s+\|\s+[a-zA-Z]+(.*)")
subheadings = [i for i in subheadings if r.match(i)]
subheadings = [i[:-1] for i in subheadings]

# %%
list_of_i = []
list_of_h = []
for i in subheadings:
    w = i.split('|')
    list_of_i.append(w[0].strip())
    list_of_h.append(w[1].strip())

# %%
list_of_i
# Out:
# ['A.5.2.1',
#  'A.5.2.2',
#  'A.5.2.3',
#  'A.5.2.4',
#  'B.4.2.1',
#  'B.4.2.2',
#  'B.4.2.3',
#  'B.4.2.4',
#  'B.4.2.4.1',
#  'B.4.2.4.2',
#  'B.4.2.5',
#  'B.4.2.5.1',
#  'B.4.2.5.2',
#  'B.4.2.6',
#  'B.4.2.5.3',
#  'B.4.3.1',
#  'B.4.3.2',
#  'B.4.3.3',
#  'B.4.3.4',
#  'B.6.2.1',
#  'B.6.2.2',
#  'B.6.2.3',
#  'B.6.4.1',
#  'B.6.4.1.1',
#  'B.6.4.1.2',
#  'B.6.4.1.3',
#  'B.6.4.1.4',
#  'B.6.4.1.5',
#  'B.6.4.1.6',
#  'B.6.4.1.7',
#  'B.6.4.1.8',
#  'B.6.4.2',
#  'B.6.4.3',
#  'B.6.5.1',
#  'B.6.5.2',
#  'B.6.5.2.1',
#  'B.6.5.2.2',
#  'B.6.5.2.3',
#  'B.6.5.2.4',
#  'B.6.6.1',
#  'B.6.6.2',
#  'B.6.6.3',
#  'B.6.6.4',
#  'B.7.2.1',
#  'B.7.2.2',
#  'B.7.2.3',
#  'B.7.2.3.1',
#  'B.7.2.3.2',
#  'B.7.2.3.3',
#  'B.7.2.4',
#  'B.7.2.5',
#  'B.7.2.6',
#  'B.7.2.6.1',
#  'B.7.2.6.2',
#  'B.7.2.6.3',
#  'B.7.2.7',
#  'B.7.3.1',
#  'B.7.3.1.1',
#  'B.7.3.1.2',
#  'B.7.3.1.3',
#  'B.7.3.1.4',
#  'B.7.3.2',
#  'B.7.3.3',
#  'B.7.3.4',
#  'B.8.1.1',
#  'B.8.1.2',
#  'B.8.1.3',
#  'B.8.1.3.1',
#  'B.8.1.3.2',
#  'B.8.1.3.3',
#  'B.8.1.4',
#  'B.8.1.4.1',
#  'B.8.1.4.2',
#  'B.8.1.5',
#  'B.8.1.6',
#  'B.8.2.1',
#  'B.8.2.2',
#  'B.8.2.3',
#  'B.8.3.1',
#  'B.8.3.2',
#  'B.8.3.2.1',
#  'B.8.3.2.2',
#  'B.8.3.2.3',
#  'B.8.3.2.4',
#  'B.8.3.2.5',
#  'B.8.3.2.6',
#  'B.8.3.3',
#  'B.8.3.4',
#  'B.8.5.1',
#  'B.8.5.2',
#  'B.8.5.2.1',
#  'B.8.5.2.2',
#  'B.8.5.2.3',
#  'B.8.5.3',
#  'B.8.5.4',
#  'B.8.5.5',
#  'B.8.5.6',
#  'B.8.5.7',
#  'B.9.4.1',
#  'B.9.4.2',
#  'B.9.4.3',
#  'B.9.4.4',
#  'B.9.4.5',
#  'B.9.4.6',
#  'B.9.4.6.1',
#  'B.9.4.6.2',
#  'B.9.4.6.3',
#  'B.9.4.7',
#  'B.9.4.8',
#  'B.9.4.9',
#  'B.9.5.1.1',
#  'B.9.5.1.2',
#  'B.9.5.1.3',
#  'B.9.6.1',
#  'B.9.6.2',
#  'B.9.6.3',
#  'B.9.6.4',
#  'B.9.7.1',
#  'B.9.7.2',
#  'B.9.7.2.1',
#  'B.9.7.2.2',
#  'B.9.7.2.3',
#  'B.9.7.3',
#  'B.9.7.4',
#  'B.10.5.1',
#  'B.10.5.2',
#  'B.10.5.3',
#  'B.10.6.1',
#  'B.10.6.2',
#  'B.10.6.3',
#  'B.10.6.4',
#  'B.10.6.5',
#  'B.10.6.6',
#  'B.11.4.1',
#  'B.11.4.2',
#  'B.11.4.3',
#  'B.11.4.4',
#  'B.11.4.5',
#  'B.11.4.6',
#  'C.5.4.1',
#  'C.5.4.2',
#  'C.5.4.3',
#  'C.5.6.1',
#  'C.5.6.2',
#  'C.5.6.3',
#  'C.5.7.1',
#  'C.5.7.1.1',
#  'C.5.7.1.2',
#  'C.5.7.2',
#  'C.5.7.2.1',
#  'C.5.7.2.2',
#  'C.5.7.3',
#  'C.5.7.4',
#  'C.5.8.1',
#  'C.5.8.2',
#  'C.5.8.2.1',
#  'C.5.8.2.2',
#  'C.5.8.3',
#  'C.5.8.3.1',
#  'C.5.8.3.2',
#  'C.5.8.3.3',
#  'C.5.8.4',
#  'C.5.9.1',
#  'C.5.9.1.1',
#  'C.5.9.1.2',
#  'C.5.9.1.3',
#  'C.5.9.1.4',
#  'C.5.9.1.5',
#  'C.5.9.1.6',
#  'C.5.9.2',
#  'C.5.9.3',
#  'C.5.9.3.1',
#  'C.5.9.3.2',
#  'C.5.9.4',
#  'C.5.9.5',
#  'C.5.9.5.1',
#  'C.5.9.5.2',
#  'C.5.9.5.3',
#  'C.6.2.1',
#  'C.6.2.2',
#  'C.6.2.2.1',
#  'C.6.2.2.2',
#  'C.6.2.2.3',
#  'C.6.2.2.4',
#  'C.6.4.1',
#  'C.6.4.2',
#  'C.7.2.1',
#  'C.7.2.1.1',
#  'C.7.2.1.2',
#  'C.7.2.1.3',
#  'C.7.2.2',
#  'C.7.2.2.1',
#  'C.7.2.2.2',
#  'C.7.2.2.3',
#  'C.7.2.3',
#  'C.7.2.4',
#  'C.7.3.1',
#  'C.7.3.2',
#  'C.7.3.3',
#  'C.7.3.4',
#  'C.7.3.5',
#  'C.8.3.1',
#  'C.8.3.2',
#  'C.8.3.3',
#  'C.8.3.4',
#  'C.8.3.4.1',
#  'C.8.3.4.2',
#  'C.8.3.4.3',
#  'C.8.3.4.4',
#  'C.8.3.5',
#  'C.8.3.6',
#  'C.8.3.7',
#  'C.8.3.7.1',
#  'C.8.3.7.2',
#  'C.8.3.7.3',
#  'C.8.3.7.4',
#  'C.8.3.7.5',
#  'C.8.3.8',
#  'C.8.3.8.1',
#  'C.8.3.8.2',
#  'C.8.3.8.3',
#  'C.8.3.9',
#  'C.10.2.1',
#  'C.10.2.2',
#  'C.10.2.3',
#  'C.10.2.4',
#  'C.10.2.5',
#  'C.10.2.6',
#  'C.10.2.7',
#  'C.10.2.8',
#  'C.10.2.9',
#  'C.10.2.10',
#  'C.10.2.11',
#  'C.10.2.12',
#  'C.10.2.13',
#  'C.10.3.1',
#  'C.10.3.2',
#  'C.10.4.1',
#  'C.10.4.2',
#  'C.10.4.3',
#  'C.11.3.1',
#  'C.11.3.2',
#  'C.11.3.3',
#  'D.7.2.1',
#  'D.7.2.2',
#  'D.7.3.1',
#  'D.7.3.2',
#  'D.7.3.3',
#  'D.8.2.1',
#  'D.8.2.2',
#  'D.8.3.1',
#  'D.8.3.2',
#  'D.8.3.3',
#  'D.8.5.1',
#  'D.8.5.2',
#  'D.8.5.3',
#  'D.8.8.1',
#  'D.8.8.2',
#  'D.8.8.3',
#  'D.8.9.1',
#  'D.8.9.2',
#  'D.8.9.3',
#  'D.8.10.1',
#  'D.8.10.2',
#  'D.8.11.1',
#  'D.8.11.2',
#  'D.8.11.3',
#  'D.8.12.1',
#  'D.8.12.2',
#  'D.8.12.3',
#  'D.8.12.4',
#  'D.8.13.1',
#  'D.8.13.2',
#  'D.8.13.3',
#  'D.8.14.1',
#  'D.8.14.3',
#  'D.8.15.1',
#  'D.8.14.2',
#  'D.8.15.2',
#  'D.8.15.3',
#  'D.8.15.4',
#  'D.8.16.1',
#  'D.8.16.2',
#  'D.8.16.3',
#  'D.9.2.1',
#  'D.9.3.1',
#  'D.9.3.2',
#  'D.9.8.1',
#  'D.9.8.2',
#  'D.9.8.3',
#  'D.9.8.4',
#  'E.4.1.1',
#  'E.4.1.2',
#  'E.4.1.3',
#  'E.4.1.4',
#  'E.4.1.5',
#  'E.4.1.6',
#  'E.4.1.7',
#  'E.5.2.1',
#  'E.5.2.2',
#  'E.5.2.3',
#  'E.5.2.3.1',
#  'E.5.2.3.2',
#  'E.7.3.1',
#  'E.7.3.2',
#  'E.7.3.3',
#  'E.7.3.4',
#  'E.12.7.1',
#  'E.12.7.2',
#  'F.3.1.1',
#  'F.3.1.2',
#  'F.3.1.3',
#  'F.3.1.4',
#  'F.3.1.5',
#  'F.3.1.5.1',
#  'F.3.1.5.2',
#  'F.3.1.5.3',
#  'F.3.2.1',
#  'F.3.2.2',
#  'F.3.2.3',
#  'F.5.6.1',
#  'F.5.6.2',
#  'F.5.6.3',
#  'F.6.2.1',
#  'F.6.2.2',
#  'F.6.2.3',
#  'F.6.2.4',
#  'F.6.2.5',
#  'F.6.2.6',
#  'F.6.3.1',
#  'F.6.3.2',
#  'F.6.3.3',
#  'F.6.3.4',
#  'F.6.3.5',
#  'F.6.3.6',
#  'F.6.3.7',
#  'F.6.3.8',
#  'F.6.3.9',
#  'F.6.3.10',
#  'F.6.4.1',
#  'F.6.4.2',
#  'F.6.4.3',
#  'F.6.4.4',
#  'F.6.4.5',
#  'F.6.4.6',
#  'F.6.5.1',
#  'F.6.5.2',
#  'F.6.4.7',
#  'F.6.5.3',
#  'F.6.5.4',
#  'F.6.5.4.1',
#  'F.6.5.4.2',
#  'F.6.5.4.3',
#  'F.6.6.1',
#  'F.6.6.2',
#  'F.6.6.3',
#  'F.7.12.1',
#  'F.7.12.2',
#  'F.7.12.3',
#  'F.7.12.3.1',
#  'F.7.12.3.2',
#  'F.7.12.3.3',
#  'F.7.12.4',
#  'F.7.12.4.1',
#  'F.7.12.4.2',
#  'F.7.12.5',
#  'F.7.13.1',
#  'F.7.13.2',
#  'F.7.13.3',
#  'F.7.13.3.1',
#  'F.7.13.3.2',
#  'F.7.13.4',
#  'F.7.13.5',
#  'F.7.13.6',
#  'F.7.13.7',
#  'F.7.13.8',
#  'F.7.13.9',
#  'F.7.13.10',
#  'F.7.13.11',
#  'F.7.13.12',
#  'F.7.13.13',
#  'F.7.13.14',
#  'F.8.3.1',
#  'F.8.3.2',
#  'F.8.3.3',
#  'F.8.3.4',
#  'F.8.6.1',
#  'F.8.6.2',
#  'F.8.6.3',
#  'F.8.6.4',
#  'F.8.6.5',
#  'F.8.8.1',
#  'F.8.8.2',
#  'F.9.3.1',
#  'F.9.3.2',
#  'F.9.3.3',
#  'F.9.3.4',
#  'F.9.3.5',
#  'F.9.3.6',
#  'F.9.4.1',
#  'F.9.4.2',
#  'F.9.4.2.1',
#  'F.9.4.2.2',
#  'F.9.4.2.3',
#  'F.9.4.3',
#  'F.9.4.3.1',
#  'F.9.4.3.2',
#  'F.9.4.3.3',
#  'F.9.4.3.4',
#  'F.9.4.4',
#  'F.9.4.5',
#  'F.9.4.6',
#  'F.9.5.1',
#  'F.9.5.2',
#  'F.9.5.3',
#  'F.9.5.4',
#  'F.9.5.5',
#  'F.9.5.6',
#  'F.10.2.1',
#  'F.10.2.2',
#  'G.2.1.1',
#  'G.2.1.2',
#  'G.2.1.3',
#  'G.3.5.1',
#  'G.3.5.2',
#  'G.4.4.1',
#  'G.4.4.2',
#  'G.4.4.3',
#  'G.4.5.1',
#  'G.4.5.2',
#  'G.4.5.3',
#  'G.4.5.4',
#  'G.4.7.1',
#  'G.4.7.2',
#  'G.4.7.3',
#  'G.4.7.4',
#  'G.4.11.1',
#  'G.4.11.2',
#  'G.4.11.3',
#  'G.4.12.1',
#  'G.4.12.2',
#  'G.4.13.1',
#  'G.4.13.3',
#  'G.4.13.2',
#  'G.4.13.4',
#  'G.4.13.5',
#  'G.4.13.6',
#  'G.4.13.7',
#  'G.4.13.8',
#  'G.4.13.9',
#  'G.4.16.1',
#  'G.4.16.2',
#  'G.4.17.1',
#  'G.4.17.2',
#  'G.4.17.3',
#  'G.4.18.1',
#  'G.4.18.2',
#  'G.4.18.3',
#  'G.4.18.4',
#  'G.4.18.6',
#  'G.4.18.5',
#  'G.4.19.1',
#  'G.4.19.2',
#  'G.4.19.3',
#  'G.4.19.4',
#  'G.4.19.5',
#  'G.4.20.1',
#  'G.4.20.2',
#  'G.4.20.3',
#  'G.4.21.1',
#  'G.4.21.2',
#  'G.4.21.3',
#  'G.5.1.1',
#  'G.5.1.2',
#  'G.5.1.3',
#  'G.5.1.4',
#  'G.5.1.5',
#  'G.7.1.1',
#  'G.7.1.2',
#  'G.7.1.3',
#  'G.7.1.4',
#  'G.7.1.5',
#  'G.7.1.6',
#  'G.7.1.7',
#  'G.7.2.1',
#  'G.7.2.2',
#  'G.7.2.3',
#  'G.7.2.4',
#  'G.7.5.1',
#  'G.7.5.2',
#  'G.7.5.3',
#  'G.7.5.4',
#  'G.7.5.5',
#  'G.7.5.6',
#  'G.7.6.1',
#  'G.7.6.2',
#  'G.7.6.3',
#  'G.7.9.1',
#  'G.7.9.2',
#  'G.11.1.1',
#  'G.11.1.2',
#  'G.11.1.3',
#  'G.11.3.1',
#  'G.11.3.2',
#  'G.11.4.1',
#  'G.11.4.2',
#  'G.11.4.3',
#  'G.11.4.4',
#  'G.11.4.5',
#  'G.11.4.6',
#  'G.11.4.7',
#  'G.11.4.8',
#  'G.11.4.9',
#  'H.2.1.1',
#  'H.2.1.2',
#  'H.2.1.3',
#  'H.2.1.4',
#  'H.2.1.5',
#  'H.2.1.6',
#  'H.2.1.7',
#  'H.3.1.1',
#  'H.3.1.2',
#  'H.3.1.3',
#  'H.3.1.4',
#  'H.3.1.5',
#  'H.3.1.6',
#  'H.3.1.7',
#  'H.3.1.8',
#  'H.3.2.1',
#  'H.3.2.2',
#  'H.3.2.3',
#  'H.4.6.1',
#  'H.4.6.2',
#  'H.4.6.3',
#  'H.4.6.4',
#  'H.4.6.5',
#  'H.4.6.6',
#  'H.4.6.7',
#  'H.4.6.7.1',
#  'H.4.6.7.2',
#  'H.4.6.7.3',
#  'H.4.8.1',
#  'H.4.8.2',
#  'H.4.8.3',
#  'H.4.8.4',
#  'H.4.9.1',
#  'H.4.9.2',
#  'H.4.10.1',
#  'H.4.10.2',
#  'H.4.10.3',
#  'H.4.10.4',
#  'H.4.10.5',
#  'H.4.10.6',
#  'H.4.12.1',
#  'H.4.12.2',
#  'H.4.12.3',
#  'H.4.12.4',
#  'H.4.12.5',
#  'H.4.12.6',
#  'H.4.12.7',
#  'H.4.12.8',
#  'H.4.12.9',
#  'H.4.13.1',
#  'H.4.13.2',
#  'H.4.13.3',
#  'H.4.13.4',
#  'H.4.13.5',
#  'H.4.13.6',
#  'H.4.13.7',
#  'H.4.13.8',
#  'H.4.13.9',
#  'H.4.14.1',
#  'H.4.14.2',
#  'H.4.14.3',
#  'H.4.14.4',
#  'H.4.15.1',
#  'H.4.15.2',
#  'H.4.15.3',
#  'H.4.15.4',
#  'H.4.16.1',
#  'H.4.16.2',
#  'H.4.16.3',
#  'H.4.16.4',
#  'H.4.16.5',
#  'H.4.16.6',
#  'H.4.16.7',
#  'H.4.16.8',
#  'H.4.16.9',
#  'H.5.2.1',
#  'H.5.2.2',
#  'H.5.2.5',
#  'H.5.2.6',
#  'H.5.2.6.1',
#  'H.5.2.6.2',
#  'H.5.2.3',
#  'H.5.2.4',
#  'H.5.2.7',
#  'H.5.2.8',
#  'H.5.4.1',
#  'H.5.4.2',
#  'H.5.4.3',
#  'H.5.4.4',
#  'H.5.4.5',
#  'H.5.4.6',
#  'H.5.5.1',
#  'H.5.5.2',
#  'H.5.5.3',
#  'H.5.5.4',
#  'H.5.5.5',
#  'H.5.5.6',
#  'H.5.5.7',
#  'H.5.6.1',
#  'H.5.6.2',
#  'H.6.2.1',
#  'H.6.2.2',
#  'H.6.2.3',
#  'H.6.2.4',
#  'H.6.2.5',
#  'H.6.2.6',
#  'H.6.2.7',
#  'H.6.2.8',
#  'H.6.2.9',
#  'H.6.3.1',
#  'H.6.3.2',
#  'H.6.3.3',
#  'H.6.3.4',
#  'H.6.3.5',
#  'H.6.3.6',
#  'H.6.3.7',
#  'H.6.4.1',
#  'H.6.4.2',
#  'H.6.4.3',
#  'H.6.4.4',
#  'H.6.4.5',
#  'H.10.3.1',
#  'H.10.3.2',
#  'H.10.3.3',
#  'H.10.3.4',
#  'H.10.4.1',
#  'H.10.4.2',
#  'H.10.4.3',
#  'H.10.4.4',
#  'H.10.4.5',
#  'H.11.2.1',
#  'H.11.2.2',
#  'H.11.2.3',
#  'H.11.2.4',
#  'H.11.2.5',
#  'H.11.2.6',
#  'H.11.2.7',
#  'H.11.2.8',
#  'H.11.2.9',
#  'H.11.3.1',
#  'H.11.3.2',
#  'H.11.3.3',
#  'H.11.3.4',
#  'H.11.3.5',
#  'H.11.3.6',
#  'H.11.3.7',
#  'H.11.3.8',
#  'H.11.7.1',
#  'H.11.7.2',
#  'H.11.7.3',
#  'H.11.8.1',
#  'H.11.8.2',
#  'H.11.8.3',
#  'H.11.8.4',
#  'H.11.8.5',
#  'K.2.6.1',
#  'K.2.6.2',
#  'K.2.7.1',
#  'K.2.7.2',
#  'K.2.7.3',
#  'K.3.5.1',
#  'K.3.5.2',
#  'K.3.5.3',
#  'K.3.5.4',
#  'K.3.5.5',
#  'K.3.5.5.1',
#  'K.3.5.5.2',
#  'K.3.5.5.3',
#  'K.3.6.1',
#  'K.3.6.2',
#  'K.3.7.1',
#  'K.3.7.2',
#  'K.3.7.3',
#  'K.3.7.4',
#  'K.5.2.1',
#  'K.5.2.2',
#  'K.5.2.3',
#  'K.5.2.4',
#  'K.5.2.5',
#  'K.5.2.5.1',
#  'K.5.2.5.2',
#  'K.5.2.6',
#  'K.5.2.7',
#  'K.5.2.8',
#  'K.5.2.8.1',
#  'K.5.2.8.2',
#  'K.5.2.8.3',
#  'K.5.3.1',
#  'K.5.3.2',
#  'K.5.4.1',
#  'K.5.4.2',
#  'K.5.4.2.1',
#  'K.5.4.2.2',
#  'K.5.4.2.3',
#  'K.5.5.1',
#  'K.5.5.2',
#  'K.5.5.2.1',
#  'K.5.5.2.2',
#  'K.5.5.2.3',
#  'K.5.5.2.4',
#  'K.5.5.2.5',
#  'K.5.5.2.6',
#  'K.5.5.2.7',
#  'K.5.5.2.8',
#  'K.5.5.2.9',
#  'K.5.5.3',
#  'K.5.5.4',
#  'K.5.5.5',
#  'K.5.6.1',
#  'K.5.6.2',
#  'K.5.6.3',
#  'K.5.6.3.1',
#  'K.5.6.3.2',
#  'K.5.6.4',
#  'K.5.6.5',
#  'K.5.7.1',
#  'K.5.7.2',
#  'K.5.8.1',
#  'K.5.8.2',
#  'K.5.8.2.1',
#  'K.5.8.2.2',
#  'K.5.8.2.3',
#  'K.5.8.2.4',
#  'K.5.9.1',
#  'K.5.9.2',
#  'K.5.9.3',
#  'K.5.10.1',
#  'K.5.10.2',
#  'K.5.10.3',
#  'K.5.12.1',
#  'K.5.12.2',
#  'K.7.1.1',
#  'K.7.1.1.1',
#  'K.7.1.1.2',
#  'K.7.1.1.3',
#  'K.7.1.1.4',
#  'K.7.1.1.5',
#  'K.7.1.1.6',
#  'K.7.1.1.7',
#  'K.7.1.1.8',
#  'K.7.1.2',
#  'K.7.1.3',
#  'K.7.1.4',
#  'K.7.1.5',
#  'K.7.1.6',
#  'K.7.2.1',
#  'K.7.2.2',
#  'K.7.2.2.1',
#  'K.7.2.2.2',
#  'K.7.2.3',
#  'K.7.2.4',
#  'K.7.2.5',
#  'K.7.2.6',
#  'K.7.2.7',
#  'K.7.4.1',
#  'K.7.4.2',
#  'K.7.4.3',
#  'K.7.4.3.1',
#  'K.7.4.3.2',
#  'K.7.4.3.3',
#  'K.7.4.3.4',
#  'K.7.4.4',
#  'K.7.6.1',
#  'K.7.6.2',
#  'K.7.6.3',
#  'K.7.7.1',
#  'K.7.7.2',
#  'K.7.7.3',
#  'K.7.7.4',
#  'K.8.1.1',
#  'K.8.1.2',
#  'K.8.1.3',
#  'K.8.1.4',
#  'K.8.1.5',
#  'K.8.4.1',
#  'K.8.4.2',
#  'K.8.4.3',
#  'K.8.4.4',
#  'K.8.4.5',
#  'K.8.4.6',
#  'K.8.4.7',
#  'K.8.4.8',
#  'K.8.4.9',
#  'K.8.4.10',
#  'K.8.4.11',
#  'K.8.4.12',
#  'K.8.5.1',
#  'K.8.5.2',
#  'K.8.5.3',
#  'K.8.5.4',
#  'K.8.5.5',
#  'K.8.5.5.1',
#  'K.8.5.5.2',
#  'K.8.5.5.3',
#  'K.8.5.6',
#  'K.8.5.7',
#  'K.8.5.8',
#  'K.8.5.9',
#  'K.8.6.1',
#  'K.8.6.2',
#  'K.8.6.3',
#  'K.8.6.3.1',
#  'K.8.6.3.2',
#  'K.8.6.3.3',
#  'K.8.6.3.4',
#  'K.8.6.3.5',
#  'K.8.6.3.6',
#  'K.8.6.4',
#  'K.8.6.4.1',
#  'K.8.6.4.2',
#  'K.8.6.4.3',
#  'K.8.6.4.4',
#  'K.8.6.4.5',
#  'K.8.6.4.6',
#  'K.8.6.5',
#  'K.8.6.5.1',
#  'K.8.6.5.2',
#  'K.8.6.5.3',
#  'K.8.6.5.4',
#  'K.8.6.5.5',
#  'K.8.6.5.6',
#  'K.9.1.1',
#  'K.9.1.2',
#  'K.9.1.3',
#  'K.9.1.4',
#  'K.9.1.4.1',
#  'K.9.1.4.2',
#  'K.9.1.5',
#  'K.9.1.5.1',
#  'K.9.1.5.2',
#  'K.9.1.6',
#  'K.9.1.7',
#  'K.9.1.7.1',
#  'K.9.1.7.2',
#  'K.9.1.7.3',
#  'K.9.1.7.4',
#  'K.9.1.8',
#  'K.9.1.9',
#  'K.9.1.10',
#  'K.9.1.11',
#  'K.9.1.12',
#  'K.9.1.13',
#  'K.9.1.14',
#  'K.9.1.15',
#  'K.9.1.16',
#  'K.9.1.17',
#  'K.9.1.18',
#  'K.9.3.1',
#  'K.9.3.2',
#  'K.9.3.3',
#  'K.9.3.4',
#  'K.9.3.5',
#  'K.9.5.1',
#  'K.9.5.2',
#  'K.9.7.1',
#  'K.9.7.1.1',
#  'K.9.7.1.2',
#  'K.9.7.1.3',
#  'K.9.7.2',
#  'K.9.7.3',
#  'K.9.7.4',
#  'K.9.7.4.1',
#  'K.9.7.4.2',
#  'K.9.7.4.3',
#  'K.9.7.4.4',
#  'K.9.7.4.5',
#  'K.10.1.1',
#  'K.10.1.2',
#  'K.10.1.3',
#  'K.10.1.4',
#  'K.10.1.5',
#  'K.10.1.6',
#  'K.10.1.7',
#  'K.10.1.8',
#  'K.10.1.9',
#  'K.10.2.1',
#  'K.10.2.2',
#  'K.10.2.3',
#  'K.10.2.4',
#  'K.10.2.5',
#  'K.10.2.6',
#  'K.10.2.7',
#  'K.10.2.8',
#  'K.10.2.9',
#  'K.10.3.1',
#  'K.10.3.2',
#  'K.10.3.3',
#  'K.10.3.4',
#  'K.10.3.5',
#  'K.10.3.6',
#  'K.10.3.7',
#  'K.10.4.1',
#  'K.10.4.2',
#  'K.10.5.1',
#  'K.10.5.2',
#  'K.10.5.3',
#  'K.10.5.4']

# %%
list_of_h
# Out:
# ['Gross floor area (GFA)',
#  'Built-up area',
#  'Gross area and net area',
#  'Building height',
#  'Gate level',
#  'Building height',
#  'Building setbacks',
#  'Building areas',
#  'Gross area (GA)',
#  'Net area (NA)',
#  'Balconies, building projections and terraces',
#  'Limitations',
#  'Guardrails for fall protection',
#  'Plot coverage',
#  'Access doors',
#  'Ground floor',
#  'Basements',
#  'Podium',
#  'Roof',
#  'Minimum clear widths',
#  'Fire resistance rating',
#  'Kiosks in mall pedestrian ways',
#  'Stairways',
#  'General',
#  'Exit staircase construction',
#  'Stairway width',
#  'Stair risers and treads',
#  'Landings',
#  'Regular use and external stairs',
#  'Handrails',
#  'Guardrails',
#  'Ramps',
#  'Elevators',
#  'Doors',
#  'Windows and daylighting',
#  'Minimum area of windows',
#  'Daylighting',
#  'Access to views',
#  'Safety of windows',
#  'Convenience openings and communicating spaces',
#  'Atria',
#  'Courtyards',
#  'Shafts',
#  'General requirements',
#  'Vehicular ramps',
#  'Parking floors and structures',
#  'General',
#  'Open versus enclosed parking',
#  'Parking areas technical requirements',
#  'Car parking bay dimensions',
#  'Bus parking bays',
#  'Parking provisions in buildings',
#  'Parking ratios',
#  'Preferred parking',
#  'Charging equipment for electrical vehicles in malls',
#  'Bicycle parking provision in building',
#  'Loading and unloading areas',
#  'General',
#  'Minimum bays and areas clearances',
#  'Building types requirements',
#  'Truck turning radii and clearances',
#  'Service ramps',
#  'Maintenance ladders',
#  'Access to utilities',
#  'General',
#  'Sanitary finishes',
#  'Sanitary provisions and fixture calculations',
#  'Occupancy requirements',
#  'Mosques and prayer rooms',
#  'Swimming pools',
#  'Public toilets requirements',
#  'Minimum space dimensions for toilet stalls',
#  'Privacy requirements for public toilets',
#  'Fixture clearances',
#  'Cleaner’s room',
#  'Drinking fountains',
#  'Feeding rooms (lactation rooms)',
#  'First aid facilities',
#  'Gymnasiums, exercise rooms and fitness centres',
#  'Swimming pools',
#  'General requirements',
#  'Safety requirements',
#  'Swimming pool fences',
#  'Decks and walkways',
#  'Ladders and steps',
#  'Diving boards',
#  'Prayer rooms',
#  'Open spaces',
#  'Waste management hierarchy',
#  'Waste storage rooms',
#  'General',
#  'Specification of waste storage rooms',
#  'Dimensions of waste storage rooms',
#  'Recycling and segregation',
#  'Special and bulky waste',
#  'Chemical and toxic waste',
#  'Hydraulic skip compactors',
#  'Refuse chutes',
#  'General requirements',
#  'Mosque architecture',
#  'Mosque access strategy',
#  'Mosque prayer hall arrangement',
#  'Women’s prayer halls in mosques',
#  'Specific requirements for mosque types',
#  'Awqat mosques (daily prayers mosque)',
#  'Jumaa mosque (Friday prayer)',
#  'Eid Mussalla',
#  'Ablution spaces',
#  'Mosque accommodation',
#  'Mosque-specific sanitary requirements',
#  'General',
#  'Food preparation',
#  'Kitchen requirements',
#  'General requirements',
#  'Schools',
#  'Kindergartens',
#  'Nurseries',
#  'Apartment buildings',
#  'Labour accommodation',
#  'General building requirements',
#  'Labour accommodation rooms',
#  'Labour accommodation amenities',
#  'Staff accommodation',
#  'Student accommodation',
#  'Local species',
#  'Shading of public access',
#  'Heat island effect reduction - surfaces shading',
#  'Recycled materials',
#  'Regional materials',
#  'Asbestos-containing materials',
#  'Lead or heavy metals containing material',
#  'Composite timber products',
#  'Certified/accredited timber',
#  'Types',
#  'Information signs',
#  'Directional signs',
#  'Identity signs',
#  'Advisory signs',
#  'Digital screens',
#  'Accessible entrances',
#  'Entrance doors',
#  'Access control barriers',
#  'Interaction space',
#  'Toe and knee clearance',
#  'Protruding objects',
#  'Forward reach',
#  'Unobstructed forward reach',
#  'Obstructed forward reach',
#  'Side reach',
#  'Unobstructed side reach',
#  'Obstructed side reach',
#  'Children’s reach ranges',
#  'Switches, controls and socket outlets',
#  'Minimum accessible door requirements',
#  'Hardware requirements',
#  'Door opening hardware',
#  'Vision panels',
#  'Manoeuvring spaces at manual doors and doorways without doors',
#  'Manoeuvring spaces for swinging and sliding doors',
#  'Manoeuvring spaces for doorways without doors',
#  'Manoeuvring spaces for two doors in series',
#  'Power-assisted and automatic accessible doors',
#  'Ramps',
#  'Accessible and pedestrian ramp requirements',
#  'Ramp runs',
#  'Ramp landings',
#  'Ramp edge protection',
#  'Curved ramps',
#  'Ramp handrails',
#  'Stairs',
#  'Elevators',
#  'General',
#  'Accessible elevator requirements',
#  'Lift platforms',
#  'Escalators and moving walks',
#  'General',
#  'Escalators',
#  'Moving walks',
#  'General',
#  'Types of curb ramps',
#  'Curb ramps with flared sides',
#  'Returned curb ramps',
#  'Curb ramps in curb extensions',
#  'Lowered sidewalk curb ramps',
#  'Accessible parking provision',
#  'Location of accessible parking spaces',
#  'Floor surfaces',
#  'Level change',
#  'Slip resistance',
#  'Other requirements',
#  'Tactile systems',
#  'General',
#  'Detectable warning surface',
#  'Tactile guiding surfaces',
#  'Glass surfaces',
#  'Wall surfaces',
#  'General',
#  'Storage facilities',
#  'Tables',
#  'Chairs and benches',
#  'Counters and checkout aisles',
#  'General',
#  'Baby changing stations',
#  'Approach and toe clearance',
#  'Water closets',
#  'Position and arrangement of toilets',
#  'Wheelchair accessible water closets',
#  'Grab bars for water closets',
#  'Children’s water closets',
#  'Urinals',
#  'Sinks and washbasins',
#  'Showers',
#  'Accessible showers',
#  'Transfer type shower compartments',
#  'Roll-in type shower compartment',
#  'Shower seats',
#  'Grab bars for showers',
#  'Bathtubs',
#  'Position and clearances',
#  'Grab bars for bathtubs with permanent seats',
#  'Grab bars for bathtubs without permanent seats',
#  'Grab bars',
#  'Cultural buildings, libraries, museums and exhibition rooms',
#  'Theatres, cinemas, conference rooms and auditoriums',
#  'Accessible auditorium seating spaces',
#  'Stages and backstage',
#  'Libraries and reading',
#  'Mosques and prayer rooms',
#  'Public spaces',
#  'Swimming pools',
#  'Recreational buildings and amusement parks',
#  'Dining spaces',
#  'Kitchen and kitchenettes',
#  'Transport buildings, stations and terminals',
#  'Sport buildings and exercise rooms',
#  'General',
#  'Adaptable units in residential buildings',
#  'General',
#  'Accessible guest room with mobility features',
#  'Accessible guest rooms with communication features',
#  'General features',
#  'Location of tactile maps',
#  'Raised characters for tactile signage',
#  'General',
#  'Horizontal distances',
#  'General',
#  'Elevators in-line',
#  'Elevators facing each other',
#  'Number of service elevators',
#  'Rated speed',
#  'Firefighting elevators',
#  'Rated speed of firefighting elevators',
#  'Firefighting elevators in super high-rise buildings',
#  'Single grouping and one floor zone',
#  'Multiple lobbies serving one zone',
#  'Multiple groupings serving different floor zones',
#  'Population estimation',
#  'Passenger elevator selection charts',
#  'Minimum elevator specifications',
#  'Population estimation',
#  'Passenger elevator selection chart',
#  'Minimum elevator specifications',
#  'Population estimation and passenger elevator selection',
#  'Minimum elevator specifications',
#  'Population estimation',
#  'Passenger elevator selection chart',
#  'Minimum elevator specifications',
#  'Population estimation',
#  'Passenger elevator selection chart',
#  'Minimum elevator specifications',
#  'Minimum escalator specifications',
#  'Population estimation',
#  'Passenger elevator selection charts',
#  'Minimum elevator specifications',
#  'Passenger elevator selection',
#  'Minimum escalator specifications',
#  'Primary and secondary modes of circulation',
#  'Minimum elevator specifications',
#  'Population estimation',
#  'Selection tables',
#  'Minimum specifications',
#  'Population estimation',
#  'Passenger elevator selection chart',
#  'Minimum elevator specifications',
#  'General',
#  'Handling capacity',
#  'Traffic pattern',
#  'Door timing',
#  'Acceleration and jerk',
#  'Destination control systems',
#  'Hybrid systems',
#  'General',
#  'Wind loadings',
#  'Permanent fixture loading',
#  'Operational forces',
#  'Thermal movements',
#  'Deflection',
#  'Fixings',
#  'Maximum glazed area',
#  'Orientation of glazed facades',
#  'Building envelope performance',
#  'Non-glazed elements',
#  'Glazed elements',
#  'General',
#  'Horizontal and inclined surfaces',
#  'Vertical surfaces',
#  'Flashing',
#  'Rope access',
#  'Power-operated systems',
#  'General',
#  'Concrete',
#  'Steel',
#  'Masonry',
#  'Geotechnics',
#  'Geotechnics investigation and testing',
#  'Geotechnical design',
#  'Execution of geotechnical works',
#  'Concrete',
#  'Geotechnics',
#  'Seismic',
#  'General',
#  'Concrete structures',
#  'Steelwork structures',
#  'Design basis',
#  'Concrete strength',
#  'Concrete mixes',
#  'Modulus of elasticity',
#  'Section properties',
#  'Detailing of reinforcement',
#  'Design basis',
#  'Additional design requirements for post-tensioned concrete',
#  'Concrete',
#  'Concrete mixes',
#  'Tendons',
#  'Ducts',
#  'Grout',
#  'Permissible stresses in post-tensioning steel',
#  'Minimum bonded reinforcement for post-tensioned concrete',
#  'Post-tensioned concrete reinforcement',
#  'Design basis',
#  'Concrete',
#  'Concrete mixes',
#  'Reinforcement and strands',
#  'Storage, transportation, handling and erection',
#  'Connections',
#  'Design basis',
#  'Steel grades',
#  'Precast staircase',
#  'Plate thickness',
#  'Structural connections',
#  'Bolted connections',
#  'Welded connections',
#  'Post-installed anchors',
#  'Design basis',
#  'Wall panels',
#  'Brick and block strengths',
#  'Design basis',
#  'Wind pressures',
#  'Wind tunnel testing',
#  'Requirements for testing',
#  'Wind direction factors',
#  'Peer review of wind tunnel testing',
#  'Allowable building movements for wind',
#  'Allowable displacement',
#  'Motions affecting occupant comfort',
#  'Structural damping for assessment of wind responses',
#  'Scope',
#  'Seismic performance criteria',
#  'Seismic ground motion values',
#  'Near-fault sites',
#  'Dubai acceleration parameters',
#  'Site class',
#  'Site coefficients and risk-targeted maximum considered earthquake',
#  'Design spectral acceleration parameters',
#  'Design response spectrum',
#  'Risk-targeted maximum considered earthquake (MC',
#  'Site-specific ground motion procedures',
#  'Seismic design category',
#  'Geological hazards and geotechnical investigation',
#  'Damping',
#  'Cracked section stiffness',
#  'Seismic assessment of existing buildings',
#  'General',
#  'Concrete beam and slab deflection',
#  'Steelwork deflection limits',
#  'Post-tensioned concrete deflection control',
#  'General',
#  'Drift due to permanent gravity load',
#  'Drift and deformation due to differential vertical shortening',
#  'Drift and deformation due to wind',
#  'Drift and deformation due to seismic',
#  'Steelwork',
#  'Concrete',
#  'General',
#  'Geotechnical desk study',
#  'Planning geotechnical investigation',
#  'Geotechnical on-site investigations',
#  'Geotechnical laboratory testing',
#  'Geotechnical reporting',
#  'Earthworks (excavation and filling)',
#  'Foundations design',
#  'General',
#  'Shallow and raft foundations',
#  'Deep and piled foundations',
#  'Shoring and earth retaining system',
#  'General',
#  'Required shoring systems',
#  'Permanent earth retaining system',
#  'Basement walls',
#  'Groundwater control and dewatering',
#  'Liquefaction',
#  'Ground improvement',
#  'General',
#  'Earthworks (excavation and filling)',
#  'Shoring retaining systems',
#  'Foundations',
#  'Groundwater control and dewatering',
#  'Ground improvement',
#  'Component of ground motion',
#  'Return period',
#  'Electrical',
#  'District cooling',
#  'Telecommunications',
#  'Essential reading',
#  'Further reading',
#  'General',
#  'Switchgear locations',
#  'Main electrical switchroom',
#  'Individual consumer premises',
#  'Multiple consumer premises',
#  'Metering cabinet arrangement',
#  'CT metering requirements',
#  'General',
#  'Minimum size of conductors',
#  'Current rating, size and voltage drop',
#  'Cable colour identification',
#  'Conduits and fittings',
#  'Trunking',
#  'Cable trays and supports',
#  'Main and sub main distribution boards',
#  'Final distribution boards',
#  'Switches',
#  'Arc fault detection devices (AFDDs)',
#  'Plugs and socket outlets',
#  'Surge protection devices (SPDs)',
#  'Cooker control units',
#  'Kitchen appliances',
#  'Control of water heaters, saunas,',
#  'Control of air conditioning unit/',
#  'Extra LV safety apparatus',
#  'Lighting and small power circuits',
#  'Maximum demand',
#  'Trunking and conduits',
#  'Flexible conduits',
#  'Cable trays',
#  'Armoured cables',
#  'Distribution boards',
#  'Busbar trunking systems (busways/bus',
#  'Segregation of circuits, phases and',
#  'Identification labels and notices',
#  'Mounting heights of accessories',
#  'General',
#  'Consumer’s main earth electrode',
#  'Earth continuity conductor (ECC)',
#  'Earth leakage protection',
#  'Equipotential bonding',
#  'PF correction',
#  'Harmonics and rapid voltage changes',
#  'Undervoltage (UV) relays with auto',
#  'General',
#  'Wiring systems and distribution boards',
#  'Earth leakage protection',
#  'General',
#  'Mode 1 charging',
#  'Mode 2 charging',
#  'Mode 3 charging',
#  'Mode 4 charging',
#  'General',
#  'Reliability of supply',
#  'Standard cable sizes',
#  'Cable loads',
#  'Parallel operation',
#  'Harmonics',
#  'Cable trenches',
#  'General',
#  'Substation location',
#  'Substation parameters',
#  'Earthing',
#  'Single room substation (RMU and transformer in same room on',
#  'Split room substation (RMU and transformer in separate rooms on',
#  'Basement substation (RMU room in ground floor and transformer',
#  'Open to sky dedicated substation with private panel',
#  'Open to sky pocket substation',
#  'DEWA control room requirements for direct 11 kV supply',
#  'General',
#  'Natural ventilation via two exterior walls',
#  'Forced ventilation with no exterior walls',
#  'Intake arrangement',
#  'Protection requirements',
#  'General requirements',
#  'Telecoms service',
#  'Reference architecture',
#  'Lead-in ducts',
#  'Meet-me-room (MMR)',
#  'Telecom rooms',
#  'Main telecom rooms (MTRs)',
#  'Floor telecom rooms (FTRs)',
#  'Mobile network services',
#  'Apartment/office/retail consolidation',
#  'Labour accommodation consolidation cabinet',
#  'Business consolidation cabinet –',
#  'Cable pathways',
#  'Fibre termination components and',
#  'HVAC and occupant comfort',
#  'Water supplies',
#  'Drainage',
#  'Acoustics',
#  'Fire safety',
#  'Lighting',
#  'Digital services enablement and ICT',
#  'General',
#  'HVAC and occupant comfort',
#  'Water supplies',
#  'Drainage',
#  'Lighting',
#  'Commissioning',
#  'Acoustics',
#  'Digital services enablement and ICT',
#  'Water supplies and drainage',
#  'Acoustics',
#  'Digital services enablement and ICT',
#  'General',
#  'Outdoor design conditions',
#  'Indoor design conditions',
#  'Outdoor air design conditions',
#  'Heat gain and loss calculations',
#  'External load criteria',
#  'Internal load criteria',
#  'Occupancy',
#  'Lighting',
#  'Electrical equipment loads',
#  'Minimum efficiency of HVAC systems',
#  'Exhaust air energy recovery',
#  'Demand controlled ventilation',
#  'Pipe and duct insulation',
#  'Performance',
#  'Air loss from entrances/exits',
#  'General',
#  'Minimum ventilation requirements for adequate indoor air quality',
#  'Indoor air quality',
#  'Air inlets and exhausts',
#  'Isolation of pollutant sources',
#  'Pandemic air quality measures',
#  'General',
#  'Ducts and duct connectors',
#  'Shafts as air ducts',
#  'Plenums',
#  'Air filters',
#  'Ductwork air leakage',
#  'Exhaust ventilation systems',
#  'Mechanical ventilation in fire mode',
#  'Fire and smoke dampers',
#  'General',
#  'Materials',
#  'Pipe joints and connections',
#  'Valves',
#  'Pipe installation',
#  'Pipe design',
#  'Pumped hydronic systems',
#  'Pressure vessels',
#  'Boilers',
#  'Controls for HVAC systems',
#  'Building management system (BMS)',
#  'H.4.14.3 Control systems for hotel rooms',
#  'Air-conditioning metering',
#  'General',
#  'Materials',
#  'Joints and connections',
#  'Piping support',
#  'Gas-fired appliances',
#  'Fireplace stoves and room heaters',
#  'Cooling towers, evaporative condensers and fluid coolers',
#  'Infrared radiant heaters',
#  'Sauna heaters',
#  'Engine and gas turbine-powered equipment and appliances',
#  'Pool and spa heaters',
#  'Cooking appliances',
#  'Conversion burners',
#  'Compliance methods',
#  'Water-efficient fittings',
#  'Water-efficient irrigation',
#  'Water metering',
#  'Main meters',
#  'Sub-meters',
#  'Condensate drainage',
#  'Condensate reuse',
#  'Wastewater reuse',
#  'Cooling tower water supply',
#  'Cold water distribution',
#  'Cooled water systems',
#  'Water recycling systems',
#  'Laboratory buildings',
#  'Swimming pool cold water supply',
#  'Irrigation water supply',
#  'General',
#  'Water tank locations',
#  'Water storage tank sizing',
#  'Water tank construction',
#  'Tank pump room',
#  'Firefighting water tanks',
#  'Combined firefighting and water storage',
#  'Treatment against microbiological bacteria growth',
#  'Water softening',
#  'General',
#  'Sanitation system disposal',
#  'Drainage from mechanical plant',
#  'Floor drains',
#  'Ventilation pipework',
#  'Sanitary plumbing acoustic requirements',
#  'Rodding eyes',
#  'Sanitation pipework',
#  'Leak detection systems',
#  'Drainage systems',
#  'Access to drainage systems',
#  'Sump pits',
#  'Foul pumping stations',
#  'Manholes',
#  'Manhole construction',
#  'Final inspection chamber and provision for future connection',
#  'General',
#  'Siphonic rainwater disposal systems',
#  'Rainwater disposal system acoustic requirements',
#  'Drainage of hardstanding paved areas',
#  'Miscellaneous rainwater drainage',
#  'General',
#  'Building services noise',
#  'Sound insulation',
#  'Control of reverberation',
#  'Mosques',
#  'Healthcare',
#  'Educational',
#  'Hotels',
#  'Performing arts venues',
#  'Digital building technology model',
#  'Implementation requirements',
#  'IoT protocols for digital services enablement',
#  'Building control and operation communication protocols',
#  'Device and data naming',
#  'Data governance and privacy',
#  'Home automation in residential buildings',
#  'Device requirements and security',
#  'Data validation',
#  'Overview',
#  'Equipment rooms and cabling pathways',
#  'Landlord and tenant cabling infrastructure',
#  'Distribution techniques',
#  'Connection topologies for digital services in buildings',
#  'Landlord data network infrastructure',
#  'Special safety monitoring requirements',
#  'Wireless technology',
#  'Context',
#  'Conventional approach to digital services and smart functionality in',
#  'Digital services enabled approach',
#  'General',
#  'Star topology',
#  'Ring topology',
#  'Bus topology',
#  'Mesh topology',
#  'Electrical',
#  'Telecommunications',
#  'HVAC systems and occupant comfort',
#  'Water',
#  'Drainage',
#  'General',
#  'Concrete',
#  'Steel',
#  'Masonry',
#  'Geotechnics',
#  'Geotechnical investigation and testing',
#  'Geotechnical design',
#  'Execution of geotechnical works',
#  'Electrical',
#  'Telecommunications',
#  'HVAC systems and occupant comfort',
#  'Water',
#  'Drainage',
#  'Acoustics',
#  'Gate level',
#  'Building height',
#  'Annexes',
#  'Building setbacks',
#  'Balconies, building projections and terraces',
#  'Limitations',
#  'Guardrails for fall protection',
#  'Gross area (GA)',
#  'Plot coverage',
#  'Floors general requirements',
#  'Ground floor',
#  'Basements',
#  'Roof',
#  'Minimum room sizes',
#  'Minimum clear heights',
#  'Doors',
#  'Windows and daylighting',
#  'Minimum area of windows',
#  'Habitable room conditions for natural lighting',
#  'Access to views',
#  'Hallways and corridors',
#  'Stairs',
#  'General',
#  'Stairway width',
#  'Stair risers and treads',
#  'Landings',
#  'Handrails',
#  'Guardrails',
#  'Exterior stairways',
#  'Spiral or curved stairs and winders',
#  'Surfaces',
#  'Ramps',
#  'Elevators',
#  'Means of egress',
#  'Building access',
#  'Firefighting vehicle access',
#  'Vehicle access and movement',
#  'General requirements',
#  'Vehicular ramps',
#  'Parking areas and garage',
#  'Maintenance ladders',
#  'General requirements',
#  'Fixture clearances',
#  'Gymnasiums, exercise rooms',
#  'Swimming pools',
#  'General requirements',
#  'Swimming pool floors',
#  'Swimming pool fences',
#  'Decks and walkways',
#  'General',
#  'Specification of waste storage areas',
#  'Dimensions of waste storage areas',
#  'Asbestos-containing materials',
#  'Lead or heavy metals containing material',
#  'Interior finishes',
#  'Surfaces shading',
#  'Exterior light pollution and controls',
#  'Strength and stability',
#  'General',
#  'Wind loads',
#  'Load resistance and transmission',
#  'Permanent fixture loading',
#  'Operational forces',
#  'Thermal movements',
#  'Deflection',
#  'Fixings',
#  'Structural use of glass',
#  'Structural use of silicone',
#  'Materials',
#  'Impact resistance',
#  'Load combination',
#  'Energy compliance method',
#  'Building envelope performance',
#  'Non-glazed elements',
#  'Glazed elements – Fenestration',
#  'Shade effect calculation',
#  'Thermal bridges',
#  'Durability',
#  'Sealing of windows and doors',
#  'Heat island effect reduction',
#  'General',
#  'Ground moisture',
#  'Precipitation including windblown spray',
#  'General',
#  'Horizontal and inclined surfaces',
#  'Vertical surfaces',
#  'Flashing',
#  'Risk of interstitial or surface condensation',
#  'Protection against impact with glazing',
#  'Containment',
#  'Overhead glazing',
#  'General',
#  'Fire testing of non-fire-rated, non-load-bearing façades and aesthetic',
#  'Solid metal panels',
#  'Roof assemblies',
#  'General conditions',
#  'Design life',
#  'Design acceptance criteria',
#  'Structural system and robustness',
#  'Durability',
#  'General',
#  'Load combinations',
#  'Dead loads',
#  'Superimposed dead loads',
#  'Live loads',
#  'Soil loads and hydrostatic pressure',
#  'Construction load',
#  'Accidental impact load',
#  'Self-straining forces',
#  'Thermally induced forces',
#  'Design for wind loading effects',
#  'Design for earthquake effects',
#  'Design basis',
#  'Strength',
#  'Deflection control',
#  'Crack control in concrete structure',
#  'Drift and deformation',
#  'General',
#  'Drift and deformation due to wind',
#  'Drift and deformation due to seismic',
#  'Movement joints and building separation',
#  'Vibration',
#  'Fatigue',
#  'Transfer elements',
#  'General',
#  'Standards',
#  'Geotechnical site investigation',
#  'General',
#  'Geotechnical desk study',
#  'Planning geotechnical investigation',
#  'Geotechnical on-site investigations',
#  'Geotechnical laboratory testing',
#  'Geotechnical reporting',
#  'Geotechnical design',
#  'Earthworks (excavation and fill)',
#  'Foundations design',
#  'Shoring and retaining systems',
#  'Groundwater control and dewatering',
#  'Liquefaction',
#  'Ground improvement',
#  'Execution of geotechnical works',
#  'General',
#  'Earthworks (excavation and filling)',
#  'Shoring retaining systems',
#  'Foundations',
#  'Groundwater control and dewatering',
#  'Ground improvement',
#  'General',
#  'Electrical supply',
#  'Incoming and metering',
#  'Point of supply',
#  'General',
#  'Switchgear locations',
#  'Tariff metering',
#  'Individual consumers premises',
#  'CT metering requirements',
#  'Ambient design conditions',
#  'Cables and conductors',
#  'General',
#  'Minimum size of conductors',
#  'Current rating, size and voltage drop',
#  'Cable colour identification',
#  'Wiring installation exposed to high temperatures',
#  'Wiring installations in hazardous areas',
#  'Load balancing',
#  'Wiring accessories',
#  'Distribution boards and consumer units',
#  'Apparatus and accessories',
#  'Standby generators',
#  'Assessment of connected load and',
#  'Design criteria for the installation of conduits, trunking, trays and',
#  'Design criteria for the installation of cables, equipment, accessories',
#  'Earthing and earth leakage protection',
#  'General',
#  'System documentation requirements',
#  'Wiring diagram datasheets',
#  'Labelling and identification',
#  'Metering and metering provision',
#  'Water metering and water conservation',
#  'Design and installation of water meters',
#  'Design and installation of telecom infrastructure',
#  'General requirements',
#  'Telecoms service',
#  'Reference architecture',
#  'Responsibility matrix',
#  'Outside plant (OSP) common infrastructure specifications',
#  'Inside plant common infrastructure specifications (ISP)',
#  'Telecom spaces',
#  'Consolidation cabinets',
#  'Cable pathways',
#  'Cables and termination equipment',
#  'Labelling scheme',
#  'General',
#  'Acoustic requirements and noise criteria',
#  'Building HVAC energy load',
#  'Thermal comfort criteria',
#  'Energy conservation and efficiency: building systems',
#  'Ventilation and air quality',
#  'Natural ventilation',
#  'Mechanical ventilation',
#  'Hydronic systems',
#  'General',
#  'Water conservation and reuse',
#  'Cold water services',
#  'Tank pump-set installation',
#  'Cold water storage tanks',
#  'Combined firefighting and water storage',
#  'Servicing and isolation valves',
#  'Backflow protection',
#  'Hot water services',
#  'General',
#  'Sanitary plumbing systems',
#  'Below ground drainage systems',
#  'Rainwater disposal',
#  'Swimming pools',
#  'Septic tanks and sewage holding tanks',
#  'Soakaways',
#  'General',
#  'Lighting controls',
#  'Emergency lighting',
#  'Fire detection and alarm',
#  'Sprinklers and hose reels',
#  'Smart monitoring']

# %%
# making data frame from list

df = pd.DataFrame(list(zip(list_of_i, list_of_h)),
               columns =['Index', 'Heading'])

# %%
df.head()
# Out:
#      Index                  Heading
# 0  A.5.2.1   Gross floor area (GFA)
# 1  A.5.2.2            Built-up area
# 2  A.5.2.3  Gross area and net area
# 3  A.5.2.4          Building height
# 4  B.4.2.1               Gate level

# %%
# sorting by first name
df.sort_values("Heading", inplace = True)
 
# dropping ALL duplicate values
df.drop_duplicates(subset ="Heading",
                     keep = False, inplace = True)

# %%
df.to_csv('Index_heading.csv')

# %%
df.head()
# Out:
#          Index                     Heading
# 107    B.9.4.7             Ablution spaces
# 288    D.9.8.2       Acceleration and jerk
# 141    C.5.4.3     Access control barriers
# 14   B.4.2.5.3                Access doors
# 623    H.6.3.2  Access to drainage systems
