# %% [markdown]
# # Text Extraction from PDF using PyMuPDF

# %%
import fitz
import pandas as pd 
doc = fitz.open('Dubai Building Code_English_2021 Edition_compressed.pdf')
page1 = doc[3]
words = page1.get_text("words")

# %%
words[9]
# Out:
# (107.722900390625,
#  78.3617172241211,
#  196.03089904785156,
#  108.74571228027344,
#  'Introduction',
#  2,
#  1,
#  0)

# %% [markdown]
# ## Extracting Coordinates of the first object

# %%
def make_text(words):

    line_dict = {} 

    words.sort(key=lambda w: w[0])

    for w in words:  

        y1 = round(w[3], 1)  

        word = w[4] 

        line = line_dict.get(y1, [])  

        line.append(word)  

        line_dict[y1] = line  

    lines = list(line_dict.items())

    lines.sort()  

    return "n".join([" ".join(line[1]) for line in lines])

# %%
dict1 = page1.get_text("dict")
print(dict1)
# Out:
# {'width': 841.89, 'height': 595.276, 'blocks': [{'number': 0, 'type': 0, 'bbox': (56.692901611328125, 13.385185241699219, 785.1934204101562, 31.10918426513672), 'lines': [{'spans': [{'size': 10.5, 'flags': 4, 'font': 'Dubai-Regular', 'color': 16777215, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'Dubai Building Code', 'origin': (56.692901611328125, 25.23968505859375), 'bbox': (56.692901611328125, 13.385185241699219, 141.16539001464844, 31.10918426513672)}], 'wmode': 0, 'dir': (1.0, 0.0), 'bbox': (56.692901611328125, 13.385185241699219, 141.16539001464844, 31.10918426513672)}, {'spans': [{'size': 10.5, 'flags': 4, 'font': 'Dubai-Regular', 'color': 16777215, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'Part A: General', 'origin': (721.6158447265625, 25.23968505859375), 'bbox': (721.6158447265625, 13.385185241699219, 785.1934204101562, 31.10918426513672)}], 'wmode': 0, 'dir': (1.0, 0.0), 'bbox': (721.6158447265625, 13.385185241699219, 785.1934204101562, 31.10918426513672)}]}, {'number': 1, 'type': 0, 'bbox': (56.692901611328125, 559.0545043945312, 71.31939697265625, 576.7785034179688), 'lines': [{'spans': [{'size': 10.5, 'flags': 4, 'font': 'Dubai-Regular', 'color': 8882054, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'A 2', 'origin': (56.692901611328125, 570.9089965820312), 'bbox': (56.692901611328125, 559.0545043945312, 71.31939697265625, 576.7785034179688)}], 'wmode': 0, 'dir': (1.0, 0.0), 'bbox': (56.692901611328125, 559.0545043945312, 71.31939697265625, 576.7785034179688)}]}, {'number': 2, 'type': 0, 'bbox': (56.692901611328125, 78.3617172241211, 196.03089904785156, 108.74571228027344), 'lines': [{'spans': [{'size': 18.0, 'flags': 4, 'font': 'Dubai-Regular', 'color': 2177098, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'A.1 ', 'origin': (56.692901611328125, 98.6837158203125), 'bbox': (56.692901611328125, 78.3617172241211, 85.51091003417969, 108.74571228027344)}], 'wmode': 0, 'dir': (1.0, 0.0), 'bbox': (56.692901611328125, 78.3617172241211, 85.51091003417969, 108.74571228027344)}, {'spans': [{'size': 18.0, 'flags': 4, 'font': 'Dubai-Regular', 'color': 2177098, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'Introduction', 'origin': (107.722900390625, 98.6837158203125), 'bbox': (107.722900390625, 78.3617172241211, 196.03089904785156, 108.74571228027344)}], 'wmode': 0, 'dir': (1.0, 0.0), 'bbox': (107.722900390625, 78.3617172241211, 196.03089904785156, 108.74571228027344)}]}, {'number': 3, 'type': 0, 'bbox': (56.692901611328125, 123.66390228271484, 394.392822265625, 167.38589477539062), 'lines': [{'spans': [{'size': 10.5, 'flags': 4, 'font': 'Dubai-Regular', 'color': 3488054, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'The objective of the Dubai Building Code (DBC) is to unify building design across ', 'origin': (56.692901611328125, 135.51840209960938), 'bbox': (56.692901611328125, 123.66390228271484, 394.392822265625, 141.38790893554688)}], 'wmode': 0, 'dir': (1.0, 0.0), 'bbox': (56.692901611328125, 123.66390228271484, 394.392822265625, 141.38790893554688)}, {'spans': [{'size': 10.5, 'flags': 4, 'font': 'Dubai-Regular', 'color': 3488054, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'Dubai, and to create a building code that is easy to use and clearly mandates the ', 'origin': (56.692901611328125, 148.51739501953125), 'bbox': (56.692901611328125, 136.66290283203125, 391.0118103027344, 154.38690185546875)}], 'wmode': 0, 'dir': (1.0, 0.0), 'bbox': (56.692901611328125, 136.66290283203125, 391.0118103027344, 154.38690185546875)}, {'spans': [{'size': 10.5, 'flags': 4, 'font': 'Dubai-Regular', 'color': 3488054, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'minimum requirements for:', 'origin': (56.692901611328125, 161.51638793945312), 'bbox': (56.692901611328125, 149.66189575195312, 169.91336059570312, 167.3858 ...

# %%
blocks = dict1["blocks"]

# %%
print(blocks)
# Out:
# [{'number': 0, 'type': 0, 'bbox': (56.692901611328125, 13.385185241699219, 785.1934204101562, 31.10918426513672), 'lines': [{'spans': [{'size': 10.5, 'flags': 4, 'font': 'Dubai-Regular', 'color': 16777215, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'Dubai Building Code', 'origin': (56.692901611328125, 25.23968505859375), 'bbox': (56.692901611328125, 13.385185241699219, 141.16539001464844, 31.10918426513672)}], 'wmode': 0, 'dir': (1.0, 0.0), 'bbox': (56.692901611328125, 13.385185241699219, 141.16539001464844, 31.10918426513672)}, {'spans': [{'size': 10.5, 'flags': 4, 'font': 'Dubai-Regular', 'color': 16777215, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'Part A: General', 'origin': (721.6158447265625, 25.23968505859375), 'bbox': (721.6158447265625, 13.385185241699219, 785.1934204101562, 31.10918426513672)}], 'wmode': 0, 'dir': (1.0, 0.0), 'bbox': (721.6158447265625, 13.385185241699219, 785.1934204101562, 31.10918426513672)}]}, {'number': 1, 'type': 0, 'bbox': (56.692901611328125, 559.0545043945312, 71.31939697265625, 576.7785034179688), 'lines': [{'spans': [{'size': 10.5, 'flags': 4, 'font': 'Dubai-Regular', 'color': 8882054, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'A 2', 'origin': (56.692901611328125, 570.9089965820312), 'bbox': (56.692901611328125, 559.0545043945312, 71.31939697265625, 576.7785034179688)}], 'wmode': 0, 'dir': (1.0, 0.0), 'bbox': (56.692901611328125, 559.0545043945312, 71.31939697265625, 576.7785034179688)}]}, {'number': 2, 'type': 0, 'bbox': (56.692901611328125, 78.3617172241211, 196.03089904785156, 108.74571228027344), 'lines': [{'spans': [{'size': 18.0, 'flags': 4, 'font': 'Dubai-Regular', 'color': 2177098, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'A.1 ', 'origin': (56.692901611328125, 98.6837158203125), 'bbox': (56.692901611328125, 78.3617172241211, 85.51091003417969, 108.74571228027344)}], 'wmode': 0, 'dir': (1.0, 0.0), 'bbox': (56.692901611328125, 78.3617172241211, 85.51091003417969, 108.74571228027344)}, {'spans': [{'size': 18.0, 'flags': 4, 'font': 'Dubai-Regular', 'color': 2177098, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'Introduction', 'origin': (107.722900390625, 98.6837158203125), 'bbox': (107.722900390625, 78.3617172241211, 196.03089904785156, 108.74571228027344)}], 'wmode': 0, 'dir': (1.0, 0.0), 'bbox': (107.722900390625, 78.3617172241211, 196.03089904785156, 108.74571228027344)}]}, {'number': 3, 'type': 0, 'bbox': (56.692901611328125, 123.66390228271484, 394.392822265625, 167.38589477539062), 'lines': [{'spans': [{'size': 10.5, 'flags': 4, 'font': 'Dubai-Regular', 'color': 3488054, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'The objective of the Dubai Building Code (DBC) is to unify building design across ', 'origin': (56.692901611328125, 135.51840209960938), 'bbox': (56.692901611328125, 123.66390228271484, 394.392822265625, 141.38790893554688)}], 'wmode': 0, 'dir': (1.0, 0.0), 'bbox': (56.692901611328125, 123.66390228271484, 394.392822265625, 141.38790893554688)}, {'spans': [{'size': 10.5, 'flags': 4, 'font': 'Dubai-Regular', 'color': 3488054, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'Dubai, and to create a building code that is easy to use and clearly mandates the ', 'origin': (56.692901611328125, 148.51739501953125), 'bbox': (56.692901611328125, 136.66290283203125, 391.0118103027344, 154.38690185546875)}], 'wmode': 0, 'dir': (1.0, 0.0), 'bbox': (56.692901611328125, 136.66290283203125, 391.0118103027344, 154.38690185546875)}, {'spans': [{'size': 10.5, 'flags': 4, 'font': 'Dubai-Regular', 'color': 3488054, 'ascender': 1.128999948501587, 'descender': -0.5590000152587891, 'text': 'minimum requirements for:', 'origin': (56.692901611328125, 161.51638793945312), 'bbox': (56.692901611328125, 149.66189575195312, 169.91336059570312, 167.38589477539062)}], 'wmode': 0, 'dir': (1.0, 0.0), ' ...

# %%
# styles = {}
# font_counts = {}

# for b in blocks:  # iterate through the text blocks
#             if b['type'] == 0:  # block contains text
#                 for l in b["lines"]:  # iterate through the text lines
#                     for s in l["spans"]:  # iterate through the text spans
#                         identifier = "{0}_{1}_{2}_{3}".format(s['size'], s['flags'], s['font'], s['color'])
#                         styles[identifier] = {'size': s['size'], 'flags': s['flags'], 'font': s['font'],
#                                                   'color': s['color']
                                              
#                         print(font_counts.get(identifier)) # count the fonts usage

# %%
all_annots = []

# %%
for pageno in range(0,len(doc)-1):

    page = doc[pageno]

    words = page.get_text("words")

    for annot in page.annots():

        if annot!=None:

            rec=annot.rect

            mywords = [w for w in words if fitz.Rect(w[:4]) in rec]

            ann= make_text(mywords)

            all_annots.append(ann)

# %%
from operator import itemgetter

# %%
def fonts(doc, granularity=False):
    """Extracts fonts and their usage in PDF documents.
    :param doc: PDF document to iterate through
    :type doc: <class 'fitz.fitz.Document'>
    :param granularity: also use 'font', 'flags' and 'color' to discriminate text
    :type granularity: bool
    :rtype: [(font_size, count), (font_size, count}], dict
    :return: most used fonts sorted by count, font style information
    """
    styles = {}
    font_counts = {}

    for page in doc:
        blocks = page.get_text("dict")["blocks"]
        for b in blocks:  # iterate through the text blocks
            if b['type'] == 0:  # block contains text
                for l in b["lines"]:  # iterate through the text lines
                    for s in l["spans"]:  # iterate through the text spans
                        if s['color'] != 3488054:
                            
                            if granularity:
                                identifier = "{0}_{1}_{2}_{3}".format(s['size'], s['flags'], s['font'], s['color'])
                                styles[identifier] = {'size': s['size'], 'flags': s['flags'], 'font': s['font'],
                                                        'color': s['color']}
                            else:
                                identifier = "{0}".format(s['size'])
                                styles[identifier] = {'size': s['size'], 'font': s['font']}

                            font_counts[identifier] = font_counts.get(identifier, 0) + 1  # count the fonts usage

    font_counts = sorted(font_counts.items(), key=itemgetter(1), reverse=True)

    if len(font_counts) < 1:
        raise ValueError("Zero discriminating fonts found!")

    return font_counts, styles

# %%
font_counts, styles = fonts(doc)

# %%
font_counts
# Out:
# [('10.5', 7050),
#  ('8.5', 2467),
#  ('8.0', 1569),
#  ('13.0', 254),
#  ('7.800000190734863', 243),
#  ('9.779999732971191', 206),
#  ('18.0', 203),
#  ('9.0', 198),
#  ('9.779500007629395', 161),
#  ('4.95550012588501', 145),
#  ('4.07480001449585', 83),
#  ('8.884200096130371', 76),
#  ('8.757599830627441', 70),
#  ('8.639100074768066', 63),
#  ('7.0', 59),
#  ('6.061299800872803', 59),
#  ('7.795300006866455', 57),
#  ('14.0', 54),
#  ('6.014599800109863', 44),
#  ('6.0808000564575195', 44),
#  ('6.879700183868408', 42),
#  ('7.679200172424316', 42),
#  ('5.807499885559082', 39),
#  ('8.936400413513184', 39),
#  ('8.285900115966797', 36),
#  ('7.160900115966797', 36),
#  ('6.121500015258789', 35),
#  ('8.96679973602295', 33),
#  ('7.124899864196777', 30),
#  ('4.405200004577637', 29),
#  ('9.820734024047852', 28),
#  ('6.417399883270264', 28),
#  ('9.325900077819824', 27),
#  ('9.291000366210938', 25),
#  ('5.5', 25),
#  ('9.335399627685547', 24),
#  ('8.788299560546875', 24),
#  ('9.434599876403809', 23),
#  ('8.235199928283691', 23),
#  ('7.090000152587891', 23),
#  ('6.9517998695373535', 22),
#  ('7.7845001220703125', 22),
#  ('8.770700454711914', 22),
#  ('7.461299896240234', 21),
#  ('6.846499919891357', 21),
#  ('8.068300247192383', 21),
#  ('10.0', 20),
#  ('6.804200172424316', 20),
#  ('8.89210033416748', 19),
#  ('7.605899810791016', 19),
#  ('8.382833480834961', 19),
#  ('7.328700065612793', 19),
#  ('8.142800331115723', 18),
#  ('7.019999980926514', 18),
#  ('8.966099739074707', 18),
#  ('8.891500473022461', 18),
#  ('6.577899932861328', 17),
#  ('8.121299743652344', 17),
#  ('8.183799743652344', 17),
#  ('8.74530029296875', 17),
#  ('6.289100170135498', 17),
#  ('6.608399868011475', 16),
#  ('4.071400165557861', 16),
#  ('8.935999870300293', 16),
#  ('9.290499687194824', 15),
#  ('8.253600120544434', 15),
#  ('40.0', 1),
#  ('7.338699817657471', 1),
#  ('9.739899635314941', 1),
#  ('9.748499870300293', 1),
#  ('9.554332733154297', 1),
#  ('9.83409309387207', 1),
#  ('9.834266662597656', 1),
#  ('9.834213256835938', 1),
#  ('9.834295272827148', 1),
#  ('9.834251403808594', 1),
#  ('9.83423137664795', 1),
#  ('9.834272384643555', 1),
#  ('8.892159461975098', 1),
#  ('8.89212703704834', 1),
#  ('9.434410095214844', 1),
#  ('7.594200134277344', 1),
#  ('14.777600288391113', 1),
#  ('9.706199645996094', 1),
#  ('9.729710578918457', 1),
#  ('9.741395950317383', 1),
#  ('9.89109992980957', 1),
#  ('11.169095993041992', 1),
#  ('11.16909122467041', 1),
#  ('11.938801765441895', 1),
#  ('9.681260108947754', 1),
#  ('7.709299087524414', 1),
#  ('7.7093915939331055', 1),
#  ('7.85161828994751', 1),
#  ('7.851696014404297', 1),
#  ('7.727099418640137', 1),
#  ('8.31470012664795', 1),
#  ('8.95934009552002', 1),
#  ('5.631186008453369', 1),
#  ('12.514846801757812', 1),
#  ('7.999084949493408', 1),
#  ('7.999100208282471', 1),
#  ('7.99916410446167', 1),
#  ('8.560002326965332', 1),
#  ('8.560074806213379', 1),
#  ('9.779315948486328', 1),
#  ('10.5615873336792', 1),
#  ('13.894481658935547', 1),
#  ('10.549200057983398', 1),
#  ('8.597599983215332', 1),
#  ('8.171299934387207', 1),
#  ('6.517000198364258', 1),
#  ('6.304178714752197', 1),
#  ('9.772100448608398', 1),
#  ('6.514699935913086', 1),
#  ('6.619699954986572', 1),
#  ('8.745280265808105', 1),
#  ('6.253300189971924', 1),
#  ('5.895400047302246', 1),
#  ('5.782700061798096', 1),
#  ('8.999957084655762', 1),
#  ('8.99998950958252', 1),
#  ('6.3735527992248535', 1)]

# %%
styles
# Out:
# {'48.0': {'size': 48.0, 'font': 'Dubai-Bold'},
#  '12.0': {'size': 12.0, 'font': 'GothamOffice-Regular'},
#  '10.5': {'size': 10.5, 'font': 'Dubai-Bold'},
#  '18.0': {'size': 18.0, 'font': 'Dubai-Regular'},
#  '13.0': {'size': 13.0, 'font': 'Dubai-Regular'},
#  '14.0': {'size': 14.0, 'font': 'Wingdings2'},
#  '36.0': {'size': 36.0, 'font': 'Dubai-Regular'},
#  '8.5': {'size': 8.5, 'font': 'Dubai-Medium'},
#  '8.0': {'size': 8.0, 'font': 'Dubai-Regular'},
#  '7.795300006866455': {'size': 7.795300006866455,
#   'font': 'GothamOffice-Regular'},
#  '7.800000190734863': {'size': 7.800000190734863,
#   'font': 'GothamOffice-Regular'},
#  '6.854100227355957': {'size': 6.854100227355957,
#   'font': 'GothamOffice-Regular'},
#  '7.75439977645874': {'size': 7.75439977645874,
#   'font': 'GothamOffice-Regular'},
#  '9.722299575805664': {'size': 9.722299575805664,
#   'font': 'GothamOffice-Regular'},
#  '9.437000274658203': {'size': 9.437000274658203,
#   'font': 'GothamOffice-Regular'},
#  '7.526500225067139': {'size': 7.526500225067139,
#  '6.556399822235107': {'size': 6.556399822235107,
#   'font': 'GothamOffice-Regular'},
#  '6.949399948120117': {'size': 6.949399948120117,
#   'font': 'GothamOffice-Regular'},
#  '6.0808000564575195': {'size': 6.0808000564575195,
#   'font': 'GothamOffice-Regular'},
#  '6.3735527992248535': {'size': 6.3735527992248535,
#   'font': 'GothamOffice-Regular'},
#  '5.5': {'size': 5.5, 'font': 'GothamOffice-Regular'},
#  '6.5': {'size': 6.5, 'font': 'GothamOffice-Regular'},
#  '6.806399822235107': {'size': 6.806399822235107,
#   'font': 'GothamOffice-Regular'},
#  '7.575699806213379': {'size': 7.575699806213379,
#   'font': 'GothamOffice-Regular'},
#  '8.067500114440918': {'size': 8.067500114440918,
#   'font': 'GothamOffice-Regular'},
#  '8.068300247192383': {'size': 8.068300247192383,
#   'font': 'GothamOffice-Regular'},
#  '8.06879997253418': {'size': 8.06879997253418,
#   'font': 'GothamOffice-Regular'},
#  '7.599999904632568': {'size': 7.599999904632568,
#   'font': 'GothamOffice-Regular'},
#  '6.7667999267578125': {'size': 6.7667999267578125,
#   'font': 'GothamOffice-Regular'},
#  '5.583099842071533': {'size': 5.583099842071533,
#   'font': 'GothamOffice-Regular'},
#  '7.979800224304199': {'size': 7.979800224304199,
#   'font': 'GothamOffice-Regular'},
#  '8.97719955444336': {'size': 8.97719955444336,
#   'font': 'GothamOffice-Regular'}}

# %%
p_style = styles[font_counts[0][0]]  # get style for most used font by count (paragraph)
print(p_style['size'])
# Out:
# 10.5

# %%
def font_tags(font_counts, styles):
    """Returns dictionary with font sizes as keys and tags as value.
    :param font_counts: (font_size, count) for all fonts occuring in document
    :type font_counts: list
    :param styles: all styles found in the document
    :type styles: dict
    :rtype: dict
    :return: all element tags based on font-sizes
    """
    p_style = styles[font_counts[0][0]]  # get style for most used font by count (paragraph)
    p_size = p_style['size']  # get the paragraph's size

    # sorting the font sizes high to low, so that we can append the right integer to each tag 
    font_sizes = []
    for (font_size, count) in font_counts:
        font_sizes.append(float(font_size))
    font_sizes.sort(reverse=True)

    # aggregating the tags for each font size
    idx = 0
    size_tag = {}
    for size in font_sizes:
        idx += 1
        if size == p_size:
            idx = 0
            size_tag[size] = '<p>'
        if size > p_size:
            size_tag[size] = '<h{0}>'.format(idx)
        elif size < p_size:
            size_tag[size] = '<s{0}>'.format(idx)

    return size_tag

# %%
size_tag = font_tags(font_counts, styles)

# %%
print(size_tag)
# Out:
# {48.0: '<h1>', 40.0: '<h2>', 36.0: '<h3>', 18.0: '<h4>', 14.777600288391113: '<h5>', 14.0: '<h6>', 13.894518852233887: '<h7>', 13.894499778747559: '<h8>', 13.894481658935547: '<h9>', 13.240099906921387: '<h10>', 13.0: '<h11>', 12.514846801757812: '<h12>', 12.225199699401855: '<h13>', 12.0: '<h14>', 11.938801765441895: '<h15>', 11.169095993041992: '<h16>', 11.16909122467041: '<h17>', 11.032400131225586: '<h18>', 10.994600296020508: '<h19>', 10.991999626159668: '<h20>', 10.979999542236328: '<h21>', 10.799099922180176: '<h
451499938964844: '<s98>', 9.438699722290039: '<s99>', 9.437000274658203: '<s100>', 9.434599876403809: '<s101>', 9.434410095214844: '<s102>', 9.431938171386719: '<s103>', 9.43190860748291: '<s104>', 9.431900024414062: '<s105>', 9.388299942016602: '<s106>', 9.385199546813965: '<s107>', 9.35420036315918: '<s108>', 9.339699745178223: '<s109>', 9.335399627685547: '<s110>', 9.335363388061523: '<s111>', 9.333399772644043: '<s112>', 9.333000183105469: '<s113>', 9.328200340270996: '<s114>', 9.326499938964844: '<s115>', 9.325900077819824: '<s116>', 9.291000366210938: '<s117>', 9.290499687194824: '<s118>', 9.247400283813477: '<s119>', 9.223199844360352: '<s120>',  ...

# %%
type(size_tag)
# Out:
# dict

# %%
def headers_para(doc, size_tag):
    """Scrapes headers & paragraphs from PDF and return texts with element tags.
    :param doc: PDF document to iterate through
    :type doc: <class 'fitz.fitz.Document'>
    :param size_tag: textual element tags for each size
    :type size_tag: dict
    :rtype: list
    :return: texts with pre-prended element tags
    """
    header_para = []  # list with headers and paragraphs
    first = True  # boolean operator for first header
    previous_s = {}  # previous span

    for page in doc:
        blocks = page.get_text("dict")["blocks"]
        for b in blocks:  # iterate through the text blocks
            if b['type'] == 0:  # this block contains text

                # REMEMBER: multiple fonts and sizes are possible IN one block

                block_string = ""  # text found in block
                for l in b["lines"]:  # iterate through the text lines
                    for s in l["spans"]:  # iterate through the text spans
                        if s['text'].strip():  # removing whitespaces:
                            if s['size'] in size_tag:
                                if first:
                                    previous_s = s
                                    first = False
                                    block_string = size_tag[s['size']] + s['text']
                                else:
                                    if s['size'] == previous_s['size']:

                                        if block_string and all((c == "|") for c in block_string):
                                            # block_string only contains pipes
                                            block_string = size_tag[s['size']] + s['text']
                                        if block_string == "":
                                            # new block has started, so append size tag
                                            block_string = size_tag[s['size']] + s['text']
                                        else:  # in the same block, so concatenate strings
                                            block_string += " " + s['text']

                                    else:
                                        header_para.append(block_string)
    #                                        print(size_tag[s['size']])
                                        block_string = size_tag[s['size']] + s['text']

                                    previous_s = s

                    # new block started, indicating with a pipe
                    block_string += "|"

                header_para.append(block_string)

    return header_para

# %%
print(headers_para(doc, size_tag))
# Out:
# ['<h1>Dubai| Building Code|', '', '<h14>2021 Edition|', '', '<p>Dubai Building Code|', '', '<h4>Contents|', '', '<p>ii|', '', '<h11>Part A|', '<h11>Part F| Part G| Part H| Part K|', '<h11>Part B| Part C| Part E| Part D|', '<h11>General|', '<h11>Structure|', '<h11>Architecture|', '<h11>Incoming utilities|', '<h11>Accessibility|', '<h11>Indoor environment|', '<h11>Vertical transportation|', '<h11>Part J|', '<h11>Security|', '<h11>Building envelope|', '<h11>Villas|', '', '<p>Dubai Building Code|', '', '<h6>Part A|', '<h3>General|', '', '<p>A 1|', '', '<h11>A.1 | Introduction|', '<h11>A.2\t| Definitions|', '<h11>A.3 | References|', '<h11>A.4 | Relationship of DBC to other local and  || international regulations|', '<h11>A.5 | Scope and application of the DBC|', '<h11>A.6 | Navigating the DBC|', '<h11>A.7 | Adoption of DBC|', '<h11>A.8 | Alternative solutions|', '<h11>A.9 | Maintenance of DBC|', '<h11>A.10 | Copyright|', '<h11>A.11 | Coordinate system|', '<h11>A.12 | Dimensions, units and calculations|', '', '<p>Dubai Building Code| Part A: General|', '<p>A 2|', '', '<h4>A.1 | Introduction|', '', '<p>The objective of the Dubai Building Code (DBC) is to unify building design across | Dubai, and to create a building code that is easy to use and clearly mandates the | minimum requirements for:|', '<p>a) the health, safety, welfare and convenience of people in and around buildings; |', '<p>b) the health, safety, welfare and convenience of people who might be affected by | buildings; |', '<p>c) building design to reduce the impact on the surrounding environment; and|', '<p>d) the sustainable development of buildings.|', '<p>The content of the DBC is based on the following inputs:|', '<p>1) existing regulations and technical requirements produced by the various | Authorities and Service Providers;|', '<p>2) interviews with Government Authorities, Service Providers, Master Developers, | Consultants and other stakeholders to understand gaps or inconsistencies | between existing regulations;|', '<p>3) benchmarking to international and regional codes.|', '<p>The DBC is arranged under themes to integrate all relevant elements of building | design. |', '<p>The regulations stipulated in the DBC are the minimum requirements for building | design. Nothing in the DBC prevents a building design that achieves higher standards | than the minimum set out in the DBC.|', '<p>Dubai Building Code| Part A: General|', '<p>A 3|', '', '<h4>A.2 | Definitions|', '', '<h14>A.2.1 | Terms|', '', '<p>Addition:  Increase to a building’s gross area or built-up | area, and/or height or depth.|', '<p>Architect:  Physical or legal person in charge of | designing or supervising building works, or both, and | licensed to practise the architecture profession in | Dubai in accordance with the applicable legislation. |', '<p>Authority:  Any ministry, department, entity, or | federal or local government institution in Dubai or | any department in licensing Authorities related to the | implementation and the provisions of the DBC. |', '<p>Building lifecycle:  Series of stages through which a | building passes during its lifetime, from initial design, | through construction, commissioning, handover, | and\toperation,\tto\tfinal\tdemolition\tand\trecycling\tof\t| demolished materials/systems.|', '<p>Built-up area:  Total constructed area in a building or | structure measured from the external walls of the | building, inclusive of balconies, terraces and other | projections, as well as any other covered spaces such | as covered parking structures, circulation corridors, | loading/unloading\tbays,\tbasements,\tservice\tfloors,\t| indoor swimming pools and any other permanent | structures on the plot.|', '<p>Building:  Structure for the use or occupancy of people | or for shelter.|', '<p>Change of use:  Alteration to the use of a building to | accommodate an alternative occupancy to that which it | was originally designed.|', '<p>Civil Engineer:  Physical or legal person in charge  ...

# %%
type(headers_para(doc, size_tag))
# Out:
# list

# %%
list1 = headers_para(doc, size_tag)

# %%
subheadings = []
subheadings = [i for i in list1 if i.startswith('<p>')]

# %%
subheadings
# Out:
# ['<p>Dubai Building Code|',
#  '<p>ii|',
#  '<p>Dubai Building Code|',
#  '<p>A 1|',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 2|',
#  '<p>The objective of the Dubai Building Code (DBC) is to unify building design across | Dubai, and to create a building code that is easy to use and clearly mandates the | minimum requirements for:|',
#  '<p>a) the health, safety, welfare and convenience of people in and around buildings; |',
#  '<p>b) the health, safety, welfare and convenience of people who might be affected by | buildings; |',
#  '<p>c) building design to reduce the impact on the surrounding environment; and|',
#  '<p>d) the sustainable development of buildings.|',
#  '<p>The content of the DBC is based on the following inputs:|',
#  '<p>1) existing regulations and technical requirements produced by the various | Authorities and Service Providers;|',
#  '<p>2) interviews with Government Authorities, Service Providers, Master Developers, | Consultants and other stakeholders to understand gaps or inconsistencies | between existing regulations;|',
#  '<p>3) benchmarking to international and regional codes.|',
#  '<p>The DBC is arranged under themes to integrate all relevant elements of building | design. |',
#  '<p>The regulations stipulated in the DBC are the minimum requirements for building | design. Nothing in the DBC prevents a building design that achieves higher standards | than the minimum set out in the DBC.|',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 3|',
#  '<p>Addition:  Increase to a building’s gross area or built-up | area, and/or height or depth.|',
#  '<p>Architect:  Physical or legal person in charge of | designing or supervising building works, or both, and | licensed to practise the architecture profession in | Dubai in accordance with the applicable legislation. |',
#  '<p>Authority:  Any ministry, department, entity, or | federal or local government institution in Dubai or | any department in licensing Authorities related to the | implementation and the provisions of the DBC. |',
#  '<p>Building lifecycle:  Series of stages through which a | building passes during its lifetime, from initial design, | through construction, commissioning, handover, | and\toperation,\tto\tfinal\tdemolition\tand\trecycling\tof\t| demolished materials/systems.|',
#  '<p>Built-up area:  Total constructed area in a building or | structure measured from the external walls of the | building, inclusive of balconies, terraces and other | projections, as well as any other covered spaces such | as covered parking structures, circulation corridors, | loading/unloading\tbays,\tbasements,\tservice\tfloors,\t| indoor swimming pools and any other permanent | structures on the plot.|',
#  '<p>Building:  Structure for the use or occupancy of people | or for shelter.|',
#  '<p>Change of use:  Alteration to the use of a building to | accommodate an alternative occupancy to that which it | was originally designed.|',
#  '<p>Civil Engineer:  Physical or legal person in charge | of designing or supervising civil engineering works, | or both, and licensed to practise the engineering | profession in Dubai in accordance with the applicable | legislation.|',
#  '<p>Consultant:  Physical or legal person in charge | of providing consulting advice during design or | construction, or both and licensed to practise | consulting in Dubai in accordance with the applicable | legislation.|',
#  '<p>Contractor:  Physical or legal person in charge of | carrying out construction works and licensed to | practise contracting activities in Dubai in accordance | with the applicable legislation. |',
#  '<p>Developer:  Person or entity who prepares land for | building sites, constructs buildings, creates residential | subdivisions or private enterprises, and rehabilitates | existing buildings.|',
#  '<p>Development:  General term for the construction, | erection or placing of a building or structure; the | making of an addition or alteration to a building or | structure;\ta\tsignificant\tchange\tin\tuse\tor\tin\tintensity\tof\t| use of any building or structure. |',
#  '<p>Development control regulations (DCR):  Document | that shows planning regulations (such as height, | land use, area, setbacks, building lines) for the full | development, and each plot in a subdivision plan, as | issued by the relevant planning Authority or master | developer. |',
#  '<p>Engineer:  Physical or legal person in charge of | designing or supervising construction works, or both, | and licensed to practise the engineering profession in | Dubai in accordance with the applicable legislation.|',
#  '<p>Existing building:  Building that is completed, including | commissioning and handover. The DBC applies to | renovation,\tmodification,\treconstruction,\taddition\tto,\tor\t| change of use of an existing building.|',
#  '<p>Floor area ratio (FAR): \tRatio\tof\tgross\tfloor\tarea\t(GFA)\t| to plot area.|',
#  '<p>Gross area (GA): \tFloor\tarea\twithin\tthe\tinside\tperimeter\t| of the exterior walls of a building. The measurement | excludes shafts and courtyards, but includes corridors, | stairways, ramps, closets, base of atria (or similar | voids) and the thickness of interior walls, columns or | other features. |',
#  '<p>NOTE:\tThis\tsection\tgives\tcommon\tdefinitions\tthat\tapply\tthroughout\tthe\tDBC.\tEach\tPart\talso\thas\ta\tsection\tfor\tterms\tspecific\tto\tthat\tPart.|',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 4|',
#  '<p>Gross floor area (GFA):  Measurement used by | Planning\tAuthorities\tin\tDubai\tto\tdefine\tthe\tfloor\tarea\t| ratio\t(FAR),\twhere\tFAR\tis\tthe\tratio\tof\tGFA\tto\tplot\tarea.\t| The\tbuilding\tGFA\tis\tthe\tsum\tof\tthe\tGFA\tof\tall\tfloors,\t| measured to the exterior surface of the external wall | thickness and from the centrelines of the common | walls joining two spaces. The measurement excludes | external wall features such as corniches, brackets, and | façade cladding materials. |',
#  '<p>Habitable space:  Space in a building for living, sleeping | or eating involving occupancy for continuous period of | time. Bathrooms, toilet rooms, closets, halls, storage | or utility spaces and similar areas are not habitable | spaces. |',
#  '<p>Heritage building:  New or existing building in a | heritage area. The heritage department of the | Authority controls the elevation design and façade | treatment of buildings in these areas.|',
#  '<p>Historical building:  Existing building of historical | importance where the original character of the building | is to be retained.|',
#  '<p>Masterplan:  Comprehensive plan to guide the long-| term\tphysical\tdevelopment\tof\ta\tspecific\tarea\tbased\t| on\tidentified\tobjectives,\tstrategies,\tand\ttimelines\t| for implementation. Includes plans for land use, | community facilities and utilities, transportation of | goods and people, and energy use and conservation. | Zoning ordinances and policies are developed for | different areas or zoning districts based on the | masterplan.|',
#  '<p>Modification: \tFit-out\tof\ta\tspace\tor\tunit,\tor\tchange\tto\ta\t| service system or building element.|',
#  '<p>Net area (NA):  Actual occupied area, not including | unoccupied accessory areas such as corridors, | stairways, ramps, toilet rooms, mechanical rooms and | closets. |',
#  '<p>Occupiable space:  Room or enclosed space designed | for human occupancy in which individuals congregate | for amusement, labour, educational or similar purposes.|',
#  '<p>Owner: \tAny\tperson,\tentity,\tfirm\tor\tcorporation\thaving\t| any legal or equitable interest in the property in whose | name the plot or building is registered as Owner, | including persons who have a long-term lease for a | specified\tperiod;\tthe\tMain\tor\tSub-Developer\tin\trelation\t| to unsold lands and buildings.|',
#  '<p>Performance-based design:  Design that follows | prescriptive design requirements, but an aspect(s) | of which is based on an alternative solution that is | equivalent to or better than the prescriptive design | requirements.|',
#  '<p>Plot:  Area of land that is:|',
#  '<p>a) clearly\tdefined\t(by\tlandmarks,\tcoordinates,\tdistinct\t| number, and the lengths of its sides and location);|',
#  '<p>a) intended for construction under any approved plan | or division project, or by any other method; and |',
#  '<p>a) legally authorized to be used for construction or | building as one unit.|',
#  '<p>Plot area:  Total area of a plot between its boundary | lines as measured on a horizontal plane.|',
#  '<p>Prescriptive design:  Design that meets the | requirements entirely.|',
#  '<p>Project:  Construction of a permanent building, or any | other civil work on a leased property including any | modifications\tor\tinstallations\tin\tpre-built\tfacilities.|',
#  '<p>Reconstruction: \tModification\tthat\tis\tnot\tstandalone.\tIt\t| affects adjacent egress routes or systems that are not | part of the reconstructed area, such that a larger part | of the building might need to be closed down or not | occupied for a period of time.|',
#  '<p>Renovation: \tChange\tto\tlinings/finishes\tor\t| strengthening of structure. It does not involve any | reconfiguration\tof\tinternal\tspaces.\t|',
#  '<p>Townhouse:  Multiple villas connected by one or more | walls to a series of similar villas.|',
#  '<p>Villa:  Separate building located on a separate plot | allocated\twith\tall\tits\tfloors\tfor\tthe\tdwelling\tof\tone\t| single family and an independent car parking space in | addition to independent external open space.|',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 5|',
#  '<p>NOTE: This section gives references that apply throughout the DBC. Each Part also | has\ta\tsection\tfor\treferences\tspecific\tto\tthat\tPart.|',
#  '<p>Ref. A.1 \tUAE\tMINISTRY\tOF\tTHE\tINTERIOR\tGENERAL\tCOMMAND\tOF\tCIVIL\t| DEFENCE,\t2018.\tUAE\tFire\tand\tLife\tSafety\tCode\tof\tPractice\t(UAE\tFLSC).\tUnited\tArab\t| Emirates: Ministry of the Interior General Command of Civil Defence.|',
#  '<p>Ref. A.2 \tGOVERNMENT\tOF\tDUBAI,\t2017.\tDubai\tuniversal\tdesign\tcode.\tDubai:\t| Government of Dubai. |',
#  '<p>Ref. A.3 \tDUBAI\tHEALTH\tAUTHORITY,\t2012.\tRegulations\t(various).\tDubai:\tDubai\t| Health\tAuthority.\tAvailable\tat:\t | www.dha.gov.ae/en/HealthRegulation/Pages/FacilityRelated.aspx.|',
#  '<p>Ref. A.4 \tDUBAI\tHEALTH\tAUTHORITY,\t2019.\tDHA\tHealth\tfacility\tguidelines\t–\tPart\tA\t| to\tPart\tF.\tDubai:\tDubai\tHealth\tAuthority.\tAvailable\tat:\t | www.dubaitourism.gov.ae/en/services.|',
#  '<p>Ref. A.5 \tDEPARTMENT\tOF\tTOURISM\tAND\tCOMMERCE\tMARKETING,\t2019.\tDTCM\t| Hotel\tclassification\tcriteria\tfor\thotels,\tguest\thouses\tand\thotel\tapartments.\tDubai:\t| DTCM. Available at:  classification.dubaitourism.ae .|',
#  '<p>Ref. A.6 \tDUBAI\tCIVIL\tAVIATION\tAUTHORITY\tApplication\tfor\ta\tno-objection\t| certificate\tto\tconstruct\ta\tbuilding\t(above\tand\tbelow\t300\tm)\tin\tAviation\tEasement\t| areas. Dubai: DCAA. Available at:  | www.dcaa.gov.ae/services/building-constructions/construct-building .|',
#  '<p>Ref. A.7  GREAT BRITAIN, 2015. The Construction (Design and Management) | Regulations.\tLondon:\tThe\tStationery\tOffice.|',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 6|',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 7|',
#  '<p>The\tDBC\tincorporates,\tunifies\tand\treplaces\tthe\t| regulations related to building design published | by Dubai Municipality (DM), Dubai Development | Authority (DDA), Department of Planning and | Development\t–\tPorts\tCustoms\tand\tFreezone\t| Corporation (Trakhees) and Dubai Silicon Oasis | Authority (DSOA).|',
#  '<p>Regulations related to building design by Dubai | Electricity and Water Authority (DEWA) and Islamic | Affairs and Charitable Activities Department (IACAD) | are incorporated or cross-referenced by the DBC.|',
#  '<p>Regulations related to building design by the Security | Industry Regulatory Agency (SIRA) are summarized | and cross-referenced in  Part J .|',
#  '<p>Federal\tregulations\talso\tremain\tin\tplace.\tThe\tDBC\t| follows\tthe\tFederal\tregulations\tof\tTelecommunications\t| Regulatory Authority (TRA) and the Ministry of | Interior Civil Defence. The TRA regulations are given in | G.11 .\tThe\tUAE\tFire\tand\tLife\tSafety\tCode\t(UAE\tFLSC)\t| [Ref. A.1]  is cross-referenced throughout the DBC.|',
#  '<p>Accessibility requirements of the Dubai Universal | Design Code  [Ref. A.2]  applicable to building design | are incorporated in  Part C  and replace these aspects of | the Dubai Universal Design Code. |',
#  '<p>The\tDubai\tHealth\tAuthority\t(DHA)\tregulations\t | [Ref. A.3 and Ref. A.4] ,\talong\twith\tthe\trelevant\tFederal\t| regulations, shall be followed for the design of all | healthcare facilities. |',
#  '<p>The Department of Tourism and Commerce Marketing | (DTCM) sets out the requirements to achieve star | ratings for hotels, resorts, hotel apartments and | guest houses  [Ref. A.5] . Achieving the minimum | requirements of the DBC does not guarantee a rating | from DTCM. DTCM should be consulted at the earliest | stage of design.|',
#  '<p>The\tKnowledge\tand\tHuman\tDevelopment\tAuthority\t| (KHDA)\tand\tthe\tMinistry\tof\tEducation\tboth\tlicense\t| education facilities, but they do not provide separate | design requirements. Education facilities are approved | by the main Authorities in accordance with the DBC.|',
#  '<p>Roads and Transport Authority (RTA) regulations in | relation to the right of way are referenced by the DBC | as appropriate.|',
#  '<p>Dubai Civil Aviation Authority (DCAA) regulates | maximum\tbuilding\theights\twithin\tthe\tflight\tpath.\t|',
#  '<p>Regulations related to permitting, procedures, | construction and design of non-building elements | such as infrastructure, transportation systems, and | the public realm remain, and can be obtained from, the | relevant Authority. |',
#  '<p>Planning development regulations published by | Developers or Planning Authorities are not replaced | by the DBC. The DBC contains planning regulations | in  Part B , but these shall be followed only where | plot-specific\tplanning\tdevelopment\tregulations\tare\t| unavailable.|',
#  '<p>The DBC relies on international codes and standards, | mainly BS EN and American codes. These codes and | standards shall be used in their latest edition except | where the DBC lists an edition. |',
#  '<p>NOTE:\tAs\tan\texample,\tPart\tF\t(Structures)\tmandates\t| the 2016 edition of ASCE/SEI 7. |',
#  '<p>An edition is mandated in the DBC for one of two | reasons.|',
#  '<p>a) The\tDBC\trefers\tto\tsections,\ttables\tand\tfigures\t| within that version of the international code or | standard and therefore the cross-references might | not apply to later editions. |',
#  '<p>b) The edition has been reviewed for its applicability | to Dubai. |',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 8|',
#  '<p>The hierarchy of the adopted codes and standards is | defined\tas\tfollows.|',
#  '<p>a) The\tDBC\tand\tUAE\tFire\tand\tLife\tSafety\tCode\tof\t| Practice\t(UAE\tFLSC)\t [Ref. A.1]  together form the | main regulations for building design in Dubai. The | UAE\tFLSC\tis\treferenced\tthroughout\tthe\tDBC.\t|',
#  '<p>b) The DBC follows the SIRA regulations for | the design of security. These regulations are | summarized and referenced in  Part J .|',
#  '<p>c) The\tDBC\tfollows\tthe\tFederal\tregulations\tof\tTRA\t| for the design of telecommunications. These | regulations are documented in  G.11 .|',
#  '<p>d) The international codes and standards for design, | material\tand\tproduct\tspecification\tlisted\tunder\tthe\t| heading of “Essential references” in each Part, and | referenced in the relevant sections of each Part, are | also requirements of the DBC. |',
#  '<p>e) Documents\tlisted\tunder\tthe\theading\tof\t“Further\t| reading” in each Part are provided for information | as useful guides to building design. |',
#  '<p>Where\tthere\tis\tconflict\tbetween\tthe\tDBC\tand\treference\t| model codes or standards, the most restrictive/highest | performance requirements shall be met.|',
#  '<p>Where\tthere\tis\ta\tconflict\tbetween\ta\tgeneral\t| requirement\tand\ta\tspecific\trequirement\tof\tthe\tDBC\t| or\tits\treferenced\tcodes/standards\tthen\tthe\tspecific\t| requirement applies.|',
#  '<p>The principle of “safe by design” requires the | Consultant to address the health and safety of all | occupants, Contractors and users of the building.  | This includes Contractors, maintenance staff, | occupants, visitors and demolition teams throughout | the building lifecycle.|',
#  '<p>This process is documented in a risk register where | the Consultant acknowledges the risk, investigates | mitigation measures and provides a design solution | which reduces the risk to a practicable level, while also | taking account of cost, constructability, other project | goals, etc. |',
#  '<p>Safe by design principles are not mandated by the | first\tedition\tof\tthe\tDBC,\tbut\tare\tlikely\tto\tbe\tenforced\t| in future revisions. Consultants should familiarize | themselves with these principles by reference to the | Construction Design and Management Regulations | [Ref. A.7] .|',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 9|',
#  '<p>The DBC applies to new buildings and changes to existing buildings as described in | Table A.1, except where an alternative solution is permitted (see A.8).|',
#  '<p>The DBC applies to the occupancies and use types described in Table A.2.|',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 10|',
#  '<p>The DBC does not apply to:|',
#  '<p>a) infrastructure such as road and rail bridges, tunnels, culverts, metro stations, | hydraulic structures, buried and overhead utilities, power stations, antennas and | masts, wind turbines and nuclear facilities;|',
#  '<p>b) marine structures such as canals, dams, dikes, levies, piers, jetties and wharves;|',
#  '<p>c) oil\tand\tgas\tstructures\tsuch\tas\tpetrochemical\tfacilities,\toil\trefineries,\tliquefied\t| natural gas terminals, oil platforms and tanks;|',
#  '<p>d) structures such as tents, cranes, storage racks, scaffolding, formwork and | falsework;|',
#  '<p>e) structures\tsubject\tto\tspecific\tloading\tconditions\tsuch\tas\tstadia,\tgrandstands,\tsilos\t| and chimneys. |',
#  '<p>The DBC does not apply to historical buildings where the original character of the | building is to be retained. Buildings considered to be historical shall conform to the | guidelines of the relevant Authority as appropriate. |',
#  '<p>Buildings in heritage areas or considered to be heritage buildings shall follow the | DBC. The heritage department of the Authority controls the elevation design and | façade treatment.|',
#  '<p>Villas and townhouses are addressed in  Part K.|',
#  '<p>A.5.2.1 | Gross floor area (GFA)|',
#  '<p>Gross\tfloor\tarea\t(GFA)\tis\tused\tby\tPlanning\tAuthorities\tin\tDubai\tto\tdefine\tthe\tfloor\t| area\tratio\t(FAR),\twhere\tFAR\tis\tthe\tratio\tof\tGFA\tto\tplot\tarea.\tThe\tbuilding\tGFA\tis\tthe\t| sum\tof\tthe\tGFA\tof\tall\tfloors,\tmeasured\tto\tthe\texterior\tsurface\tof\tthe\texternal\twall\t| thickness and from the centrelines of the common walls joining two spaces. The | measurement excludes external wall features such as corniches, brackets, and façade | cladding materials. |',
#  '<p>GFA\tis\tcalculated\tbased\ton\tTable\tA.3.\t\t|',
#  '<p>GFA\tmight\tbe\tin\tdevelopment\tcontrol\tregulations\t(DCR).\tConsultants\tshall\tcalculate\t| GFA\tusing\tthe\tDBC\tdefinition\tand\tTable\tA.1\tunless\tGFA\tis\tstated\tin\tthe\tDCR.|',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 11|',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 12|',
#  '<p>A.5.2.2 | Built-up area |',
#  '<p>Built-up area is used also by Planning Authorities. It | is\tdefined\tas\tthe\ttotal\tconstructed\tarea\tin\ta\tbuilding\t| or structure measured from the external walls of the | building, inclusive of balconies, terraces and other | projections as well as any other covered spaces such | as covered parking structures, circulation corridors, | loading/unloading\tbays,\tbasements,\tservice\tfloors,\t| indoor swimming pools and any other permanent | structures on the plot. Calculation of total built-up area | shall exclude the following: |',
#  '<p>a) shafts, courtyards and yards including mechanical, | electrical and plumbing (MEP) shafts, refuse chutes | and similar; |',
#  '<p>b) non-covered outdoor landscape and hardscape | surfaces and courtyards; |',
#  '<p>c) lightweight outdoor shading structures such as | pergolas and standalone canopies.|',
#  '<p>An example calculation using a sample plan is shown in | Figure\tA.1.|',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 13|',
#  '<p>A.5.2.3 | Gross area and net area|',
#  '<p>The terms “gross area” (GA) and “net area” (NA) are | used\tby\tthe\tDBC\tto\tcalculate\toccupant\tload\tin\ta\tfloor\t| or\tspace.\tThey\tare\tdefined\tin\tA.2\tand\tfurther\tdescribed\t| and illustrated in  Part B . |',
#  '<p>A.5.2.4 | Building height|',
#  '<p>Building height is a key variable that is checked by | the Authorities for compliance with the DBC, DCR/| affection\tplans,\tUAE\tFLSC\t [Ref. A.1]  and, where | applicable, DCAA restrictions on building heights | located in Aviation easement areas due to overhead | flight\tpaths.\t|',
#  '<p>Each\tdefinition\tof\tbuilding\theight\tis\tslightly\tdifferent\t| as\tthey\tare\tused\tto\tregulate\tdifferent\tissues.\tFor\tthis\t| reason, Consultants shall check building height against | the\tDBC,\tDCR/affection\tplans,\tUAE\tFLSC\t [Ref. A.1]| and, where applicable, DCAA regulations  [Ref. A.6] .|',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 14|',
#  '<p>The\tDBC\tis\tdivided\tinto\tParts\tas\tdescribed\tin\tFigure\tA.2.\t| Each Part is subdivided into sections by topic.|',
#  '<p>Minimum requirements for sustainability are embedded | within the relevant Parts of the DBC. Developers and | Consultants are encouraged to apply the rating system | adopted by the relevant Authority to assess their | projects and exceed these minimum requirements. |',
#  '<p>Fire\tsafety\trequirements\tare\tgiven\tin\tthe\trelevant\t| Parts\tof\tthe\tDBC\tand\tcross\treferenced\tto\tUAE\tFLSC\t| [Ref. A.1] . The aim of this cross-referencing is to help | Consultants navigate and coordinate the requirements | of\tthe\ttwo\tdocuments.\tWhere\tan\telement\tof\tUAE\tFLSC\t| is not applicable in Dubai, or the DBC contains additional | information\tnot\tin\tUAE\tFLSC,\tthis\tis\tindicated\tin\tthe\t| text.|',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 15|',
#  '<p>The overarching objectives of the DBC, its intention | and regulatory scope, are set out in A.1. |',
#  '<p>Each Part of the DBC starts with a set of performance | statements. These set out the broad outcomes that | the completed building is expected to achieve, and | are provided to explain the intent of the prescriptive | design requirements within the Part. If the prescriptive | design requirements of the Part are followed, then the | performance statements of the Part are deemed to be | met and will be accepted by the Authority.|',
#  '<p>Each Part has a section for essential references and | further reading. The requirements of the DBC and | the essential references form the prescriptive design | requirements of the DBC and will be enforced by the | Authority. Websites and webpages shall be checked | regularly for updates.|',
#  '<p>NOTE: Where websites and webpages have been cited | throughout the DBC, they are provided for ease of | reference and are correct at the time of publication. | Changes to the location of a webpage or website, or its | contents, cannot be guaranteed.|',
#  '<p>In\taddition\tto\tthe\tcommon\tdefinitions\tin\tA.2,\teach\tPart\t| has\ta\tsection\tfor\tdefinitions.|',
#  '<p>Any annex material is included at the end of the Part | to which it relates. Annex material contains further | explanatory material.|',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 16|',
#  '<p>Projects\tin\tdesign\tor\tconstruction\tthat\thave\ta\tfinal\t| approved design from the Authority do not need to | conform to the DBC.|',
#  '<p>Projects\tin\tdesign\twithout\ta\tfinal\tapproved\tdesign\tshall\t| conform to the DBC. The requirements of the DBC are | based on regulations enforced prior to its publication | and\tin\tmany\tinstances\tthe\tDBC\tis\tless\tstringent.\tFor\t| example, requirements unrelated to health, safety, | welfare and environment have generally been removed | from the regulations. Therefore, it is expected that | there\twill\tbe\tbenefits\tto\tDevelopers\tand\tOwners\tin\t| adopting the DBC.|',
#  '<p>The DBC is intended to be a prescriptive design code. | Performance statements are provided at the start of | each Part to describe the outcomes that the completed | building is expected to achieve. |',
#  '<p>The performance statements form a set of overarching | regulations that convey the requirements of the  | DBC (see A.6.2). |',
#  '<p>The preferred method of meeting the performance | statements of the DBC is to follow the prescriptive | design requirements in each Part. |',
#  '<p>The inclusion of performance statements sets out the | intent of the DBC and future-proofs it, supporting | a possible transition to a more performance-based | regulatory system in the future.|',
#  '<p>Alternative solutions which meet the performance | statements of the DBC are permitted:|',
#  '<p>a) for projects that cannot reasonably meet the | prescribed requirements; and|',
#  '<p>b) for changes to existing buildings where the | requirements of the DBC would result in a | disproportionate cost to the Owner/Developer.|',
#  '<p>The Authority will decide if an alternative solution is | permitted. |',
#  '<p>An alternative solution shall meet the intent of | the performance statements and provide at least | an equivalent level of performance to all of the | prescriptive design requirements. |',
#  '<p>Alternative solutions shall be applied to a performance-| based design holistically such that a change from | one Part of the DBC does not reduce the building’s | performance in other aspects.|',
#  '<p>Alternative solutions for changes to existing buildings | shall demonstrate that the existing conditions are | maintained to the current level of compliance or | improved to meet the safety levels of the DBC and  | UAE\tFLSC\t [Ref. A.1] . |',
#  '<p>The Authority will decide whether or not a | performance-based design is equivalent to the | prescriptive design requirements. The responsibility | is on the Consultant to demonstrate that the | performance-based design is required and that | it is at least equivalent to the prescriptive design | requirements.|',
#  '<p>The DBC lists preferred international codes and | standards in each Part (see A.4.2). Where permitted | by the Authority, alternative standards can be used | provided that the comparable standard meets the | intent of the DBC. |',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 17|',
#  '<p>The DBC is an interactive document available | electronically. |',
#  '<p>The DBC will typically be maintained and updated on a | two- to three-year cycle. If necessary, addendums will | be issued between cycles. It is therefore important that | Consultants, Contractors and Engineers check back | regularly to ensure that they are following the latest | version of the DBC. |',
#  '<p>This\tedition\tis\tthe\tfirst\tedition\tof\tthe\tDBC.|',
#  '<p>Amended content in future editions will be clearly | indicated.\tFor\texample,\tnew\tcontent\twill\tbe\tside\tlined\tin\t| the\tfirst\tedition\tin\twhich\tit\tis\tpublished.|',
#  '<p>No content of the DBC, in part or whole, shall be | copied, printed, sold or reproduced in any format.|',
#  '<p>The coordinate system used by the Authority is Dubai | Local\tTransverse\tMercator\t(DLTM).\tThe\treference\t| point for levelling is Port Rashid.|',
#  '<p>Dubai Building Code| Part A: General|',
#  '<p>A 18|',
#  '<p>All\tdimensions\tin\tthe\tfigures\tand\tdiagrams\tof\tthe\t| DBC are given in millimetres without units, unless the | distance exceeds 1,000 mm, and then it is given in | metres with units (m). Dimensions that are not stated | as “maximum” or “minimum” are absolute.|',
#  '<p>All dimensions are subject to conventional industry | tolerances, except where the requirement is stated as a | range\twith\tspecific\tminimum\tand\tmaximum\tend\tpoints.|',
#  '<p>All quantities shall be in metric units with the units | defined.|',
#  '<p>All engineering shall be performed in dynamically | consistent units. One of the two systems shown in | Table A.4 should be used. Use of dimensions between | analysis models, drawings and/or building information | modelling (BIM) models shall be fully coordinated and | consistent.|',
#  '<p>Where the required number of elements (e.g. parking | or sanitary provisions) to be provided is determined by | calculations of ratios or percentages, and this results in | remainders or fractions, the next greater whole number | of such elements shall be provided.|',
#  '<p>Dubai Building Code|',
#  '<p>B 1|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 2|',
#  '<p>Performance statement| The performance statement will be met | by following the requirements of:|',
#  '<p>The building shall be appropriately | integrated with the surrounding natural | and built environment.|',
#  '<p>B.4, B.9 and B.10|',
#  '<p>The building shall facilitate the safety, | convenience and welfare of building | occupants as they move in and around | the building, including access and | egress. |',
#  '<p>B.4, B.5, B.6, B.9 and B.11|',
#  '<p>The building shall provide appropriate | access and safe circulation for vehicles | within the site and building.|',
#  '<p>B.7 and B.9|',
#  '<p>The building shall provide minimum | communal provisions and facilities for | the welfare of occupants. |',
#  '<p>B.8 and B.9|',
#  '<p>The building shall be provided with | adequate and accessible solid waste and | recycling storage to safeguard people | from injury or illness caused by infection | or contamination.|',
#  '<p>B.8.5 and B.9|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 3|',
#  '<p>Accessibility:  Ease of independent approach, entry, | evacuation and/or use of a building and its services | and facilities by all of the building’s potential users, | regardless of disability, age or gender, and with an | assurance of individual health, safety and welfare.|',
#  '<p>Accessible:  Site, building, facility or portion thereof | that conforms to  Part C .|',
#  '<p>Advertising: \tAny\tidentification\tor\tdescription\tor\t| drawing\tor\tany\tother\tmeans\tto\tbe\tfitted\tor\terected\tor\t| printed or written or drawn, either directly or indirectly, | or any building or structure or plot, whose purpose is | to draw attention to any business, product, service, etc.|',
#  '<p>Affection plan:  Plan of the plot or site issued by the | Authority, showing information that includes (but is | not limited to) the plot boundaries, plot dimensions, | plot areas, setbacks and surroundings as well as the | land uses. Also called site plan.|',
#  '<p>Amenity space:  Public or private area within the | boundaries of a plot or a development site for the | building occupant’s recreation or convenience (such as | landscaped areas, patios, swimming pools, play areas, | prayer rooms, exercise areas and similar uses).|',
#  '<p>Annex:  Building or installation, attached to or | independent from the main building, the use of which | is secondary or complementary to the function of the | main building.|',
#  '<p>Arcade:  Roofed corridor that leads to any building, | faces a street or open courtyard, or links more than | one building. Usually formed through a series of arches | supported\ton\tcolumns\tor\tpiers\t(see\tFigure\tB.1).|',
#  '<p>Authorized use:  Plot use or building occupancy | authorized\taccording\tto\tthe\tclassification\tof\tlands\t| in\tDubai\tnoted\tin\tthe\tofficial\taffection\tplan\tor\t| development regulation.|',
#  "<p>Balcony:  Covered or uncovered occupied projection or | partial projection outside the external walls, attached | to the building and accessed from the building's | interior\tspaces\t(see\tFigure\tB.2).|",
#  '<p>Assembly:  Occupancy\tclassification\tassociated\twith\t| the gathering of people for deliberation, worship, | entertainment, eating, drinking, amusement, awaiting | transportation, or similar uses.|',
#  '<p>Atrium:  Large-volume\tspace\tcreated\tby\ta\tfloor\topening\t| or\tseries\tof\tfloor\topenings,\tconnecting\ttwo\tor\tmore\t| storeys\tor\texceeding\t15\tm\tin\theight\tfrom\tfinished\tfloor.\t| The space is covered at the top of the opening(s) and | used for purposes other than an enclosed stairway, | an elevator hoistway, an escalator opening or a utility | shaft.|',
#  '<p>Basement floor:  Storey of a building wholly or partly | below\tthe\tgate\tlevel\tthat\tis\tnot\tthe\tfirst\tstorey\tabove\t| gate\tlevel.\tA\tbasement\tslab\tsoffit\tlevel\tis\tnot\thigher\t| than 1,200 mm above the building gate level.|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 4|',
#  '<p>Bathroom:  Room containing a water closet, a | washbasin, and either a bathtub, a shower, or both. |',
#  '<p>Bi-separator: \tPiece\tof\tequipment\tfitted\tto\tthe\tend\tof\ta\t| refuse chute which allows the user to deposit multiple | waste streams, such as recycling and residual waste, | into a single refuse chute. |',
#  '<p>Boundary wall/fence:  Free-standing\tstructure\t| constructed from approved materials surrounding a | plot, resting on the ground and rising above ground | level\tand\tused\tfor\tconfinement\tand/or\tscreening\tfor\t| safety or security or division purposes.|',
#  '<p>Building:  Structure for the use or occupancy of people | or for shelter.|',
#  '<p>Building element:  Component of a building, which | might\tor\tmight\tnot\tbe\tof\tfire\tresistance\trated\t| construction and is constructed of approved materials. |',
#  '<p>Building envelope:  Physical barrier between the | exterior and the conditioned environment of a building | to resist air, water, moisture, heat, cold, light, and noise | transfer.\tFor\tan\tair-conditioned\tbuilding,\tthe\tbuilding\t| envelope comprises the elements of a building that | separate conditioned spaces from the exterior. Crown | extensions to the façade to cover plant screen cladding | are part of the building envelope. The building envelope | does not include the physical barrier below ground.|',
#  '<p>Building height, total:  Vertical distance measured from | the approved road edge level at the plot main access to | the highest roof surface or element.|',
#  '<p>Building height:  Vertical distance measured from the | approved road edge level at the plot main access to the | mean\tfinished\tlevel\tof\tthe\tbuilding\troof.\t|',
#  '<p>Building occupants:  Persons using the building. |',
#  '<p>Building projection:  Projection or protrusion that | extends\toutside\tthe\tvertical\texternal\twall\tof\tthe\tfloor\t| below, such as balconies.|',
#  '<p>Building setback: \tHorizontal\tdistance\tbetween\tthe\t| nearest part of any building or structure on the plot | above ground and the plot boundary, measured | perpendicular to the plot boundary.|',
#  '<p>Built environment:  External and internal environments | and\tany\telement,\tcomponent\tor\tfitting\tthat\tis\t| commissioned, designed, constructed and managed for | use by people.|',
#  '<p>Bulky waste:  Waste, such as furniture, which is usually | too large for regular waste collections.|',
#  '<p>Business:  Occupancy used for the transaction of | business\tother\tthan\tretail,\tusually\tused\tfor\toffice,\t| professional or service-type transactions, including | storage of records and accounts.|',
#  '<p>Canopy:  Building projection that provides weather | protection, identity or decoration and is partially | or wholly supported by the building to which it is | attached. |',
#  '<p>Carpool vehicle:  Shared vehicle used by people who | each have a car but travel together to save cost, to | reduce driving stress and to promote other socio | environmental\tbenefits.|',
#  '<p>Chimney:  Primarily vertical structure containing one | or\tmore\tflues,\tfor\tthe\tpurpose\tof\tcarrying\tgaseous\t| products of combustion and air from a fuel-burning | appliance to the outdoor atmosphere.|',
#  '<p>Chute:  Vertical shaft or sloping channel provided for | building utilities and services. |',
#  '<p>Circulation:  Means of passage for pedestrians in and | around the built environment, including (but not | limited to) corridors, hallways, courtyards, stairways | and stair landings.|',
#  '<p>Clear width:  Free\tunobstructed\tspace\tfor\taccess.|',
#  '<p>Clinic:  Buildings (or portions thereof) used to provide | medical care on less than a 24 h basis. |',
#  '<p>Corridor:  Enclosed\tcomponent\tthat\tdefines\tand\t| provides a path of travel.|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 5|',
#  '<p>Courtyard:  Open, uncovered space, unobstructed to | the sky, bounded on three or more sides by exterior | building walls or other enclosing devices as shown in | Figure\tB.3.|',
#  '<p>Curb:  Raised\tedge\ton\ta\troadway,\tconcrete\tfloor\tslab\t | or around roof plant.|',
#  '<p>Daylighting:  Illumination of interior spaces using | natural light.|',
#  '<p>Department store:  Store, exhibition, building, or part | of a building used for the retail sale of a broad variety | of items.|',
#  '<p>Designated preferred parking spaces:  Parking spaces | that are closest to the main entrance of a building, | excluding accessible spaces, or parking spaces closest | to the pedestrian exit from the parking area.|',
#  '<p>Entrance:  Access point to a building, portion of a | building or facility. An entrance includes the approach | walk, the vertical access leading to the entrance | platform, the entrance platform itself and the entry | door(s) or gate(s).|',
#  '<p>Environmental impact assessment (EIA):  Process  | of predicting, identifying and evaluating the likely | impacts\t(initial\tand\tcumulative),\tboth\tbeneficial\tand\t| adverse, of a project on the environment including the | potential effects of the environment on the project.|',
#  '<p>Exhibition:  Space or structure used for the display  | of products or services.|',
#  '<p>Exit access:  Portion of a means of egress that leads to | an exit.|',
#  '<p>Exit discharge:  Portion of a means of egress between | the termination of an exit and a public way.|',
#  '<p>Exit passageway:  Exit component that is separated | from\tother\tspaces\tof\ta\tbuilding\tor\tstructure\tby\tfire\t| resistance rated construction and opening protectives, | providing a protected path of egress travel in a | horizontal direction to exit discharge or public way | or outside building. Additional uses for the exit | passageway\tinclude\tstair\ttransfer\tin\tupper\tfloors\t | as well as to reduce travel distance to an exit by having | an exit passageway lead to a stair of exit discharge. |',
#  '<p>Development:  General term for the construction, | erection or placing of a building or structure; the | making of an addition or alteration to a building or | structure;\ta\tsignificant\tchange\tin\tuse\tor\tin\tintensity\tof\t| use of any building or structure. |',
#  '<p>Development control regulations (DCR):  Document | that shows planning regulations (such as height, | land use, area, setbacks, building lines) for the full | development, and each plot in a subdivision plan, as | issued by the relevant planning Authority or  | master Developer.|',
#  '<p>Door:  Combination of a door leaf or leaves, frame, | hardware, and other accessories, positioned in an | opening in a wall and intended primarily for access  | and egress.|',
#  '<p>Driveway:  Access to a required off-street parking  | and loading facility area.|',
#  '<p>Education:  Occupancy used for educational purposes, | including training centres and universities. |',
#  '<p>Element:  Component or space of a building,  | facility or site.|',
#  '<p>Elevator lobby: \tLanding\tfrom\twhich\toccupants\tdirectly\t| enter an elevator car(s) and into which occupants | directly enter upon leaving an elevator car(s).|',
#  '<p>Enclosed parking:  Parking occupancy that is partially | or wholly enclosed on all sides, and that does not | qualify as open parking.|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 6|',
#  '<p>Exterior stairway:  Stairway that is open on at least one | side, except for required structural columns, beams, | handrails and guardrails. The adjoining open area can | be either yards, courtyards or public ways.  | The other sides of the exterior stairway can be closed.|',
#  '<p>External wall:  Wall, load bearing or non-load bearing, | that is used as an enclosing wall for a building and | might form part of the building envelope.|',
#  '<p>Facility:  All or any portion of the buildings, structures, | site improvements, equipment, roads, walks, | passageways, parking lots or other property located  | at the site.|',
#  '<p>Feeding room or lactation room:  Private space where a | nursing mother can nurse a child or lactate.|',
#  '<p>Fixed seating: \tFurniture\tor\tfixture\tdesigned\tand\t| installed for the use of sitting, and secured in place. | Includes bench-type seats and seats with or without | backs or arm rests.|',
#  '<p>Flight:  Continuous run of stair treads from one landing | to another.|',
#  '<p>Flood or flooding:  General and temporary condition | of partial or complete inundation of normally dry land | from:|',
#  '<p>a) the\toverflow\tof\tinland\tor\ttidal\twaters;|',
#  '<p>b) the unusual and rapid accumulation or runoff  | of surface waters from any source.|',
#  '<p>Floor finish: \tExposed\tfloor\tsurfaces\tof\tbuildings\t| including\tcoverings\tapplied\tover\ta\tfloor\tor\tstair,\t| including risers.|',
#  '<p>Floor height:  Vertical distance from top to top of two | successive\tfinished\tfloor\tsurfaces.\tFor\tthe\ttopmost\t| storey,\tfrom\tthe\ttop\tof\tthe\tfloor\tfinish\tto\tthe\ttop\tof\tthe\t| ceiling joists or, where there is no ceiling, to the top of | the roof surface.|',
#  '<p>Floor or storey:  Portion of a building located between | the\tupper\tsurface\tof\ta\tfloor\tand\tthe\tupper\tsurface\tof\t| the\tfloor\tor\troof\tnext\tabove.|',
#  '<p>Fuel dispensing facilities: \tFacility\twhere\tmotor\tfuels\t| are\tstored\tand\tdispensed\tfrom\tfixed\tequipment\tinto\t| the fuel tanks of motor vehicles or marine craft or into | approved containers, including all equipment used in | connection therewith.|',
#  '<p>Gate level:  \tDefined\theight\ton\tthe\tplot\tboundary\tat\tthe\t| vehicular or pedestrian access point to the plot. It is an | elevation difference between the road level (existing or | future) and the level of the plot’s access point.|',
#  '<p>The gate level of a plot shall be a minimum height | of +300 mm from the edge of the road or a slope of | between\t2-5%\tfrom\tthe\tedge\tof\tthe\troad\tto\tthe\tplot’s\t| access point.|',
#  '<p>Glazed element:  Individual element within a building | envelope that lets in light, including windows, plastic | panels, clerestories, skylights, doors that are more than | one half glass, and glass block walls.|',
#  '<p>Glazing:  Glass that is installed as one of the | components\tof\ta\twall,\tfloor,\tceiling\tor\troofing\tsystem.|',
#  '<p>Gross area (GA): \tFloor\tarea\twithin\tthe\tinside\tperimeter\t| of the exterior walls of a building. The measurement | excludes shafts and courtyards, but includes corridors, | stairways, ramps, closets, base of atria (or similar | voids) and the thickness of interior walls, columns or | other features. |',
#  '<p>Ground floor: \tFirst\tfloor\tin\tthe\tbuilding\tabove\tthe\tgate\t| level. |',
#  '<p>Guard room:  Room, unit, or residential space on the | same plot of land as the main building, or located | within the main building, designated for the occupancy | of the guard.|',
#  '<p>Guardrail:  Vertical protective barrier erected along | elevated walking surfaces, exposed edges of stairways, | balconies and similar areas that minimizes the | possibility of fall from elevated surfaces to lower level.|',
#  '<p>Habitable space:  Space in a building for living, sleeping | or eating involving occupancy for continuous period of | time. Bathrooms, toilet rooms, closets, halls, storage | or utility spaces and similar areas are not habitable | spaces.|',
#  '<p>Handrail: \tHorizontal\tor\tsloping\trail\tintended\tfor\t| handhold and grasping by hand for guidance or | support\t(see\tFigure\tB.4).|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 7|',
#  '<p>Hardscape:  Area of a project site, excluding buildings, | made with hard materials, including roads, car parks, | patios, courtyards and walkways.|',
#  '<p>Hazardous waste:  Waste material that can cause | substantial harm to humans, properties and/| or the environment due to its inherent hazardous | characteristics.\tHazardous\twaste\ttakes\tthe\tform\tof\t| solid, liquid, sludge, gas or any combination thereof. |',
#  '<p>Healthcare:  Occupancy used to provide medical, | psychiatric, surgical, therapeutic treatment for people.|',
#  '<p>Helipad:  Dedicated structural surface used for the | landing, taking off, taxiing and parking of helicopters.|',
#  '<p>High-rise building:  Building height greater than or | equal to 23 m and up to 90 m, measured in accordance | with\tthe\tUAE\tFLSC\t [Ref. B.1] . A more detailed | definition\tis\tgiven\tin\tUAE\tFLSC.|',
#  '<p>Hospital:  Building or portion thereof used on a 24 h | basis for the medical, psychiatric, obstetrical or surgical | care of four or more inpatients.|',
#  '<p>Hotel:  Building or groups of buildings under the | same management in which there are sleeping | accommodations for lodging with or without meals for | people on a transient basis.|',
#  '<p>Hotel apartments:  Collection of apartments or studios | that are rented to guests by the day, the week, the | month or the year.|',
#  '<p>Hotel establishment: \tHotels,\tguest\thouses,\thotel\t| apartments or resorts.|',
#  '<p>Hotel suite:  Separate guest unit in a hotel that | contains one or more bedrooms with a living room and | other services.|',
#  '<p>Housekeeper’s room:  Attached or separate room or | unit on the same plot of land as the main building, | designated for the residence of housekeepers or other | maintenance staff such as gardeners, guards and | drivers. |',
#  '<p>Hybrid vehicle:  Vehicle using two different forms | of power, such as an electric motor and an internal | combustion engine, or an electric motor with a battery | and fuel cells for energy storage.|',
#  '<p>Illuminance:  Amount of light falling onto a surface area.|',
#  '<p>Industrial/factory/workshop:  Occupancy in which | products are manufactured or in which processing, | assembling,\tmixing,\tpackaging,\tfinishing,\tdecorating,\tor\t| repair operations are conducted.|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 8|',
#  '<p>Intersection:  Crossing of two or more roads.|',
#  '<p>Kiosk:  Temporary or permanent structure of | lightweight construction occupied as a retail outlet, | food\toutlet\tor\tservice\toutlet.\tKiosks\tare\tgenerally\t| located at malls, shopping centres, assembly areas and | exhibition centres.|',
#  '<p>Kitchen:  Place for the preparation of meals and | beverages. |',
#  '<p>Labour accommodation:  Building used for group | accommodation\tfor\tworkers\tof\ta\tcompany\tor\ta\tfirm,\t| for which the sanitary facilities and other services are | common.|',
#  '<p>Landing:  Floor\tarea\tat\tthe\ttop\tof\ta\tflight\tof\tstairs\tor\t| between\ttwo\tflights\tof\tstairs,\tor\ta\tplatform\tor\tpart\tof\ta\t| floor\tstructure\tat\tthe\tend\tof\ta\tramp\tor\tat\tthe\tentrance\t| to an elevator car.|',
#  '<p>Land use:  Activities, operations, or purposes that are | employed\tin\ta\tparticular\tgeographic\tarea;\tthe\tspecific\t| manner\tin\twhich\ta\tplot\tof\tland\tis\tutilized.\tLand\tuse\t| is usually regulated through zoning and planning | regulations.|',
# ...
#  '<p>b) Buildings shall allow for smooth pedestrian access with crossings and pathways. | Pathways shall be provided for building entries from surrounding streets, parking | bays and external sidewalk. |',
#  '<p>c) Accessible routes shall be provided in accordance with  C.5 .|',
#  '<p>d) Buildings providing pick-up and drop-off areas shall conform to Chapter 7.2  | of Dubai access management manual requirements  [Ref. B.37] . |',
#  '<p>e) For\tmixed-use\tbuildings\tcontaining\tresidential\toccupancy\tand\tother\tpublic\t | or business occupancies, the residential pedestrian access point and lobbies shall | be\tseparated\tfrom\tthose\tserving\tpublic/business\toccupancies.\tFor\tother\tmixed-| use buildings, the segregation of pedestrian access points for different building | occupancies is recommended for privacy and security. |',
#  '<p>f) The number and location of exits discharging directly from the building to outside | shall be in accordance with B.4.3.1. |',
#  '<p>g) Access\troutes\tand\taccessways\tfor\tfire\ttrucks\tshall\tbe\tprovided\tin\taccordance\t| with\tCh.\t2\tof\tUAE\tFLSC\t [Ref. B.1] .\tFire\ttrucks\tshall\tbe\table\tto\treach,\twithin\tthe\t| required distances and as applicable, the building entry points, breeching inlets | and the perimeter façade of the building. |',
#  '<p>h) Public\troadways\tcarrying\theavy\tvolumes\tof\ttraffic\tshall\tnot\tbe\tused\tfor\taccess\t| unless an alternative access point cannot be provided, and it is agreed with RTA | and the Authority. |',
#  '<p>B.7.2.1 | General requirements|',
#  '<p>Vehicle\taccess\tshall\tbe\tlocated\taway\tfrom\tany\ttraffic\tintersections\tdepending\ton\troad\t| type, vehicle type and other factors as approved by RTA.|',
#  '<p>Vehicle access shall conform to RTA requirements. Public rights of way shall be | designed in accordance with the RTA Dubai access management manual  [Ref. B.37]| and RTA Geometric design manual for Dubai roads  [Ref. B.38] .|',
#  '<p>Building developments which are deemed by the Authority to have an impact on the | traffic\tgeneration\tfor\tthe\tsurrounding\troads\tand\tproperties\tshall\tsubmit\ta\ttraffic\t| impact\tassessment\t(TIA)\tor\ttraffic\timpact\tstudy\t(TIS)\tto\tthe\tAuthorities.|',
#  '<p>Vehicle access shall be separated from local road intersection or minor T junctions by | not\tless\tthan\t15\tm\tfrom\tthe\tchamfered\tedge\tof\tthe\tplot\t(see\tFigure\tB.49\tand\t | Figure\tB.50).\t\tFor\tother\troad\tintersections,\tDubai\taccess\tmanagement\tmanual\t| requirements  [Ref. B.37]  shall be followed.|',
#  '<p>If the building is facing more than one road, the vehicle access point should be from | the\tsecondary\troad,\tor\tas\tspecified\ton\tthe\taffection\tplan,\tas\tshown\tin\tFigure\tB.49.|',
#  '<p>Segregation between light and heavy vehicle parking areas inside plots shall  | be provided in accordance with B.7.3.|',
#  '<p>Vehicle\taccess\tshall\tnot\tbe\tlocated\topposite\ta\tT\tjunction,\tas\tshown\tin\tFigure\tB.50.|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 59|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 60|',
#  '<p>Internal roads within plot limits shall be not less than:|',
#  '<p>a) 3\tm\tclear\twidth\troad\tor\tpavement\tfor\tone-way\ttraffic;|',
#  '<p>b) 6\tm\tclear\twidth\troad\tor\tpavement\tfor\ttwo-way\ttraffic.|',
#  '<p>All vehicular roadways and parking areas shall be provided with exterior lighting to | illuminate the surface area in accordance with  H.7 . All internal roads or access to | plots\tshall\tbe\tlit\tto\ta\tCIE\t115\t(lighting\tclass\tM5,\tL',
#  '<p>\t≥\t0.5\tcd/m',
#  '<p> with uniformity  | U',
#  '<p>\t≥\t0.35)\t [Ref. B.39] .\tLighting\tshall\tbe\tdesigned,\tarranged\tand\tinstalled\tto\tconfine\t| direct rays onto the plots and to direct light away from adjacent structures or streets. |',
#  '<p>All parts of the site to which vehicles might have access shall be hard surfaced and | drained.|',
#  '<p>All vehicular manoeuvring to take place within plot limits without impacting ROW|',
#  '<p>B.7.2.2 | Vehicular ramps|',
#  '<p>Ramps allocated for vehicular access shall conform to Table B.9 and the following.|',
#  '<p>a) Curved and helical vehicular ramps are not preferred. |',
#  '<p>b) Any curved portion of vehicular ramps shall conform to the requirements for | curved ramps.|',
#  '<p>c) Lane\tseparation\tfor\tramps\tshall\tbe\tprovided\tthrough\tcurbs,\twalls\tor\tother\t| structural segregation.|',
#  '<p>d) Where\ta\tcurb\tis\tused\tbetween\tlanes\tto\tseparate\ttraffic\tflows,\teach\tlane\tshall\tmeet\t| the minimum width requirement. Curbs shall be not less than 300 mm in width, | and not less than 150 mm in height.|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 61|',
#  '<p>Vehicular ramps shall meet the following requirements. |',
#  '<p>1) Floor\tsurfaces\tshall\tbe\tof\tbroom\tfinish\ttexture\tor\tprovided\twith\tanti-slip\t| treatment. |',
#  '<p>2) Ramps shall be free from any projections or obstacles that could obstruct safe | movement or use.|',
#  '<p>3) Corners of structural elements adjacent to ramps shall be covered with | protective materials.|',
#  '<p>4) Ramps\tshall\tbe\tprovided\twith\treflective\tmirrors\tthat\tare\tappropriately\tsized\t | to enhance visibility at directional changes, turns and in areas where visibility  | is\tdifficult.\t|',
#  '<p>5) Ramps shall be equipped with all necessary connections for rainwater drainage.|',
#  '<p>6) Floor\tsurfaces\tshall\tbe\tnon-combustible,\tgraded\tand\tequipped\twith\tdrainage\t | in\taccordance\twith\tTable\t3.37,\tCh.\t3\tof\tUAE\tFLSC\t [Ref. B.1] .  |',
#  '<p>Vehicular\tramps\tshall\tnot\tbe\tused\tfor\tmeans\tof\tegress,\tas\tspecified\tin\tTable\t3.37,\t | Ch.\t3\tof\tUAE\tFLSC\t [Ref. B.1] ,\twith\tthe\tfollowing\texception.\tFor\tone\tlevel\tbelow\t | or one level above discharge level of parking, vehicular ramps may be used as one of | the means of egress, provided that no shutters or doors are installed in such ramps. |',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 62|',
#  '<p>Ramp design should provide blended transitions to horizontal parking levels.  | The transition should be equal to half the percentage of ramp’s slope, according  | to\tthe\tdimensions\tgiven\tin\tTable\tB.10\tand\tFigure\tB.54.|',
#  '<p>Mechanical parking can substitute for vehicular ramps, provided that following | requirements are met.|',
#  '<p>i) | A TIA shall be submitted.|',
#  '<p>ii) | \tThe\tsystem\tused\tshall\tbe\tprovided\twith\tan\tinspection\tcertificate\tfor\tinstallation\t| and safety in accordance with BS EN 14010:2003+A1:2009.|',
#  '<p>iii) Building occupants shall not be able to access the structure. A suitable and | airconditioned waiting area shall be provided adjacent to the parking exits. |',
#  '<p>iv)  An emergency auto response system shall be provided, to enable continuity  | of\tuse\tand\tavoid\timpact\ton\tROW\tand\ttraffic\tflow\tin\tthe\tevent\tof\tsystem\tfailure.|',
#  '<p>v) | The\tsystem\tshall\tbe\tcapable\tof\toperating\tat\t25%\tminimum\tcapacity\tthrough\t | a standby generator in case of electrical outage. |',
#  '<p>vi) \tThe\tnet\tfloor\theight\tof\tthe\tparking\tlevels\tshall\tmatch\tthe\tsystem\tspecification\t| requirements, and may be less than the minimum clear heights given in B.5.3. |',
#  '<p>vii) The\tmechanical\tparking\tshall\tmeet\tthe\tfire\tsafety\trequirements\tof\t | UAE\tFLSC\t [Ref. B.1] . |',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 63|',
#  '<p>B.7.2.3 | Parking floors and structures|',
#  '<p>B.7.2.3.1  | General|',
#  '<p>Parking areas within a building shall be separated from other occupancies.  | Occupiable spaces adjacent to or within parking areas shall be provided with  | thermal and acoustic treatment. Ventilation separation conforming to  Part H ,  | and\tfire\tseparation\tconforming\tto\tTable\t1.9,\tCh.\t1\tof\tUAE\tFLSC\t [Ref. B.1] , shall be | provided. |',
#  '<p>Parking areas clear height shall conform to B.5.3. |',
#  '<p>Floor\tsurfaces\tshall\tbe\tnon-absorbent,\tnon-combustible,\tgraded\tand\tequipped\t | with\tdrainage\tin\taccordance\twith\tTable\t3.37,\tCh.\t3\tof\tUAE\tFLSC\t [Ref. B.1] .  |',
#  '<p>The\tarea\tof\tfloor\tused\tfor\tparking\tof\tcars\tor\tother\tvehicles\tshall\tbe\tsloped\tto\tfacilitate\t| the movement of liquids to a drain or toward the main vehicle entry doorway. |',
#  '<p>The\tslope\tin\tareas\twhere\tvehicles\tare\tparked\tshall\tbe\tnot\tmore\tthan\t4%\t(as\tshown\t | in\tFigure\tB.55).\tAccessible\tparking\tslopes\tshall\tbe\tlimited\tto\ta\tmaximum\tof\t2%.\t|',
#  '<p>Vehicle guards not less than 1,200 mm in height shall be placed where the vertical | distance\tfrom\tthe\tfloor\tof\ta\tdrive\tlane\tor\tparking\tbay\tto\tthe\tground\tor\tsurface\tdirectly\t| below is greater than 300 mm, such as parking on podiums roof or adjacent to ramps. | The guards shall conform to Clause 4.5.3 of ASCE/SEI 7-16. Mechanical parking | facilities are exempt from this requirement.|',
#  '<p>B.7.2.3.2  | Open versus enclosed parking|',
#  '<p>Open parking has permanent wall openings for natural ventilation at each parking | level. The exterior sides of the structure shall have uniformly distributed openings  | on two or more sides. The area of such openings in external walls on a level shall  | be\tnot\tless\tthan\t20%\tof\tthe\ttotal\tperimeter\twall\tarea\tof\teach\tlevel.\tThe\taggregate\t| length (i.e. total of widths) of the openings deemed to be providing natural | ventilation\tshall\tbe\tnot\tless\tthan\t40%\tof\tthe\tperimeter\tof\tthe\tlevel.\tOpen\tparking\t| facilities\tshall\tconform\tto\tNFPA\t88A\tfor\tnatural\tventilation.\t|',
#  '<p>Parking\tfacilities\tthat\tdo\tnot\tmeet\tthe\tdefinition\tof\topen\tparking\tshall\tbe\tdesigned\t | as enclosed parking with mechanical ventilation as required by  H.4.12.11 .|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 64|',
#  '<p>B.7.2.3.3  | Parking areas technical requirements |',
#  '<p>Parking areas (covered or uncovered) shall be provided for vehicles within  | the plot limits.|',
#  '<p>Parking\tshall\tnot\timpede\tfire\texit\tdoors,\ttheir\taccess\tand\texit\tdischarge\tpath.|',
#  '<p>Wheel stoppers of a maximum height of 120 mm and a minimum width of 200 mm | shall\tbe\tinstalled\tas\tshown\tin\tFigure\tB.56\twhere\tparking\tbays\tare\tadjacent\tto\tfences,\t| walls, buildings or walkways. Wheel stops should be avoided where they might  | be in the path of pedestrians moving to or from parked vehicles.|',
#  '<p>For\tparking\tentry\tand\texit,\ta\tstraight,\tand\tpreferably\tlevel,\t6\tm\tlong\taccess\tshould\tbe\t| provided\tbefore\tvehicle\taccess\tbarriers\tas\tshown\tin\tFigure\tB.57.\tParking\tareas\tshall\t| be\tprovided\twith\tdirectional\tarrows\tand\ttraffic\tsigns,\tas\tdescribed\tin\tB.11.|',
#  '<p>A\tfixed\tmirror\tshall\tbe\tprovided\tfor\tblind\tcorners.|',
#  '<p>No parking area shall be allowed to be utilized as both a parking bay and a loading | space.|',
#  '<p>Basement parking areas shall account for the presence of columns and adjacent | walls, which shall be covered with protective angle guards of suitable material. Round | columns do not require protective angle guards.|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 65|',
#  '<p>Dead-end driveways should be avoided. If they are to be included in design,  | they should serve a maximum of eight spaces with manoeuvring space provided  | (see\tFigure\tB.58).\tTandem\tparking\tmay\tbe\tused\tin\tthe\tfollowing\tsituations:|',
#  '<p>a) residential parking provision of the same residential unit, when the unit requires | two parking bays according to B.7.2.6.1. Tandem parking shall be limited to two | bays. |',
#  '<p>b) hotel facilities, for parking operated solely through a valet parking service.  | Tandem parking shall be limited to three bays.|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 66|',
#  '<p>B.7.2.4 | Car parking bay dimensions|',
#  '<p>The dimension of car parking bays and driveways shall be not less than the minimum | values given in Table B.11.|',
#  '<p>In designing parking spaces, bays bounded by building structural elements or walls | shall have an additional space of 300 mm from the structural element if it interrupts | the opening of vehicle doors or manoeuvring or at the end of the driveway.|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 67|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 68|',
#  '<p>B.7.2.5 | Bus parking bays|',
#  '<p>Bus\tparking\tprovisions\twithin\tplot\tlimits\tshall\tconform\tto\tTable\tB.12,\tFigure\tB.64\t | and\tFigure\tB.65.|',
#  '<p>The parking dimensions and manoeuvring clearances are based on a 12 m long bus.  | A vehicular manoeuvring analysis shall be conducted to determine requirements  | for alternative bus sizes and other parking angles. |',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 69|',
#  '<p>B.7.2.6 | Parking provisions in buildings |',
#  '<p>B.7.2.6.1  | Parking ratios |',
#  '<p>Parking ratios shall be determined in accordance with Table B.13 for the relevant | building occupancy. Parking requirements set out in the affection plan or DCR shall | take precedent over Table B.13.|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 70|',
#  '<p>Parking ratios for any building occupancy not listed in Table B.13 should  | be determined in accordance with RTA parking rates requirements  [Ref. B.40] . |',
#  '<p>When the building includes a mix of occupancies, the parking provided should | conform\tto\tthe\trequirement\tfor\teach\tspecific\toccupancy.|',
#  '<p>Parking for sport stadiums and event arenas shall be determined according  | to a transport study of the type of sport or event, the number of seats, visitors  | and the public parking and transportation network.|',
#  '<p>B.7.2.6.2  | Preferred parking |',
#  '<p>For\tbuildings\tthat\thave\tmore\tthan\t20\tparking\tbays,\tdesignated\tpreferred\tparking\t| shall be provided for a combination of hybrid vehicles, electrical vehicles and carpool | vehicles. |',
#  '<p>The number of preferred parking bays shall be calculated based on the total  | vehicle\tparking\tbays\trequired\tfor\tthe\tbuilding,\tas\tdefined\tin\tB.7.2.6.1.\t|',
#  '<p>The\tpercentage\trequired\tfor\tpreferred\tparking\tis\t5%.\tThis\tpercentage\tdoes\t | not include parking bays provided for people of determination (see  C.6.4 ).|',
#  '<p>B.7.2.6.3  | Charging equipment for electrical vehicles in malls |',
#  '<p>For\tshopping\tmalls,\twhere\tpreferred\tparking\tbays\tare\tprovided\tin\taccordance\twith\t| B.7.2.6.2, necessary charging equipment for electrical vehicles shall be provided for | 20%\tof\tthe\ttotal\tpreferred\tparking\tbays.\tCharging\tequipment\tshall\tconform\tto\t G.5 .|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 71|',
#  '<p>B.7.2.7 | Bicycle parking provision in building |',
#  '<p>Bicycle parking should be located within the building or within a shaded area at | ground\tlevel\t(see\tFigure\tB.66)\tin\teasily\taccessible\tlocations\twithin\tthe\tplot\tlimit\tand\t| no more than 30 m from the building entrance.|',
#  '<p>Parking\tshall\tnot\timpede\tfire\texit\tdoors,\ttheir\taccess\tand\texit\tdischarge\tpath.|',
#  '<p>For\tstudent\taccommodation\tand\tlabour\taccommodation\tbuildings,\tbicycle\tparking\t| facilities\tshall\tbe\tprovided\tfor\t10%\tof\tbuilding\toccupants.\t|',
#  '<p>Other\tbuildings\tshall\tbe\tprovided\twith\tbicycle\tparking\tequivalent\tto\t5%\tof\tthe\t| building\tcar\tparking\trequirement\tas\tspecified\tin\tB.7.2.6.1.|',
#  '<p>The dimensions for cycle stands shall be not less than the minimum values given  | in\tTable\tB.14\tand\tFigure\tB.67.|',
#  '<p>Dubai Building Code| Part B: Architecture|',
#  '<p>B 72|',
#  '<p>B.7.3.1 | Loading and unloading areas |',
#  '<p>B.7.3.1.1  | General|',
#  ...]

# %%
subheadings = [i[3:] for i in subheadings]

# %%
subheadings
# Out:
# ['Dubai Building Code|',
#  'ii|',
#  'Dubai Building Code|',
#  'A 1|',
#  'Dubai Building Code| Part A: General|',
#  'A 2|',
#  'The objective of the Dubai Building Code (DBC) is to unify building design across | Dubai, and to create a building code that is easy to use and clearly mandates the | minimum requirements for:|',
#  'a) the health, safety, welfare and convenience of people in and around buildings; |',
#  'b) the health, safety, welfare and convenience of people who might be affected by | buildings; |',
#  'c) building design to reduce the impact on the surrounding environment; and|',
#  'd) the sustainable development of buildings.|',
#  'The content of the DBC is based on the following inputs:|',
#  '1) existing regulations and technical requirements produced by the various | Authorities and Service Providers;|',
#  '2) interviews with Government Authorities, Service Providers, Master Developers, | Consultants and other stakeholders to understand gaps or inconsistencies | between existing regulations;|',
#  '3) benchmarking to international and regional codes.|',
#  'The DBC is arranged under themes to integrate all relevant elements of building | design. |',
#  'The regulations stipulated in the DBC are the minimum requirements for building | design. Nothing in the DBC prevents a building design that achieves higher standards | than the minimum set out in the DBC.|',
#  'Dubai Building Code| Part A: General|',
#  'A 3|',
#  'Addition:  Increase to a building’s gross area or built-up | area, and/or height or depth.|',
#  'Architect:  Physical or legal person in charge of | designing or supervising building works, or both, and | licensed to practise the architecture profession in | Dubai in accordance with the applicable legislation. |',
#  'Authority:  Any ministry, department, entity, or | federal or local government institution in Dubai or | any department in licensing Authorities related to the | implementation and the provisions of the DBC. |',
#  'Building lifecycle:  Series of stages through which a | building passes during its lifetime, from initial design, | through construction, commissioning, handover, | and\toperation,\tto\tfinal\tdemolition\tand\trecycling\tof\t| demolished materials/systems.|',
#  'Built-up area:  Total constructed area in a building or | structure measured from the external walls of the | building, inclusive of balconies, terraces and other | projections, as well as any other covered spaces such | as covered parking structures, circulation corridors, | loading/unloading\tbays,\tbasements,\tservice\tfloors,\t| indoor swimming pools and any other permanent | structures on the plot.|',
#  'Building:  Structure for the use or occupancy of people | or for shelter.|',
#  'Change of use:  Alteration to the use of a building to | accommodate an alternative occupancy to that which it | was originally designed.|',
#  'Civil Engineer:  Physical or legal person in charge | of designing or supervising civil engineering works, | or both, and licensed to practise the engineering | profession in Dubai in accordance with the applicable | legislation.|',
#  'Consultant:  Physical or legal person in charge | of providing consulting advice during design or | construction, or both and licensed to practise | consulting in Dubai in accordance with the applicable | legislation.|',
#  'Contractor:  Physical or legal person in charge of | carrying out construction works and licensed to | practise contracting activities in Dubai in accordance | with the applicable legislation. |',
#  'Developer:  Person or entity who prepares land for | building sites, constructs buildings, creates residential | subdivisions or private enterprises, and rehabilitates | existing buildings.|',
#  'Development:  General term for the construction, | erection or placing of a building or structure; the | making of an addition or alteration to a building or | structure;\ta\tsignificant\tchange\tin\tuse\tor\tin\tintensity\tof\t| use of any building or structure. |',
#  'Development control regulations (DCR):  Document | that shows planning regulations (such as height, | land use, area, setbacks, building lines) for the full | development, and each plot in a subdivision plan, as | issued by the relevant planning Authority or master | developer. |',
#  'Engineer:  Physical or legal person in charge of | designing or supervising construction works, or both, | and licensed to practise the engineering profession in | Dubai in accordance with the applicable legislation.|',
#  'Existing building:  Building that is completed, including | commissioning and handover. The DBC applies to | renovation,\tmodification,\treconstruction,\taddition\tto,\tor\t| change of use of an existing building.|',
#  'Floor area ratio (FAR): \tRatio\tof\tgross\tfloor\tarea\t(GFA)\t| to plot area.|',
#  'Gross area (GA): \tFloor\tarea\twithin\tthe\tinside\tperimeter\t| of the exterior walls of a building. The measurement | excludes shafts and courtyards, but includes corridors, | stairways, ramps, closets, base of atria (or similar | voids) and the thickness of interior walls, columns or | other features. |',
#  'NOTE:\tThis\tsection\tgives\tcommon\tdefinitions\tthat\tapply\tthroughout\tthe\tDBC.\tEach\tPart\talso\thas\ta\tsection\tfor\tterms\tspecific\tto\tthat\tPart.|',
#  'Dubai Building Code| Part A: General|',
#  'A 4|',
#  'Gross floor area (GFA):  Measurement used by | Planning\tAuthorities\tin\tDubai\tto\tdefine\tthe\tfloor\tarea\t| ratio\t(FAR),\twhere\tFAR\tis\tthe\tratio\tof\tGFA\tto\tplot\tarea.\t| The\tbuilding\tGFA\tis\tthe\tsum\tof\tthe\tGFA\tof\tall\tfloors,\t| measured to the exterior surface of the external wall | thickness and from the centrelines of the common | walls joining two spaces. The measurement excludes | external wall features such as corniches, brackets, and | façade cladding materials. |',
#  'Habitable space:  Space in a building for living, sleeping | or eating involving occupancy for continuous period of | time. Bathrooms, toilet rooms, closets, halls, storage | or utility spaces and similar areas are not habitable | spaces. |',
#  'Heritage building:  New or existing building in a | heritage area. The heritage department of the | Authority controls the elevation design and façade | treatment of buildings in these areas.|',
#  'Historical building:  Existing building of historical | importance where the original character of the building | is to be retained.|',
#  'Masterplan:  Comprehensive plan to guide the long-| term\tphysical\tdevelopment\tof\ta\tspecific\tarea\tbased\t| on\tidentified\tobjectives,\tstrategies,\tand\ttimelines\t| for implementation. Includes plans for land use, | community facilities and utilities, transportation of | goods and people, and energy use and conservation. | Zoning ordinances and policies are developed for | different areas or zoning districts based on the | masterplan.|',
#  'Modification: \tFit-out\tof\ta\tspace\tor\tunit,\tor\tchange\tto\ta\t| service system or building element.|',
#  'Net area (NA):  Actual occupied area, not including | unoccupied accessory areas such as corridors, | stairways, ramps, toilet rooms, mechanical rooms and | closets. |',
#  'Occupiable space:  Room or enclosed space designed | for human occupancy in which individuals congregate | for amusement, labour, educational or similar purposes.|',
#  'Owner: \tAny\tperson,\tentity,\tfirm\tor\tcorporation\thaving\t| any legal or equitable interest in the property in whose | name the plot or building is registered as Owner, | including persons who have a long-term lease for a | specified\tperiod;\tthe\tMain\tor\tSub-Developer\tin\trelation\t| to unsold lands and buildings.|',
#  'Performance-based design:  Design that follows | prescriptive design requirements, but an aspect(s) | of which is based on an alternative solution that is | equivalent to or better than the prescriptive design | requirements.|',
#  'Plot:  Area of land that is:|',
#  'a) clearly\tdefined\t(by\tlandmarks,\tcoordinates,\tdistinct\t| number, and the lengths of its sides and location);|',
#  'a) intended for construction under any approved plan | or division project, or by any other method; and |',
#  'a) legally authorized to be used for construction or | building as one unit.|',
#  'Plot area:  Total area of a plot between its boundary | lines as measured on a horizontal plane.|',
#  'Prescriptive design:  Design that meets the | requirements entirely.|',
#  'Project:  Construction of a permanent building, or any | other civil work on a leased property including any | modifications\tor\tinstallations\tin\tpre-built\tfacilities.|',
#  'Reconstruction: \tModification\tthat\tis\tnot\tstandalone.\tIt\t| affects adjacent egress routes or systems that are not | part of the reconstructed area, such that a larger part | of the building might need to be closed down or not | occupied for a period of time.|',
#  'Renovation: \tChange\tto\tlinings/finishes\tor\t| strengthening of structure. It does not involve any | reconfiguration\tof\tinternal\tspaces.\t|',
#  'Townhouse:  Multiple villas connected by one or more | walls to a series of similar villas.|',
#  'Villa:  Separate building located on a separate plot | allocated\twith\tall\tits\tfloors\tfor\tthe\tdwelling\tof\tone\t| single family and an independent car parking space in | addition to independent external open space.|',
#  'Dubai Building Code| Part A: General|',
#  'A 5|',
#  'NOTE: This section gives references that apply throughout the DBC. Each Part also | has\ta\tsection\tfor\treferences\tspecific\tto\tthat\tPart.|',
#  'Ref. A.1 \tUAE\tMINISTRY\tOF\tTHE\tINTERIOR\tGENERAL\tCOMMAND\tOF\tCIVIL\t| DEFENCE,\t2018.\tUAE\tFire\tand\tLife\tSafety\tCode\tof\tPractice\t(UAE\tFLSC).\tUnited\tArab\t| Emirates: Ministry of the Interior General Command of Civil Defence.|',
#  'Ref. A.2 \tGOVERNMENT\tOF\tDUBAI,\t2017.\tDubai\tuniversal\tdesign\tcode.\tDubai:\t| Government of Dubai. |',
#  'Ref. A.3 \tDUBAI\tHEALTH\tAUTHORITY,\t2012.\tRegulations\t(various).\tDubai:\tDubai\t| Health\tAuthority.\tAvailable\tat:\t | www.dha.gov.ae/en/HealthRegulation/Pages/FacilityRelated.aspx.|',
#  'Ref. A.4 \tDUBAI\tHEALTH\tAUTHORITY,\t2019.\tDHA\tHealth\tfacility\tguidelines\t–\tPart\tA\t| to\tPart\tF.\tDubai:\tDubai\tHealth\tAuthority.\tAvailable\tat:\t | www.dubaitourism.gov.ae/en/services.|',
#  'Ref. A.5 \tDEPARTMENT\tOF\tTOURISM\tAND\tCOMMERCE\tMARKETING,\t2019.\tDTCM\t| Hotel\tclassification\tcriteria\tfor\thotels,\tguest\thouses\tand\thotel\tapartments.\tDubai:\t| DTCM. Available at:  classification.dubaitourism.ae .|',
#  'Ref. A.6 \tDUBAI\tCIVIL\tAVIATION\tAUTHORITY\tApplication\tfor\ta\tno-objection\t| certificate\tto\tconstruct\ta\tbuilding\t(above\tand\tbelow\t300\tm)\tin\tAviation\tEasement\t| areas. Dubai: DCAA. Available at:  | www.dcaa.gov.ae/services/building-constructions/construct-building .|',
#  'Ref. A.7  GREAT BRITAIN, 2015. The Construction (Design and Management) | Regulations.\tLondon:\tThe\tStationery\tOffice.|',
#  'Dubai Building Code| Part A: General|',
#  'A 6|',
#  'Dubai Building Code| Part A: General|',
#  'A 7|',
#  'The\tDBC\tincorporates,\tunifies\tand\treplaces\tthe\t| regulations related to building design published | by Dubai Municipality (DM), Dubai Development | Authority (DDA), Department of Planning and | Development\t–\tPorts\tCustoms\tand\tFreezone\t| Corporation (Trakhees) and Dubai Silicon Oasis | Authority (DSOA).|',
#  'Regulations related to building design by Dubai | Electricity and Water Authority (DEWA) and Islamic | Affairs and Charitable Activities Department (IACAD) | are incorporated or cross-referenced by the DBC.|',
#  'Regulations related to building design by the Security | Industry Regulatory Agency (SIRA) are summarized | and cross-referenced in  Part J .|',
#  'Federal\tregulations\talso\tremain\tin\tplace.\tThe\tDBC\t| follows\tthe\tFederal\tregulations\tof\tTelecommunications\t| Regulatory Authority (TRA) and the Ministry of | Interior Civil Defence. The TRA regulations are given in | G.11 .\tThe\tUAE\tFire\tand\tLife\tSafety\tCode\t(UAE\tFLSC)\t| [Ref. A.1]  is cross-referenced throughout the DBC.|',
#  'Accessibility requirements of the Dubai Universal | Design Code  [Ref. A.2]  applicable to building design | are incorporated in  Part C  and replace these aspects of | the Dubai Universal Design Code. |',
#  'The\tDubai\tHealth\tAuthority\t(DHA)\tregulations\t | [Ref. A.3 and Ref. A.4] ,\talong\twith\tthe\trelevant\tFederal\t| regulations, shall be followed for the design of all | healthcare facilities. |',
#  'The Department of Tourism and Commerce Marketing | (DTCM) sets out the requirements to achieve star | ratings for hotels, resorts, hotel apartments and | guest houses  [Ref. A.5] . Achieving the minimum | requirements of the DBC does not guarantee a rating | from DTCM. DTCM should be consulted at the earliest | stage of design.|',
#  'The\tKnowledge\tand\tHuman\tDevelopment\tAuthority\t| (KHDA)\tand\tthe\tMinistry\tof\tEducation\tboth\tlicense\t| education facilities, but they do not provide separate | design requirements. Education facilities are approved | by the main Authorities in accordance with the DBC.|',
#  'Roads and Transport Authority (RTA) regulations in | relation to the right of way are referenced by the DBC | as appropriate.|',
#  'Dubai Civil Aviation Authority (DCAA) regulates | maximum\tbuilding\theights\twithin\tthe\tflight\tpath.\t|',
#  'Regulations related to permitting, procedures, | construction and design of non-building elements | such as infrastructure, transportation systems, and | the public realm remain, and can be obtained from, the | relevant Authority. |',
#  'Planning development regulations published by | Developers or Planning Authorities are not replaced | by the DBC. The DBC contains planning regulations | in  Part B , but these shall be followed only where | plot-specific\tplanning\tdevelopment\tregulations\tare\t| unavailable.|',
#  'The DBC relies on international codes and standards, | mainly BS EN and American codes. These codes and | standards shall be used in their latest edition except | where the DBC lists an edition. |',
#  'NOTE:\tAs\tan\texample,\tPart\tF\t(Structures)\tmandates\t| the 2016 edition of ASCE/SEI 7. |',
#  'An edition is mandated in the DBC for one of two | reasons.|',
#  'a) The\tDBC\trefers\tto\tsections,\ttables\tand\tfigures\t| within that version of the international code or | standard and therefore the cross-references might | not apply to later editions. |',
#  'b) The edition has been reviewed for its applicability | to Dubai. |',
#  'Dubai Building Code| Part A: General|',
#  'A 8|',
#  'The hierarchy of the adopted codes and standards is | defined\tas\tfollows.|',
#  'a) The\tDBC\tand\tUAE\tFire\tand\tLife\tSafety\tCode\tof\t| Practice\t(UAE\tFLSC)\t [Ref. A.1]  together form the | main regulations for building design in Dubai. The | UAE\tFLSC\tis\treferenced\tthroughout\tthe\tDBC.\t|',
#  'b) The DBC follows the SIRA regulations for | the design of security. These regulations are | summarized and referenced in  Part J .|',
#  'c) The\tDBC\tfollows\tthe\tFederal\tregulations\tof\tTRA\t| for the design of telecommunications. These | regulations are documented in  G.11 .|',
#  'd) The international codes and standards for design, | material\tand\tproduct\tspecification\tlisted\tunder\tthe\t| heading of “Essential references” in each Part, and | referenced in the relevant sections of each Part, are | also requirements of the DBC. |',
#  'e) Documents\tlisted\tunder\tthe\theading\tof\t“Further\t| reading” in each Part are provided for information | as useful guides to building design. |',
#  'Where\tthere\tis\tconflict\tbetween\tthe\tDBC\tand\treference\t| model codes or standards, the most restrictive/highest | performance requirements shall be met.|',
#  'Where\tthere\tis\ta\tconflict\tbetween\ta\tgeneral\t| requirement\tand\ta\tspecific\trequirement\tof\tthe\tDBC\t| or\tits\treferenced\tcodes/standards\tthen\tthe\tspecific\t| requirement applies.|',
#  'The principle of “safe by design” requires the | Consultant to address the health and safety of all | occupants, Contractors and users of the building.  | This includes Contractors, maintenance staff, | occupants, visitors and demolition teams throughout | the building lifecycle.|',
#  'This process is documented in a risk register where | the Consultant acknowledges the risk, investigates | mitigation measures and provides a design solution | which reduces the risk to a practicable level, while also | taking account of cost, constructability, other project | goals, etc. |',
#  'Safe by design principles are not mandated by the | first\tedition\tof\tthe\tDBC,\tbut\tare\tlikely\tto\tbe\tenforced\t| in future revisions. Consultants should familiarize | themselves with these principles by reference to the | Construction Design and Management Regulations | [Ref. A.7] .|',
#  'Dubai Building Code| Part A: General|',
#  'A 9|',
#  'The DBC applies to new buildings and changes to existing buildings as described in | Table A.1, except where an alternative solution is permitted (see A.8).|',
#  'The DBC applies to the occupancies and use types described in Table A.2.|',
#  'Dubai Building Code| Part A: General|',
#  'A 10|',
#  'The DBC does not apply to:|',
#  'a) infrastructure such as road and rail bridges, tunnels, culverts, metro stations, | hydraulic structures, buried and overhead utilities, power stations, antennas and | masts, wind turbines and nuclear facilities;|',
#  'b) marine structures such as canals, dams, dikes, levies, piers, jetties and wharves;|',
#  'c) oil\tand\tgas\tstructures\tsuch\tas\tpetrochemical\tfacilities,\toil\trefineries,\tliquefied\t| natural gas terminals, oil platforms and tanks;|',
#  'd) structures such as tents, cranes, storage racks, scaffolding, formwork and | falsework;|',
#  'e) structures\tsubject\tto\tspecific\tloading\tconditions\tsuch\tas\tstadia,\tgrandstands,\tsilos\t| and chimneys. |',
#  'The DBC does not apply to historical buildings where the original character of the | building is to be retained. Buildings considered to be historical shall conform to the | guidelines of the relevant Authority as appropriate. |',
#  'Buildings in heritage areas or considered to be heritage buildings shall follow the | DBC. The heritage department of the Authority controls the elevation design and | façade treatment.|',
#  'Villas and townhouses are addressed in  Part K.|',
#  'A.5.2.1 | Gross floor area (GFA)|',
#  'Gross\tfloor\tarea\t(GFA)\tis\tused\tby\tPlanning\tAuthorities\tin\tDubai\tto\tdefine\tthe\tfloor\t| area\tratio\t(FAR),\twhere\tFAR\tis\tthe\tratio\tof\tGFA\tto\tplot\tarea.\tThe\tbuilding\tGFA\tis\tthe\t| sum\tof\tthe\tGFA\tof\tall\tfloors,\tmeasured\tto\tthe\texterior\tsurface\tof\tthe\texternal\twall\t| thickness and from the centrelines of the common walls joining two spaces. The | measurement excludes external wall features such as corniches, brackets, and façade | cladding materials. |',
#  'GFA\tis\tcalculated\tbased\ton\tTable\tA.3.\t\t|',
#  'GFA\tmight\tbe\tin\tdevelopment\tcontrol\tregulations\t(DCR).\tConsultants\tshall\tcalculate\t| GFA\tusing\tthe\tDBC\tdefinition\tand\tTable\tA.1\tunless\tGFA\tis\tstated\tin\tthe\tDCR.|',
#  'Dubai Building Code| Part A: General|',
#  'A 11|',
#  'Dubai Building Code| Part A: General|',
#  'A 12|',
#  'A.5.2.2 | Built-up area |',
#  'Built-up area is used also by Planning Authorities. It | is\tdefined\tas\tthe\ttotal\tconstructed\tarea\tin\ta\tbuilding\t| or structure measured from the external walls of the | building, inclusive of balconies, terraces and other | projections as well as any other covered spaces such | as covered parking structures, circulation corridors, | loading/unloading\tbays,\tbasements,\tservice\tfloors,\t| indoor swimming pools and any other permanent | structures on the plot. Calculation of total built-up area | shall exclude the following: |',
#  'a) shafts, courtyards and yards including mechanical, | electrical and plumbing (MEP) shafts, refuse chutes | and similar; |',
#  'b) non-covered outdoor landscape and hardscape | surfaces and courtyards; |',
#  'c) lightweight outdoor shading structures such as | pergolas and standalone canopies.|',
#  'An example calculation using a sample plan is shown in | Figure\tA.1.|',
#  'Dubai Building Code| Part A: General|',
#  'A 13|',
#  'A.5.2.3 | Gross area and net area|',
#  'The terms “gross area” (GA) and “net area” (NA) are | used\tby\tthe\tDBC\tto\tcalculate\toccupant\tload\tin\ta\tfloor\t| or\tspace.\tThey\tare\tdefined\tin\tA.2\tand\tfurther\tdescribed\t| and illustrated in  Part B . |',
#  'A.5.2.4 | Building height|',
#  'Building height is a key variable that is checked by | the Authorities for compliance with the DBC, DCR/| affection\tplans,\tUAE\tFLSC\t [Ref. A.1]  and, where | applicable, DCAA restrictions on building heights | located in Aviation easement areas due to overhead | flight\tpaths.\t|',
#  'Each\tdefinition\tof\tbuilding\theight\tis\tslightly\tdifferent\t| as\tthey\tare\tused\tto\tregulate\tdifferent\tissues.\tFor\tthis\t| reason, Consultants shall check building height against | the\tDBC,\tDCR/affection\tplans,\tUAE\tFLSC\t [Ref. A.1]| and, where applicable, DCAA regulations  [Ref. A.6] .|',
#  'Dubai Building Code| Part A: General|',
#  'A 14|',
#  'The\tDBC\tis\tdivided\tinto\tParts\tas\tdescribed\tin\tFigure\tA.2.\t| Each Part is subdivided into sections by topic.|',
#  'Minimum requirements for sustainability are embedded | within the relevant Parts of the DBC. Developers and | Consultants are encouraged to apply the rating system | adopted by the relevant Authority to assess their | projects and exceed these minimum requirements. |',
#  'Fire\tsafety\trequirements\tare\tgiven\tin\tthe\trelevant\t| Parts\tof\tthe\tDBC\tand\tcross\treferenced\tto\tUAE\tFLSC\t| [Ref. A.1] . The aim of this cross-referencing is to help | Consultants navigate and coordinate the requirements | of\tthe\ttwo\tdocuments.\tWhere\tan\telement\tof\tUAE\tFLSC\t| is not applicable in Dubai, or the DBC contains additional | information\tnot\tin\tUAE\tFLSC,\tthis\tis\tindicated\tin\tthe\t| text.|',
#  'Dubai Building Code| Part A: General|',
#  'A 15|',
#  'The overarching objectives of the DBC, its intention | and regulatory scope, are set out in A.1. |',
#  'Each Part of the DBC starts with a set of performance | statements. These set out the broad outcomes that | the completed building is expected to achieve, and | are provided to explain the intent of the prescriptive | design requirements within the Part. If the prescriptive | design requirements of the Part are followed, then the | performance statements of the Part are deemed to be | met and will be accepted by the Authority.|',
#  'Each Part has a section for essential references and | further reading. The requirements of the DBC and | the essential references form the prescriptive design | requirements of the DBC and will be enforced by the | Authority. Websites and webpages shall be checked | regularly for updates.|',
#  'NOTE: Where websites and webpages have been cited | throughout the DBC, they are provided for ease of | reference and are correct at the time of publication. | Changes to the location of a webpage or website, or its | contents, cannot be guaranteed.|',
#  'In\taddition\tto\tthe\tcommon\tdefinitions\tin\tA.2,\teach\tPart\t| has\ta\tsection\tfor\tdefinitions.|',
#  'Any annex material is included at the end of the Part | to which it relates. Annex material contains further | explanatory material.|',
#  'Dubai Building Code| Part A: General|',
#  'A 16|',
#  'Projects\tin\tdesign\tor\tconstruction\tthat\thave\ta\tfinal\t| approved design from the Authority do not need to | conform to the DBC.|',
#  'Projects\tin\tdesign\twithout\ta\tfinal\tapproved\tdesign\tshall\t| conform to the DBC. The requirements of the DBC are | based on regulations enforced prior to its publication | and\tin\tmany\tinstances\tthe\tDBC\tis\tless\tstringent.\tFor\t| example, requirements unrelated to health, safety, | welfare and environment have generally been removed | from the regulations. Therefore, it is expected that | there\twill\tbe\tbenefits\tto\tDevelopers\tand\tOwners\tin\t| adopting the DBC.|',
#  'The DBC is intended to be a prescriptive design code. | Performance statements are provided at the start of | each Part to describe the outcomes that the completed | building is expected to achieve. |',
#  'The performance statements form a set of overarching | regulations that convey the requirements of the  | DBC (see A.6.2). |',
#  'The preferred method of meeting the performance | statements of the DBC is to follow the prescriptive | design requirements in each Part. |',
#  'The inclusion of performance statements sets out the | intent of the DBC and future-proofs it, supporting | a possible transition to a more performance-based | regulatory system in the future.|',
#  'Alternative solutions which meet the performance | statements of the DBC are permitted:|',
#  'a) for projects that cannot reasonably meet the | prescribed requirements; and|',
#  'b) for changes to existing buildings where the | requirements of the DBC would result in a | disproportionate cost to the Owner/Developer.|',
#  'The Authority will decide if an alternative solution is | permitted. |',
#  'An alternative solution shall meet the intent of | the performance statements and provide at least | an equivalent level of performance to all of the | prescriptive design requirements. |',
#  'Alternative solutions shall be applied to a performance-| based design holistically such that a change from | one Part of the DBC does not reduce the building’s | performance in other aspects.|',
#  'Alternative solutions for changes to existing buildings | shall demonstrate that the existing conditions are | maintained to the current level of compliance or | improved to meet the safety levels of the DBC and  | UAE\tFLSC\t [Ref. A.1] . |',
#  'The Authority will decide whether or not a | performance-based design is equivalent to the | prescriptive design requirements. The responsibility | is on the Consultant to demonstrate that the | performance-based design is required and that | it is at least equivalent to the prescriptive design | requirements.|',
#  'The DBC lists preferred international codes and | standards in each Part (see A.4.2). Where permitted | by the Authority, alternative standards can be used | provided that the comparable standard meets the | intent of the DBC. |',
#  'Dubai Building Code| Part A: General|',
#  'A 17|',
#  'The DBC is an interactive document available | electronically. |',
#  'The DBC will typically be maintained and updated on a | two- to three-year cycle. If necessary, addendums will | be issued between cycles. It is therefore important that | Consultants, Contractors and Engineers check back | regularly to ensure that they are following the latest | version of the DBC. |',
#  'This\tedition\tis\tthe\tfirst\tedition\tof\tthe\tDBC.|',
#  'Amended content in future editions will be clearly | indicated.\tFor\texample,\tnew\tcontent\twill\tbe\tside\tlined\tin\t| the\tfirst\tedition\tin\twhich\tit\tis\tpublished.|',
#  'No content of the DBC, in part or whole, shall be | copied, printed, sold or reproduced in any format.|',
#  'The coordinate system used by the Authority is Dubai | Local\tTransverse\tMercator\t(DLTM).\tThe\treference\t| point for levelling is Port Rashid.|',
#  'Dubai Building Code| Part A: General|',
#  'A 18|',
#  'All\tdimensions\tin\tthe\tfigures\tand\tdiagrams\tof\tthe\t| DBC are given in millimetres without units, unless the | distance exceeds 1,000 mm, and then it is given in | metres with units (m). Dimensions that are not stated | as “maximum” or “minimum” are absolute.|',
#  'All dimensions are subject to conventional industry | tolerances, except where the requirement is stated as a | range\twith\tspecific\tminimum\tand\tmaximum\tend\tpoints.|',
#  'All quantities shall be in metric units with the units | defined.|',
#  'All engineering shall be performed in dynamically | consistent units. One of the two systems shown in | Table A.4 should be used. Use of dimensions between | analysis models, drawings and/or building information | modelling (BIM) models shall be fully coordinated and | consistent.|',
#  'Where the required number of elements (e.g. parking | or sanitary provisions) to be provided is determined by | calculations of ratios or percentages, and this results in | remainders or fractions, the next greater whole number | of such elements shall be provided.|',
#  'Dubai Building Code|',
#  'B 1|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 2|',
#  'Performance statement| The performance statement will be met | by following the requirements of:|',
#  'The building shall be appropriately | integrated with the surrounding natural | and built environment.|',
#  'B.4, B.9 and B.10|',
#  'The building shall facilitate the safety, | convenience and welfare of building | occupants as they move in and around | the building, including access and | egress. |',
#  'B.4, B.5, B.6, B.9 and B.11|',
#  'The building shall provide appropriate | access and safe circulation for vehicles | within the site and building.|',
#  'B.7 and B.9|',
#  'The building shall provide minimum | communal provisions and facilities for | the welfare of occupants. |',
#  'B.8 and B.9|',
#  'The building shall be provided with | adequate and accessible solid waste and | recycling storage to safeguard people | from injury or illness caused by infection | or contamination.|',
#  'B.8.5 and B.9|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 3|',
#  'Accessibility:  Ease of independent approach, entry, | evacuation and/or use of a building and its services | and facilities by all of the building’s potential users, | regardless of disability, age or gender, and with an | assurance of individual health, safety and welfare.|',
#  'Accessible:  Site, building, facility or portion thereof | that conforms to  Part C .|',
#  'Advertising: \tAny\tidentification\tor\tdescription\tor\t| drawing\tor\tany\tother\tmeans\tto\tbe\tfitted\tor\terected\tor\t| printed or written or drawn, either directly or indirectly, | or any building or structure or plot, whose purpose is | to draw attention to any business, product, service, etc.|',
#  'Affection plan:  Plan of the plot or site issued by the | Authority, showing information that includes (but is | not limited to) the plot boundaries, plot dimensions, | plot areas, setbacks and surroundings as well as the | land uses. Also called site plan.|',
#  'Amenity space:  Public or private area within the | boundaries of a plot or a development site for the | building occupant’s recreation or convenience (such as | landscaped areas, patios, swimming pools, play areas, | prayer rooms, exercise areas and similar uses).|',
#  'Annex:  Building or installation, attached to or | independent from the main building, the use of which | is secondary or complementary to the function of the | main building.|',
#  'Arcade:  Roofed corridor that leads to any building, | faces a street or open courtyard, or links more than | one building. Usually formed through a series of arches | supported\ton\tcolumns\tor\tpiers\t(see\tFigure\tB.1).|',
#  'Authorized use:  Plot use or building occupancy | authorized\taccording\tto\tthe\tclassification\tof\tlands\t| in\tDubai\tnoted\tin\tthe\tofficial\taffection\tplan\tor\t| development regulation.|',
#  "Balcony:  Covered or uncovered occupied projection or | partial projection outside the external walls, attached | to the building and accessed from the building's | interior\tspaces\t(see\tFigure\tB.2).|",
#  'Assembly:  Occupancy\tclassification\tassociated\twith\t| the gathering of people for deliberation, worship, | entertainment, eating, drinking, amusement, awaiting | transportation, or similar uses.|',
#  'Atrium:  Large-volume\tspace\tcreated\tby\ta\tfloor\topening\t| or\tseries\tof\tfloor\topenings,\tconnecting\ttwo\tor\tmore\t| storeys\tor\texceeding\t15\tm\tin\theight\tfrom\tfinished\tfloor.\t| The space is covered at the top of the opening(s) and | used for purposes other than an enclosed stairway, | an elevator hoistway, an escalator opening or a utility | shaft.|',
#  'Basement floor:  Storey of a building wholly or partly | below\tthe\tgate\tlevel\tthat\tis\tnot\tthe\tfirst\tstorey\tabove\t| gate\tlevel.\tA\tbasement\tslab\tsoffit\tlevel\tis\tnot\thigher\t| than 1,200 mm above the building gate level.|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 4|',
#  'Bathroom:  Room containing a water closet, a | washbasin, and either a bathtub, a shower, or both. |',
#  'Bi-separator: \tPiece\tof\tequipment\tfitted\tto\tthe\tend\tof\ta\t| refuse chute which allows the user to deposit multiple | waste streams, such as recycling and residual waste, | into a single refuse chute. |',
#  'Boundary wall/fence:  Free-standing\tstructure\t| constructed from approved materials surrounding a | plot, resting on the ground and rising above ground | level\tand\tused\tfor\tconfinement\tand/or\tscreening\tfor\t| safety or security or division purposes.|',
#  'Building:  Structure for the use or occupancy of people | or for shelter.|',
#  'Building element:  Component of a building, which | might\tor\tmight\tnot\tbe\tof\tfire\tresistance\trated\t| construction and is constructed of approved materials. |',
#  'Building envelope:  Physical barrier between the | exterior and the conditioned environment of a building | to resist air, water, moisture, heat, cold, light, and noise | transfer.\tFor\tan\tair-conditioned\tbuilding,\tthe\tbuilding\t| envelope comprises the elements of a building that | separate conditioned spaces from the exterior. Crown | extensions to the façade to cover plant screen cladding | are part of the building envelope. The building envelope | does not include the physical barrier below ground.|',
#  'Building height, total:  Vertical distance measured from | the approved road edge level at the plot main access to | the highest roof surface or element.|',
#  'Building height:  Vertical distance measured from the | approved road edge level at the plot main access to the | mean\tfinished\tlevel\tof\tthe\tbuilding\troof.\t|',
#  'Building occupants:  Persons using the building. |',
#  'Building projection:  Projection or protrusion that | extends\toutside\tthe\tvertical\texternal\twall\tof\tthe\tfloor\t| below, such as balconies.|',
#  'Building setback: \tHorizontal\tdistance\tbetween\tthe\t| nearest part of any building or structure on the plot | above ground and the plot boundary, measured | perpendicular to the plot boundary.|',
#  'Built environment:  External and internal environments | and\tany\telement,\tcomponent\tor\tfitting\tthat\tis\t| commissioned, designed, constructed and managed for | use by people.|',
#  'Bulky waste:  Waste, such as furniture, which is usually | too large for regular waste collections.|',
#  'Business:  Occupancy used for the transaction of | business\tother\tthan\tretail,\tusually\tused\tfor\toffice,\t| professional or service-type transactions, including | storage of records and accounts.|',
#  'Canopy:  Building projection that provides weather | protection, identity or decoration and is partially | or wholly supported by the building to which it is | attached. |',
#  'Carpool vehicle:  Shared vehicle used by people who | each have a car but travel together to save cost, to | reduce driving stress and to promote other socio | environmental\tbenefits.|',
#  'Chimney:  Primarily vertical structure containing one | or\tmore\tflues,\tfor\tthe\tpurpose\tof\tcarrying\tgaseous\t| products of combustion and air from a fuel-burning | appliance to the outdoor atmosphere.|',
#  'Chute:  Vertical shaft or sloping channel provided for | building utilities and services. |',
#  'Circulation:  Means of passage for pedestrians in and | around the built environment, including (but not | limited to) corridors, hallways, courtyards, stairways | and stair landings.|',
#  'Clear width:  Free\tunobstructed\tspace\tfor\taccess.|',
#  'Clinic:  Buildings (or portions thereof) used to provide | medical care on less than a 24 h basis. |',
#  'Corridor:  Enclosed\tcomponent\tthat\tdefines\tand\t| provides a path of travel.|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 5|',
#  'Courtyard:  Open, uncovered space, unobstructed to | the sky, bounded on three or more sides by exterior | building walls or other enclosing devices as shown in | Figure\tB.3.|',
#  'Curb:  Raised\tedge\ton\ta\troadway,\tconcrete\tfloor\tslab\t | or around roof plant.|',
#  'Daylighting:  Illumination of interior spaces using | natural light.|',
#  'Department store:  Store, exhibition, building, or part | of a building used for the retail sale of a broad variety | of items.|',
#  'Designated preferred parking spaces:  Parking spaces | that are closest to the main entrance of a building, | excluding accessible spaces, or parking spaces closest | to the pedestrian exit from the parking area.|',
#  'Entrance:  Access point to a building, portion of a | building or facility. An entrance includes the approach | walk, the vertical access leading to the entrance | platform, the entrance platform itself and the entry | door(s) or gate(s).|',
#  'Environmental impact assessment (EIA):  Process  | of predicting, identifying and evaluating the likely | impacts\t(initial\tand\tcumulative),\tboth\tbeneficial\tand\t| adverse, of a project on the environment including the | potential effects of the environment on the project.|',
#  'Exhibition:  Space or structure used for the display  | of products or services.|',
#  'Exit access:  Portion of a means of egress that leads to | an exit.|',
#  'Exit discharge:  Portion of a means of egress between | the termination of an exit and a public way.|',
#  'Exit passageway:  Exit component that is separated | from\tother\tspaces\tof\ta\tbuilding\tor\tstructure\tby\tfire\t| resistance rated construction and opening protectives, | providing a protected path of egress travel in a | horizontal direction to exit discharge or public way | or outside building. Additional uses for the exit | passageway\tinclude\tstair\ttransfer\tin\tupper\tfloors\t | as well as to reduce travel distance to an exit by having | an exit passageway lead to a stair of exit discharge. |',
#  'Development:  General term for the construction, | erection or placing of a building or structure; the | making of an addition or alteration to a building or | structure;\ta\tsignificant\tchange\tin\tuse\tor\tin\tintensity\tof\t| use of any building or structure. |',
#  'Development control regulations (DCR):  Document | that shows planning regulations (such as height, | land use, area, setbacks, building lines) for the full | development, and each plot in a subdivision plan, as | issued by the relevant planning Authority or  | master Developer.|',
#  'Door:  Combination of a door leaf or leaves, frame, | hardware, and other accessories, positioned in an | opening in a wall and intended primarily for access  | and egress.|',
#  'Driveway:  Access to a required off-street parking  | and loading facility area.|',
#  'Education:  Occupancy used for educational purposes, | including training centres and universities. |',
#  'Element:  Component or space of a building,  | facility or site.|',
#  'Elevator lobby: \tLanding\tfrom\twhich\toccupants\tdirectly\t| enter an elevator car(s) and into which occupants | directly enter upon leaving an elevator car(s).|',
#  'Enclosed parking:  Parking occupancy that is partially | or wholly enclosed on all sides, and that does not | qualify as open parking.|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 6|',
#  'Exterior stairway:  Stairway that is open on at least one | side, except for required structural columns, beams, | handrails and guardrails. The adjoining open area can | be either yards, courtyards or public ways.  | The other sides of the exterior stairway can be closed.|',
#  'External wall:  Wall, load bearing or non-load bearing, | that is used as an enclosing wall for a building and | might form part of the building envelope.|',
#  'Facility:  All or any portion of the buildings, structures, | site improvements, equipment, roads, walks, | passageways, parking lots or other property located  | at the site.|',
#  'Feeding room or lactation room:  Private space where a | nursing mother can nurse a child or lactate.|',
#  'Fixed seating: \tFurniture\tor\tfixture\tdesigned\tand\t| installed for the use of sitting, and secured in place. | Includes bench-type seats and seats with or without | backs or arm rests.|',
#  'Flight:  Continuous run of stair treads from one landing | to another.|',
#  'Flood or flooding:  General and temporary condition | of partial or complete inundation of normally dry land | from:|',
#  'a) the\toverflow\tof\tinland\tor\ttidal\twaters;|',
#  'b) the unusual and rapid accumulation or runoff  | of surface waters from any source.|',
#  'Floor finish: \tExposed\tfloor\tsurfaces\tof\tbuildings\t| including\tcoverings\tapplied\tover\ta\tfloor\tor\tstair,\t| including risers.|',
#  'Floor height:  Vertical distance from top to top of two | successive\tfinished\tfloor\tsurfaces.\tFor\tthe\ttopmost\t| storey,\tfrom\tthe\ttop\tof\tthe\tfloor\tfinish\tto\tthe\ttop\tof\tthe\t| ceiling joists or, where there is no ceiling, to the top of | the roof surface.|',
#  'Floor or storey:  Portion of a building located between | the\tupper\tsurface\tof\ta\tfloor\tand\tthe\tupper\tsurface\tof\t| the\tfloor\tor\troof\tnext\tabove.|',
#  'Fuel dispensing facilities: \tFacility\twhere\tmotor\tfuels\t| are\tstored\tand\tdispensed\tfrom\tfixed\tequipment\tinto\t| the fuel tanks of motor vehicles or marine craft or into | approved containers, including all equipment used in | connection therewith.|',
#  'Gate level:  \tDefined\theight\ton\tthe\tplot\tboundary\tat\tthe\t| vehicular or pedestrian access point to the plot. It is an | elevation difference between the road level (existing or | future) and the level of the plot’s access point.|',
#  'The gate level of a plot shall be a minimum height | of +300 mm from the edge of the road or a slope of | between\t2-5%\tfrom\tthe\tedge\tof\tthe\troad\tto\tthe\tplot’s\t| access point.|',
#  'Glazed element:  Individual element within a building | envelope that lets in light, including windows, plastic | panels, clerestories, skylights, doors that are more than | one half glass, and glass block walls.|',
#  'Glazing:  Glass that is installed as one of the | components\tof\ta\twall,\tfloor,\tceiling\tor\troofing\tsystem.|',
#  'Gross area (GA): \tFloor\tarea\twithin\tthe\tinside\tperimeter\t| of the exterior walls of a building. The measurement | excludes shafts and courtyards, but includes corridors, | stairways, ramps, closets, base of atria (or similar | voids) and the thickness of interior walls, columns or | other features. |',
#  'Ground floor: \tFirst\tfloor\tin\tthe\tbuilding\tabove\tthe\tgate\t| level. |',
#  'Guard room:  Room, unit, or residential space on the | same plot of land as the main building, or located | within the main building, designated for the occupancy | of the guard.|',
#  'Guardrail:  Vertical protective barrier erected along | elevated walking surfaces, exposed edges of stairways, | balconies and similar areas that minimizes the | possibility of fall from elevated surfaces to lower level.|',
#  'Habitable space:  Space in a building for living, sleeping | or eating involving occupancy for continuous period of | time. Bathrooms, toilet rooms, closets, halls, storage | or utility spaces and similar areas are not habitable | spaces.|',
#  'Handrail: \tHorizontal\tor\tsloping\trail\tintended\tfor\t| handhold and grasping by hand for guidance or | support\t(see\tFigure\tB.4).|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 7|',
#  'Hardscape:  Area of a project site, excluding buildings, | made with hard materials, including roads, car parks, | patios, courtyards and walkways.|',
#  'Hazardous waste:  Waste material that can cause | substantial harm to humans, properties and/| or the environment due to its inherent hazardous | characteristics.\tHazardous\twaste\ttakes\tthe\tform\tof\t| solid, liquid, sludge, gas or any combination thereof. |',
#  'Healthcare:  Occupancy used to provide medical, | psychiatric, surgical, therapeutic treatment for people.|',
#  'Helipad:  Dedicated structural surface used for the | landing, taking off, taxiing and parking of helicopters.|',
#  'High-rise building:  Building height greater than or | equal to 23 m and up to 90 m, measured in accordance | with\tthe\tUAE\tFLSC\t [Ref. B.1] . A more detailed | definition\tis\tgiven\tin\tUAE\tFLSC.|',
#  'Hospital:  Building or portion thereof used on a 24 h | basis for the medical, psychiatric, obstetrical or surgical | care of four or more inpatients.|',
#  'Hotel:  Building or groups of buildings under the | same management in which there are sleeping | accommodations for lodging with or without meals for | people on a transient basis.|',
#  'Hotel apartments:  Collection of apartments or studios | that are rented to guests by the day, the week, the | month or the year.|',
#  'Hotel establishment: \tHotels,\tguest\thouses,\thotel\t| apartments or resorts.|',
#  'Hotel suite:  Separate guest unit in a hotel that | contains one or more bedrooms with a living room and | other services.|',
#  'Housekeeper’s room:  Attached or separate room or | unit on the same plot of land as the main building, | designated for the residence of housekeepers or other | maintenance staff such as gardeners, guards and | drivers. |',
#  'Hybrid vehicle:  Vehicle using two different forms | of power, such as an electric motor and an internal | combustion engine, or an electric motor with a battery | and fuel cells for energy storage.|',
#  'Illuminance:  Amount of light falling onto a surface area.|',
#  'Industrial/factory/workshop:  Occupancy in which | products are manufactured or in which processing, | assembling,\tmixing,\tpackaging,\tfinishing,\tdecorating,\tor\t| repair operations are conducted.|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 8|',
#  'Intersection:  Crossing of two or more roads.|',
#  'Kiosk:  Temporary or permanent structure of | lightweight construction occupied as a retail outlet, | food\toutlet\tor\tservice\toutlet.\tKiosks\tare\tgenerally\t| located at malls, shopping centres, assembly areas and | exhibition centres.|',
#  'Kitchen:  Place for the preparation of meals and | beverages. |',
#  'Labour accommodation:  Building used for group | accommodation\tfor\tworkers\tof\ta\tcompany\tor\ta\tfirm,\t| for which the sanitary facilities and other services are | common.|',
#  'Landing:  Floor\tarea\tat\tthe\ttop\tof\ta\tflight\tof\tstairs\tor\t| between\ttwo\tflights\tof\tstairs,\tor\ta\tplatform\tor\tpart\tof\ta\t| floor\tstructure\tat\tthe\tend\tof\ta\tramp\tor\tat\tthe\tentrance\t| to an elevator car.|',
#  'Land use:  Activities, operations, or purposes that are | employed\tin\ta\tparticular\tgeographic\tarea;\tthe\tspecific\t| manner\tin\twhich\ta\tplot\tof\tland\tis\tutilized.\tLand\tuse\t| is usually regulated through zoning and planning | regulations.|',
#  'Level:  Ground\tor\tfloor\tsurface,\tor\tpart\tof\ta\tsurface,\t| having\ta\tslope\tof\tnot\tmore\tthan\t2%\tat\tany\tpoint\tand\tin\t| any direction.|',
#  'Line of sight:  Imaginary line from the eye to a | perceived object or view.|',
#  'Loading area:  Area used for loading or unloading | of vehicles, located entirely on private property and | provided with permanent independent access.|',
#  'Lobby:  Entrance or foyer to a space or building which | acts as a transition area.|',
#  'Local road:  A roadway with the primary function | of providing access to adjacent properties and to | roadways\tof\ta\thigher\tfunctional\tclassification.|',
#  'Local species: \tLocal\tplants\tand\tplants\tadapted\tto\tthe\t| local environment.|',
#  'Low-rise building:  Building height less than or up to  | 15\tm,\tmeasured\tin\taccordance\twith\tthe\tUAE\tFLSC\t | [Ref. B.1] .\tA\tmore\tdetailed\tdefinition\tis\tgiven\tin\t | UAE\tFLSC.\t|',
# ...
#  'Glazed elevators contained entirely within an atrium or communicating space do not | need\tto\tbe\tfire\tresistance\trated.\t|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 58|',
#  'The following provisions shall be included when setting the building access strategy | during the design process. |',
#  'a) Public\tand\tservice\tentrances\tshall\tbe\tclearly\tlocated\tand\tidentified\twith\tsignage\t | as in accordance with B.11. The location of car parking and the main entrance | shall\tbe\tclearly\tidentified\twith\tsignage\tin\taccordance\twith\tB.11.|',
#  'b) Buildings shall allow for smooth pedestrian access with crossings and pathways. | Pathways shall be provided for building entries from surrounding streets, parking | bays and external sidewalk. |',
#  'c) Accessible routes shall be provided in accordance with  C.5 .|',
#  'd) Buildings providing pick-up and drop-off areas shall conform to Chapter 7.2  | of Dubai access management manual requirements  [Ref. B.37] . |',
#  'e) For\tmixed-use\tbuildings\tcontaining\tresidential\toccupancy\tand\tother\tpublic\t | or business occupancies, the residential pedestrian access point and lobbies shall | be\tseparated\tfrom\tthose\tserving\tpublic/business\toccupancies.\tFor\tother\tmixed-| use buildings, the segregation of pedestrian access points for different building | occupancies is recommended for privacy and security. |',
#  'f) The number and location of exits discharging directly from the building to outside | shall be in accordance with B.4.3.1. |',
#  'g) Access\troutes\tand\taccessways\tfor\tfire\ttrucks\tshall\tbe\tprovided\tin\taccordance\t| with\tCh.\t2\tof\tUAE\tFLSC\t [Ref. B.1] .\tFire\ttrucks\tshall\tbe\table\tto\treach,\twithin\tthe\t| required distances and as applicable, the building entry points, breeching inlets | and the perimeter façade of the building. |',
#  'h) Public\troadways\tcarrying\theavy\tvolumes\tof\ttraffic\tshall\tnot\tbe\tused\tfor\taccess\t| unless an alternative access point cannot be provided, and it is agreed with RTA | and the Authority. |',
#  'B.7.2.1 | General requirements|',
#  'Vehicle\taccess\tshall\tbe\tlocated\taway\tfrom\tany\ttraffic\tintersections\tdepending\ton\troad\t| type, vehicle type and other factors as approved by RTA.|',
#  'Vehicle access shall conform to RTA requirements. Public rights of way shall be | designed in accordance with the RTA Dubai access management manual  [Ref. B.37]| and RTA Geometric design manual for Dubai roads  [Ref. B.38] .|',
#  'Building developments which are deemed by the Authority to have an impact on the | traffic\tgeneration\tfor\tthe\tsurrounding\troads\tand\tproperties\tshall\tsubmit\ta\ttraffic\t| impact\tassessment\t(TIA)\tor\ttraffic\timpact\tstudy\t(TIS)\tto\tthe\tAuthorities.|',
#  'Vehicle access shall be separated from local road intersection or minor T junctions by | not\tless\tthan\t15\tm\tfrom\tthe\tchamfered\tedge\tof\tthe\tplot\t(see\tFigure\tB.49\tand\t | Figure\tB.50).\t\tFor\tother\troad\tintersections,\tDubai\taccess\tmanagement\tmanual\t| requirements  [Ref. B.37]  shall be followed.|',
#  'If the building is facing more than one road, the vehicle access point should be from | the\tsecondary\troad,\tor\tas\tspecified\ton\tthe\taffection\tplan,\tas\tshown\tin\tFigure\tB.49.|',
#  'Segregation between light and heavy vehicle parking areas inside plots shall  | be provided in accordance with B.7.3.|',
#  'Vehicle\taccess\tshall\tnot\tbe\tlocated\topposite\ta\tT\tjunction,\tas\tshown\tin\tFigure\tB.50.|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 59|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 60|',
#  'Internal roads within plot limits shall be not less than:|',
#  'a) 3\tm\tclear\twidth\troad\tor\tpavement\tfor\tone-way\ttraffic;|',
#  'b) 6\tm\tclear\twidth\troad\tor\tpavement\tfor\ttwo-way\ttraffic.|',
#  'All vehicular roadways and parking areas shall be provided with exterior lighting to | illuminate the surface area in accordance with  H.7 . All internal roads or access to | plots\tshall\tbe\tlit\tto\ta\tCIE\t115\t(lighting\tclass\tM5,\tL',
#  '\t≥\t0.5\tcd/m',
#  ' with uniformity  | U',
#  '\t≥\t0.35)\t [Ref. B.39] .\tLighting\tshall\tbe\tdesigned,\tarranged\tand\tinstalled\tto\tconfine\t| direct rays onto the plots and to direct light away from adjacent structures or streets. |',
#  'All parts of the site to which vehicles might have access shall be hard surfaced and | drained.|',
#  'All vehicular manoeuvring to take place within plot limits without impacting ROW|',
#  'B.7.2.2 | Vehicular ramps|',
#  'Ramps allocated for vehicular access shall conform to Table B.9 and the following.|',
#  'a) Curved and helical vehicular ramps are not preferred. |',
#  'b) Any curved portion of vehicular ramps shall conform to the requirements for | curved ramps.|',
#  'c) Lane\tseparation\tfor\tramps\tshall\tbe\tprovided\tthrough\tcurbs,\twalls\tor\tother\t| structural segregation.|',
#  'd) Where\ta\tcurb\tis\tused\tbetween\tlanes\tto\tseparate\ttraffic\tflows,\teach\tlane\tshall\tmeet\t| the minimum width requirement. Curbs shall be not less than 300 mm in width, | and not less than 150 mm in height.|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 61|',
#  'Vehicular ramps shall meet the following requirements. |',
#  '1) Floor\tsurfaces\tshall\tbe\tof\tbroom\tfinish\ttexture\tor\tprovided\twith\tanti-slip\t| treatment. |',
#  '2) Ramps shall be free from any projections or obstacles that could obstruct safe | movement or use.|',
#  '3) Corners of structural elements adjacent to ramps shall be covered with | protective materials.|',
#  '4) Ramps\tshall\tbe\tprovided\twith\treflective\tmirrors\tthat\tare\tappropriately\tsized\t | to enhance visibility at directional changes, turns and in areas where visibility  | is\tdifficult.\t|',
#  '5) Ramps shall be equipped with all necessary connections for rainwater drainage.|',
#  '6) Floor\tsurfaces\tshall\tbe\tnon-combustible,\tgraded\tand\tequipped\twith\tdrainage\t | in\taccordance\twith\tTable\t3.37,\tCh.\t3\tof\tUAE\tFLSC\t [Ref. B.1] .  |',
#  'Vehicular\tramps\tshall\tnot\tbe\tused\tfor\tmeans\tof\tegress,\tas\tspecified\tin\tTable\t3.37,\t | Ch.\t3\tof\tUAE\tFLSC\t [Ref. B.1] ,\twith\tthe\tfollowing\texception.\tFor\tone\tlevel\tbelow\t | or one level above discharge level of parking, vehicular ramps may be used as one of | the means of egress, provided that no shutters or doors are installed in such ramps. |',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 62|',
#  'Ramp design should provide blended transitions to horizontal parking levels.  | The transition should be equal to half the percentage of ramp’s slope, according  | to\tthe\tdimensions\tgiven\tin\tTable\tB.10\tand\tFigure\tB.54.|',
#  'Mechanical parking can substitute for vehicular ramps, provided that following | requirements are met.|',
#  'i) | A TIA shall be submitted.|',
#  'ii) | \tThe\tsystem\tused\tshall\tbe\tprovided\twith\tan\tinspection\tcertificate\tfor\tinstallation\t| and safety in accordance with BS EN 14010:2003+A1:2009.|',
#  'iii) Building occupants shall not be able to access the structure. A suitable and | airconditioned waiting area shall be provided adjacent to the parking exits. |',
#  'iv)  An emergency auto response system shall be provided, to enable continuity  | of\tuse\tand\tavoid\timpact\ton\tROW\tand\ttraffic\tflow\tin\tthe\tevent\tof\tsystem\tfailure.|',
#  'v) | The\tsystem\tshall\tbe\tcapable\tof\toperating\tat\t25%\tminimum\tcapacity\tthrough\t | a standby generator in case of electrical outage. |',
#  'vi) \tThe\tnet\tfloor\theight\tof\tthe\tparking\tlevels\tshall\tmatch\tthe\tsystem\tspecification\t| requirements, and may be less than the minimum clear heights given in B.5.3. |',
#  'vii) The\tmechanical\tparking\tshall\tmeet\tthe\tfire\tsafety\trequirements\tof\t | UAE\tFLSC\t [Ref. B.1] . |',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 63|',
#  'B.7.2.3 | Parking floors and structures|',
#  'B.7.2.3.1  | General|',
#  'Parking areas within a building shall be separated from other occupancies.  | Occupiable spaces adjacent to or within parking areas shall be provided with  | thermal and acoustic treatment. Ventilation separation conforming to  Part H ,  | and\tfire\tseparation\tconforming\tto\tTable\t1.9,\tCh.\t1\tof\tUAE\tFLSC\t [Ref. B.1] , shall be | provided. |',
#  'Parking areas clear height shall conform to B.5.3. |',
#  'Floor\tsurfaces\tshall\tbe\tnon-absorbent,\tnon-combustible,\tgraded\tand\tequipped\t | with\tdrainage\tin\taccordance\twith\tTable\t3.37,\tCh.\t3\tof\tUAE\tFLSC\t [Ref. B.1] .  |',
#  'The\tarea\tof\tfloor\tused\tfor\tparking\tof\tcars\tor\tother\tvehicles\tshall\tbe\tsloped\tto\tfacilitate\t| the movement of liquids to a drain or toward the main vehicle entry doorway. |',
#  'The\tslope\tin\tareas\twhere\tvehicles\tare\tparked\tshall\tbe\tnot\tmore\tthan\t4%\t(as\tshown\t | in\tFigure\tB.55).\tAccessible\tparking\tslopes\tshall\tbe\tlimited\tto\ta\tmaximum\tof\t2%.\t|',
#  'Vehicle guards not less than 1,200 mm in height shall be placed where the vertical | distance\tfrom\tthe\tfloor\tof\ta\tdrive\tlane\tor\tparking\tbay\tto\tthe\tground\tor\tsurface\tdirectly\t| below is greater than 300 mm, such as parking on podiums roof or adjacent to ramps. | The guards shall conform to Clause 4.5.3 of ASCE/SEI 7-16. Mechanical parking | facilities are exempt from this requirement.|',
#  'B.7.2.3.2  | Open versus enclosed parking|',
#  'Open parking has permanent wall openings for natural ventilation at each parking | level. The exterior sides of the structure shall have uniformly distributed openings  | on two or more sides. The area of such openings in external walls on a level shall  | be\tnot\tless\tthan\t20%\tof\tthe\ttotal\tperimeter\twall\tarea\tof\teach\tlevel.\tThe\taggregate\t| length (i.e. total of widths) of the openings deemed to be providing natural | ventilation\tshall\tbe\tnot\tless\tthan\t40%\tof\tthe\tperimeter\tof\tthe\tlevel.\tOpen\tparking\t| facilities\tshall\tconform\tto\tNFPA\t88A\tfor\tnatural\tventilation.\t|',
#  'Parking\tfacilities\tthat\tdo\tnot\tmeet\tthe\tdefinition\tof\topen\tparking\tshall\tbe\tdesigned\t | as enclosed parking with mechanical ventilation as required by  H.4.12.11 .|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 64|',
#  'B.7.2.3.3  | Parking areas technical requirements |',
#  'Parking areas (covered or uncovered) shall be provided for vehicles within  | the plot limits.|',
#  'Parking\tshall\tnot\timpede\tfire\texit\tdoors,\ttheir\taccess\tand\texit\tdischarge\tpath.|',
#  'Wheel stoppers of a maximum height of 120 mm and a minimum width of 200 mm | shall\tbe\tinstalled\tas\tshown\tin\tFigure\tB.56\twhere\tparking\tbays\tare\tadjacent\tto\tfences,\t| walls, buildings or walkways. Wheel stops should be avoided where they might  | be in the path of pedestrians moving to or from parked vehicles.|',
#  'For\tparking\tentry\tand\texit,\ta\tstraight,\tand\tpreferably\tlevel,\t6\tm\tlong\taccess\tshould\tbe\t| provided\tbefore\tvehicle\taccess\tbarriers\tas\tshown\tin\tFigure\tB.57.\tParking\tareas\tshall\t| be\tprovided\twith\tdirectional\tarrows\tand\ttraffic\tsigns,\tas\tdescribed\tin\tB.11.|',
#  'A\tfixed\tmirror\tshall\tbe\tprovided\tfor\tblind\tcorners.|',
#  'No parking area shall be allowed to be utilized as both a parking bay and a loading | space.|',
#  'Basement parking areas shall account for the presence of columns and adjacent | walls, which shall be covered with protective angle guards of suitable material. Round | columns do not require protective angle guards.|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 65|',
#  'Dead-end driveways should be avoided. If they are to be included in design,  | they should serve a maximum of eight spaces with manoeuvring space provided  | (see\tFigure\tB.58).\tTandem\tparking\tmay\tbe\tused\tin\tthe\tfollowing\tsituations:|',
#  'a) residential parking provision of the same residential unit, when the unit requires | two parking bays according to B.7.2.6.1. Tandem parking shall be limited to two | bays. |',
#  'b) hotel facilities, for parking operated solely through a valet parking service.  | Tandem parking shall be limited to three bays.|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 66|',
#  'B.7.2.4 | Car parking bay dimensions|',
#  'The dimension of car parking bays and driveways shall be not less than the minimum | values given in Table B.11.|',
#  'In designing parking spaces, bays bounded by building structural elements or walls | shall have an additional space of 300 mm from the structural element if it interrupts | the opening of vehicle doors or manoeuvring or at the end of the driveway.|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 67|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 68|',
#  'B.7.2.5 | Bus parking bays|',
#  'Bus\tparking\tprovisions\twithin\tplot\tlimits\tshall\tconform\tto\tTable\tB.12,\tFigure\tB.64\t | and\tFigure\tB.65.|',
#  'The parking dimensions and manoeuvring clearances are based on a 12 m long bus.  | A vehicular manoeuvring analysis shall be conducted to determine requirements  | for alternative bus sizes and other parking angles. |',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 69|',
#  'B.7.2.6 | Parking provisions in buildings |',
#  'B.7.2.6.1  | Parking ratios |',
#  'Parking ratios shall be determined in accordance with Table B.13 for the relevant | building occupancy. Parking requirements set out in the affection plan or DCR shall | take precedent over Table B.13.|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 70|',
#  'Parking ratios for any building occupancy not listed in Table B.13 should  | be determined in accordance with RTA parking rates requirements  [Ref. B.40] . |',
#  'When the building includes a mix of occupancies, the parking provided should | conform\tto\tthe\trequirement\tfor\teach\tspecific\toccupancy.|',
#  'Parking for sport stadiums and event arenas shall be determined according  | to a transport study of the type of sport or event, the number of seats, visitors  | and the public parking and transportation network.|',
#  'B.7.2.6.2  | Preferred parking |',
#  'For\tbuildings\tthat\thave\tmore\tthan\t20\tparking\tbays,\tdesignated\tpreferred\tparking\t| shall be provided for a combination of hybrid vehicles, electrical vehicles and carpool | vehicles. |',
#  'The number of preferred parking bays shall be calculated based on the total  | vehicle\tparking\tbays\trequired\tfor\tthe\tbuilding,\tas\tdefined\tin\tB.7.2.6.1.\t|',
#  'The\tpercentage\trequired\tfor\tpreferred\tparking\tis\t5%.\tThis\tpercentage\tdoes\t | not include parking bays provided for people of determination (see  C.6.4 ).|',
#  'B.7.2.6.3  | Charging equipment for electrical vehicles in malls |',
#  'For\tshopping\tmalls,\twhere\tpreferred\tparking\tbays\tare\tprovided\tin\taccordance\twith\t| B.7.2.6.2, necessary charging equipment for electrical vehicles shall be provided for | 20%\tof\tthe\ttotal\tpreferred\tparking\tbays.\tCharging\tequipment\tshall\tconform\tto\t G.5 .|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 71|',
#  'B.7.2.7 | Bicycle parking provision in building |',
#  'Bicycle parking should be located within the building or within a shaded area at | ground\tlevel\t(see\tFigure\tB.66)\tin\teasily\taccessible\tlocations\twithin\tthe\tplot\tlimit\tand\t| no more than 30 m from the building entrance.|',
#  'Parking\tshall\tnot\timpede\tfire\texit\tdoors,\ttheir\taccess\tand\texit\tdischarge\tpath.|',
#  'For\tstudent\taccommodation\tand\tlabour\taccommodation\tbuildings,\tbicycle\tparking\t| facilities\tshall\tbe\tprovided\tfor\t10%\tof\tbuilding\toccupants.\t|',
#  'Other\tbuildings\tshall\tbe\tprovided\twith\tbicycle\tparking\tequivalent\tto\t5%\tof\tthe\t| building\tcar\tparking\trequirement\tas\tspecified\tin\tB.7.2.6.1.|',
#  'The dimensions for cycle stands shall be not less than the minimum values given  | in\tTable\tB.14\tand\tFigure\tB.67.|',
#  'Dubai Building Code| Part B: Architecture|',
#  'B 72|',
#  'B.7.3.1 | Loading and unloading areas |',
#  'B.7.3.1.1  | General|',
#  ...]

# %%
import re
r = re.compile("[a-zA-Z]\.([0-9]+(\.[0-9]+)+)\s+\|\s+[a-zA-Z]+(.*)")
subheadings = [i for i in subheadings if r.match(i)]
subheadings = [i[:-1] for i in subheadings]

# %%
subheadings
# Out:
# ['A.5.2.1 | Gross floor area (GFA)',
#  'A.5.2.2 | Built-up area ',
#  'A.5.2.3 | Gross area and net area',
#  'A.5.2.4 | Building height',
#  'B.4.2.1 | Gate level',
#  'B.4.2.2 | Building height',
#  'B.4.2.3 | Building setbacks ',
#  'B.4.2.4 | Building areas ',
#  'B.4.2.4.1  | Gross area (GA)',
#  'B.4.2.4.2  | Net area (NA)',
#  'B.4.2.5 | Balconies, building projections and terraces',
#  'B.4.2.5.1  | Limitations',
#  'B.4.2.5.2  | Guardrails for fall protection',
#  'B.4.2.6 | Plot coverage',
#  'B.4.2.5.3  | Access doors',
#  'B.4.3.1 | Ground floor',
#  'B.4.3.2 | Basements',
#  'B.4.3.3 | Podium',
#  'B.4.3.4 | Roof ',
#  'B.6.2.1 | Minimum clear widths',
#  'B.6.2.2 | Fire resistance rating',
#  'B.6.2.3 | Kiosks in mall pedestrian ways',
#  'B.6.4.1 | Stairways',
#  'B.6.4.1.1  | General',
#  'B.6.4.1.2  | Exit staircase construction',
#  'B.6.4.1.3 | Stairway width',
#  'B.6.4.1.4  | Stair risers and treads',
#  'B.6.4.1.5  | Landings',
#  'B.6.4.1.6  | Regular use and external stairs',
#  'B.6.4.1.7  | Handrails',
#  'B.6.4.1.8  | Guardrails',
#  'B.6.4.2 | Ramps',
#  'B.6.4.3 | Elevators ',
#  'B.6.5.1 | Doors ',
#  'B.6.5.2 | Windows and daylighting',
#  'B.6.5.2.1  | Minimum area of windows',
#  'B.6.5.2.2  | Daylighting ',
#  'B.6.5.2.3  | Access to views',
#  'B.6.5.2.4  | Safety of windows',
#  'B.6.6.1 | Convenience openings and communicating spaces',
#  'B.6.6.2 | Atria',
#  'B.6.6.3 | Courtyards',
#  'B.6.6.4 | Shafts',
#  'B.7.2.1 | General requirements',
#  'B.7.2.2 | Vehicular ramps',
#  'B.7.2.3 | Parking floors and structures',
#  'B.7.2.3.1  | General',
#  'B.7.2.3.2  | Open versus enclosed parking',
#  'B.7.2.3.3  | Parking areas technical requirements ',
#  'B.7.2.4 | Car parking bay dimensions',
#  'B.7.2.5 | Bus parking bays',
#  'B.7.2.6 | Parking provisions in buildings ',
#  'B.7.2.6.1  | Parking ratios ',
#  'B.7.2.6.2  | Preferred parking ',
#  'B.7.2.6.3  | Charging equipment for electrical vehicles in malls ',
#  'B.7.2.7 | Bicycle parking provision in building ',
#  'B.7.3.1 | Loading and unloading areas ',
#  'B.7.3.1.1  | General',
#  'B.7.3.1.2  | Minimum bays and areas clearances ',
#  'B.7.3.1.3  | Building types requirements',
#  'B.7.3.1.4  | Truck turning radii and clearances',
#  'B.7.3.2 | Service ramps ',
#  'B.7.3.3 | Maintenance ladders',
#  'B.7.3.4 | Access to utilities',
#  'B.8.1.1 | General',
#  'B.8.1.2 | Sanitary finishes',
#  'B.8.1.3 | Sanitary provisions and fixture calculations',
#  'B.8.1.3.1  | Occupancy requirements',
#  'B.8.1.3.2  | Mosques and prayer rooms',
#  'B.8.1.3.3  | Swimming pools',
#  'B.8.1.4 | Public toilets requirements ',
#  'B.8.1.4.1  | Minimum space dimensions for toilet stalls ',
#  'B.8.1.4.2  | Privacy requirements for public toilets',
#  'B.8.1.5 | Fixture clearances',
#  'B.8.1.6 | Cleaner’s room',
#  'B.8.2.1 | Drinking fountains ',
#  'B.8.2.2 | Feeding rooms (lactation rooms)',
#  'B.8.2.3 | First aid facilities ',
#  'B.8.3.1 | Gymnasiums, exercise rooms and fitness centres ',
#  'B.8.3.2 | Swimming pools',
#  'B.8.3.2.1  | General requirements',
#  'B.8.3.2.2  | Safety requirements',
#  'B.8.3.2.3  | Swimming pool fences',
#  'B.8.3.2.4  | Decks and walkways',
#  'B.8.3.2.5  | Ladders and steps',
#  'B.8.3.2.6  | Diving boards',
#  'B.8.3.3 | Prayer rooms ',
#  'B.8.3.4 | Open spaces ',
#  'B.8.5.1 | Waste management hierarchy',
#  'B.8.5.2 | Waste storage rooms',
#  'B.8.5.2.1  | General',
#  'B.8.5.2.2  | Specification of waste storage rooms',
#  'B.8.5.2.3 | Dimensions of waste storage rooms',
#  'B.8.5.3 | Recycling and segregation',
#  'B.8.5.4 | Special and bulky waste',
#  'B.8.5.5 | Chemical and toxic waste',
#  'B.8.5.6 | Hydraulic skip compactors',
#  'B.8.5.7 | Refuse chutes',
#  'B.9.4.1 | General requirements',
#  'B.9.4.2 | Mosque architecture ',
#  'B.9.4.3 | Mosque access strategy ',
#  'B.9.4.4 | Mosque prayer hall arrangement ',
#  'B.9.4.5 | Women’s prayer halls in mosques ',
#  'B.9.4.6 | Specific requirements for mosque types ',
#  'B.9.4.6.1  | Awqat mosques (daily prayers mosque)',
#  'B.9.4.6.2  | Jumaa mosque (Friday prayer) ',
#  'B.9.4.6.3  | Eid Mussalla',
#  'B.9.4.7 | Ablution spaces',
#  'B.9.4.8 | Mosque accommodation ',
#  'B.9.4.9 | Mosque-specific sanitary requirements ',
#  'B.9.5.1.1  | General',
#  'B.9.5.1.2  | Food preparation',
#  'B.9.5.1.3  | Kitchen requirements',
#  'B.9.6.1 | General requirements',
#  'B.9.6.2 | Schools',
#  'B.9.6.3 | Kindergartens ',
#  'B.9.6.4 | Nurseries',
#  'B.9.7.1 | Apartment buildings',
#  'B.9.7.2 | Labour accommodation',
#  'B.9.7.2.1  | General building requirements',
#  'B.9.7.2.2  | Labour accommodation rooms',
#  'B.9.7.2.3  | Labour accommodation amenities ',
#  'B.9.7.3 | Staff accommodation ',
#  'B.9.7.4 | Student accommodation',
#  'B.10.5.1 | Local species ',
#  'B.10.5.2 | Shading of public access',
#  'B.10.5.3 | Heat island effect reduction - surfaces shading',
#  'B.10.6.1 | Recycled materials',
#  'B.10.6.2 | Regional materials',
#  'B.10.6.3 | Asbestos-containing materials',
#  'B.10.6.4 | Lead or heavy metals containing material',
#  'B.10.6.5 | Composite timber products ',
#  'B.10.6.6 | Certified/accredited timber',
#  'B.11.4.1 | Types',
#  'B.11.4.2 | Information signs',
#  'B.11.4.3 | Directional signs',
#  'B.11.4.4 | Identity signs',
#  'B.11.4.5 | Advisory signs',
#  'B.11.4.6 | Digital screens',
#  'C.5.4.1 | Accessible entrances',
#  'C.5.4.2 | Entrance doors',
#  'C.5.4.3 | Access control barriers',
#  'C.5.6.1 | Interaction space',
#  'C.5.6.2 | Toe and knee clearance',
#  'C.5.6.3 | Protruding objects',
#  'C.5.7.1 | Forward reach',
#  'C.5.7.1.1 | Unobstructed forward reach',
#  'C.5.7.1.2 | Obstructed forward reach',
#  'C.5.7.2 | Side reach',
#  'C.5.7.2.1 | Unobstructed side reach',
#  'C.5.7.2.2 | Obstructed side reach',
#  'C.5.7.3 | Children’s reach ranges',
#  'C.5.7.4 | Switches, controls and socket outlets ',
#  'C.5.8.1 | Minimum accessible door requirements',
#  'C.5.8.2 | Hardware requirements',
#  'C.5.8.2.1 | Door opening hardware',
#  'C.5.8.2.2 | Vision panels',
#  'C.5.8.3 | Manoeuvring spaces at manual doors and doorways without doors',
#  'C.5.8.3.1 | Manoeuvring spaces for swinging and sliding doors',
#  'C.5.8.3.2 | Manoeuvring spaces for doorways without doors',
#  'C.5.8.3.3 | Manoeuvring spaces for two doors in series',
#  'C.5.8.4 | Power-assisted and automatic accessible doors',
#  'C.5.9.1 | Ramps',
#  'C.5.9.1.1 | Accessible and pedestrian ramp requirements',
#  'C.5.9.1.2 | Ramp runs',
#  'C.5.9.1.3 | Ramp landings',
#  'C.5.9.1.4 | Ramp edge protection',
#  'C.5.9.1.5 | Curved ramps',
#  'C.5.9.1.6 | Ramp handrails ',
#  'C.5.9.2 | Stairs',
#  'C.5.9.3 | Elevators',
#  'C.5.9.3.1 | General',
#  'C.5.9.3.2 | Accessible elevator requirements',
#  'C.5.9.4 | Lift platforms',
#  'C.5.9.5 | Escalators and moving walks',
#  'C.5.9.5.1 | General',
#  'C.5.9.5.2 | Escalators',
#  'C.5.9.5.3 | Moving walks',
#  'C.6.2.1 | General',
#  'C.6.2.2 | Types of curb ramps',
#  'C.6.2.2.1 | Curb ramps with flared sides',
#  'C.6.2.2.2 | Returned curb ramps',
#  'C.6.2.2.3 | Curb ramps in curb extensions',
#  'C.6.2.2.4 | Lowered sidewalk curb ramps',
#  'C.6.4.1 | Accessible parking provision',
#  'C.6.4.2 | Location of accessible parking spaces',
#  'C.7.2.1 | Floor surfaces',
#  'C.7.2.1.1 | Level change',
#  'C.7.2.1.2 | Slip resistance',
#  'C.7.2.1.3 | Other requirements',
#  'C.7.2.2 | Tactile systems',
#  'C.7.2.2.1 | General',
#  'C.7.2.2.2 | Detectable warning surface',
#  'C.7.2.2.3 | Tactile guiding surfaces',
#  'C.7.2.3 | Glass surfaces',
#  'C.7.2.4 | Wall surfaces ',
#  'C.7.3.1 | General',
#  'C.7.3.2 | Storage facilities',
#  'C.7.3.3 | Tables',
#  'C.7.3.4 | Chairs and benches',
#  'C.7.3.5 | Counters and checkout aisles',
#  'C.8.3.1 | General',
#  'C.8.3.2 | Baby changing stations',
#  'C.8.3.3 | Approach and toe clearance',
#  'C.8.3.4 | Water closets',
#  'C.8.3.4.1 | Position and arrangement of toilets',
#  'C.8.3.4.2 | Wheelchair accessible water closets',
#  'C.8.3.4.3 | Grab bars for water closets',
#  'C.8.3.4.4 | Children’s water closets',
#  'C.8.3.5 | Urinals',
#  'C.8.3.6 | Sinks and washbasins',
#  'C.8.3.7 | Showers',
#  'C.8.3.7.1 | Accessible showers',
#  'C.8.3.7.2 | Transfer type shower compartments',
#  'C.8.3.7.3 | Roll-in type shower compartment',
#  'C.8.3.7.4 | Shower seats',
#  'C.8.3.7.5 | Grab bars for showers',
#  'C.8.3.8 | Bathtubs',
#  'C.8.3.8.1 | Position and clearances',
#  'C.8.3.8.2 | Grab bars for bathtubs with permanent seats',
#  'C.8.3.8.3 | Grab bars for bathtubs without permanent seats ',
#  'C.8.3.9 | Grab bars',
#  'C.10.2.1 | Cultural buildings, libraries, museums and exhibition rooms',
#  'C.10.2.2 | Theatres, cinemas, conference rooms and auditoriums',
#  'C.10.2.3 | Accessible auditorium seating spaces',
#  'C.10.2.4 | Stages and backstage',
#  'C.10.2.5 | Libraries and reading | areas ',
#  'C.10.2.6 | Mosques and prayer rooms',
#  'C.10.2.7 | Public spaces',
#  'C.10.2.8 | Swimming pools',
#  'C.10.2.9 | Recreational buildings and amusement parks',
#  'C.10.2.10 | Dining spaces',
#  'C.10.2.11 | Kitchen and kitchenettes',
#  'C.10.2.12 | Transport buildings, stations and terminals',
#  'C.10.2.13 | Sport buildings and exercise rooms ',
#  'C.10.3.1 | General',
#  'C.10.3.2 | Adaptable units in residential buildings',
#  'C.10.4.1 | General',
#  'C.10.4.2 | Accessible guest room with mobility features',
#  'C.10.4.3 | Accessible guest rooms with communication features',
#  'C.11.3.1 | General features',
#  'C.11.3.2 | Location of tactile maps',
#  'C.11.3.3 | Raised characters for tactile signage',
#  'D.7.2.1 | General',
#  'D.7.2.2 | Horizontal distances',
#  'D.7.3.1 | General',
#  'D.7.3.2 | Elevators in-line ',
#  'D.7.3.3 | Elevators facing each other',
#  'D.8.2.1 | Number of service elevators',
#  'D.8.2.2 | Rated speed',
#  'D.8.3.1 | Firefighting elevators ',
#  'D.8.3.2 | Rated speed of firefighting elevators',
#  'D.8.3.3 | Firefighting elevators in super high-rise buildings',
#  'D.8.5.1 | Single grouping and one floor zone',
#  'D.8.5.2 | Multiple lobbies serving one zone ',
#  'D.8.5.3 | Multiple groupings serving different floor zones',
#  'D.8.8.1 | Population estimation',
#  'D.8.8.2 | Passenger elevator selection charts',
#  'D.8.8.3 | Minimum elevator specifications',
#  'D.8.9.1 | Population estimation',
#  'D.8.9.2 | Passenger elevator selection chart',
#  'D.8.9.3 | Minimum elevator specifications',
#  'D.8.10.1 | Population estimation and passenger elevator selection',
#  'D.8.10.2 | Minimum elevator specifications',
#  'D.8.11.1 | Population estimation',
#  'D.8.11.2 | Passenger elevator selection chart',
#  'D.8.11.3 | Minimum elevator specifications',
#  'D.8.12.1 | Population estimation',
#  'D.8.12.2 | Passenger elevator selection chart',
#  'D.8.12.3 | Minimum elevator specifications',
#  'D.8.12.4 | Minimum escalator specifications',
#  'D.8.13.1 | Population estimation',
#  'D.8.13.2 | Passenger elevator selection charts',
#  'D.8.13.3 | Minimum elevator specifications',
#  'D.8.14.1 | Passenger elevator selection',
#  'D.8.14.3 | Minimum escalator specifications',
#  'D.8.15.1 | Primary and secondary modes of circulation',
#  'D.8.14.2 | Minimum elevator specifications',
#  'D.8.15.2 | Population estimation',
#  'D.8.15.3 | Selection tables',
#  'D.8.15.4 | Minimum specifications ',
#  'D.8.16.1 | Population estimation',
#  'D.8.16.2 | Passenger elevator selection chart',
#  'D.8.16.3 | Minimum elevator specifications',
#  'D.9.2.1 | General',
#  'D.9.3.1 | Handling capacity',
#  'D.9.3.2 | Traffic pattern',
#  'D.9.8.1 | Door timing',
#  'D.9.8.2 | Acceleration and jerk',
#  'D.9.8.3 | Destination control systems',
#  'D.9.8.4 | Hybrid systems',
#  'E.4.1.1 | General ',
#  'E.4.1.2 | Wind loadings',
#  'E.4.1.3 | Permanent fixture loading',
#  'E.4.1.4 | Operational forces',
#  'E.4.1.5 | Thermal movements',
#  'E.4.1.6 | Deflection',
#  'E.4.1.7 | Fixings',
#  'E.5.2.1 | Maximum glazed area',
#  'E.5.2.2 | Orientation of glazed facades  ',
#  'E.5.2.3 | Building envelope performance ',
#  'E.5.2.3.1 | Non-glazed elements',
#  'E.5.2.3.2 | Glazed elements ',
#  'E.7.3.1 | General',
#  'E.7.3.2 | Horizontal and inclined surfaces',
#  'E.7.3.3 | Vertical surfaces',
#  'E.7.3.4 | Flashing',
#  'E.12.7.1 | Rope access',
#  'E.12.7.2 | Power-operated systems',
#  'F.3.1.1 | General',
#  'F.3.1.2 | Concrete',
#  'F.3.1.3 | Steel',
#  'F.3.1.4 | Masonry',
#  'F.3.1.5 | Geotechnics',
#  'F.3.1.5.1 | Geotechnics investigation and testing',
#  'F.3.1.5.2 | Geotechnical design',
#  'F.3.1.5.3 | Execution of geotechnical works',
#  'F.3.2.1 | Concrete',
#  'F.3.2.2 | Geotechnics',
#  'F.3.2.3 | Seismic',
#  'F.5.6.1 | General',
#  'F.5.6.2 | Concrete structures',
#  'F.5.6.3 | Steelwork structures',
#  'F.6.2.1 | Design basis',
#  'F.6.2.2 | Concrete strength',
#  'F.6.2.3 | Concrete mixes',
#  'F.6.2.4 | Modulus of elasticity ',
#  'F.6.2.5 | Section properties',
#  'F.6.2.6 | Detailing of reinforcement',
#  'F.6.3.1 | Design basis',
#  'F.6.3.2 | Additional design requirements for post-tensioned concrete',
#  'F.6.3.3 | Concrete',
#  'F.6.3.4 | Concrete mixes ',
#  'F.6.3.5 | Tendons',
#  'F.6.3.6 | Ducts',
#  'F.6.3.7 | Grout',
#  'F.6.3.8 | Permissible stresses in post-tensioning steel',
#  'F.6.3.9 | Minimum bonded reinforcement for post-tensioned concrete ',
#  'F.6.3.10 | Post-tensioned concrete reinforcement  || detailing',
#  'F.6.4.1 | Design basis',
#  'F.6.4.2 | Concrete',
#  'F.6.4.3 | Concrete mixes ',
#  'F.6.4.4 | Reinforcement and strands',
#  'F.6.4.5 | Storage, transportation, handling and erection',
#  'F.6.4.6 | Connections',
#  'F.6.5.1 | Design basis',
#  'F.6.5.2 | Steel grades',
#  'F.6.4.7 | Precast staircase',
#  'F.6.5.3 | Plate thickness',
#  'F.6.5.4 | Structural connections',
#  'F.6.5.4.1 | Bolted connections',
#  'F.6.5.4.2 | Welded connections',
#  'F.6.5.4.3 | Post-installed anchors',
#  'F.6.6.1 | Design basis',
#  'F.6.6.2 | Wall panels',
#  'F.6.6.3 | Brick and block strengths',
#  'F.7.12.1 | Design basis',
#  'F.7.12.2 | Wind pressures',
#  'F.7.12.3 | Wind tunnel testing',
#  'F.7.12.3.1 | Requirements for testing',
#  'F.7.12.3.2 | Wind direction factors',
#  'F.7.12.3.3 | Peer review of wind tunnel testing',
#  'F.7.12.4 | Allowable building movements for wind',
#  'F.7.12.4.1 | Allowable displacement',
#  'F.7.12.4.2 | Motions affecting occupant comfort',
#  'F.7.12.5 | Structural damping for assessment of wind responses',
#  'F.7.13.1 | Scope',
#  'F.7.13.2 | Seismic performance criteria',
#  'F.7.13.3 | Seismic ground motion values',
#  'F.7.13.3.1 | Near-fault sites',
#  'F.7.13.3.2 | Dubai acceleration parameters',
#  'F.7.13.4 | Site class',
#  'F.7.13.5 | Site coefficients and risk-targeted maximum considered earthquake | (MC',
#  'F.7.13.6 | Design spectral acceleration parameters',
#  'F.7.13.7 | Design response spectrum',
#  'F.7.13.8 | Risk-targeted maximum considered earthquake (MC',
#  'F.7.13.9 | Site-specific ground motion procedures',
#  'F.7.13.10 | Seismic design category',
#  'F.7.13.11 | Geological hazards and geotechnical investigation',
#  'F.7.13.12 | Damping ',
#  'F.7.13.13 | Cracked section stiffness ',
#  'F.7.13.14 | Seismic assessment of existing buildings',
#  'F.8.3.1 | General',
#  'F.8.3.2 | Concrete beam and slab deflection',
#  'F.8.3.3 | Steelwork deflection limits',
#  'F.8.3.4 | Post-tensioned concrete deflection control',
#  'F.8.6.1 | General',
#  'F.8.6.2 | Drift due to permanent gravity load',
#  'F.8.6.3 | Drift and deformation due to differential vertical shortening',
#  'F.8.6.4 | Drift and deformation due to wind ',
#  'F.8.6.5 | Drift and deformation due to seismic',
#  'F.8.8.1 | Steelwork',
#  'F.8.8.2 | Concrete',
#  'F.9.3.1 | General',
#  'F.9.3.2 | Geotechnical desk study',
#  'F.9.3.3 | Planning geotechnical investigation',
#  'F.9.3.4 | Geotechnical on-site investigations',
#  'F.9.3.5 | Geotechnical laboratory testing',
#  'F.9.3.6 | Geotechnical reporting',
#  'F.9.4.1 | Earthworks (excavation and filling)',
#  'F.9.4.2 | Foundations design',
#  'F.9.4.2.1 | General',
#  'F.9.4.2.2 | Shallow and raft foundations',
#  'F.9.4.2.3 | Deep and piled foundations',
#  'F.9.4.3 | Shoring and earth retaining system ',
#  'F.9.4.3.1 | General',
#  'F.9.4.3.2 | Required shoring systems ',
#  'F.9.4.3.3 | Permanent earth retaining system ',
#  'F.9.4.3.4 | Basement walls',
#  'F.9.4.4 | Groundwater control and dewatering',
#  'F.9.4.5 | Liquefaction',
#  'F.9.4.6 | Ground improvement',
#  'F.9.5.1 | General',
#  'F.9.5.2 | Earthworks (excavation and filling)',
#  'F.9.5.3 | Shoring retaining systems',
#  'F.9.5.4 | Foundations',
#  'F.9.5.5 | Groundwater control and dewatering',
#  'F.9.5.6 | Ground improvement',
#  'F.10.2.1 | Component of ground motion',
#  'F.10.2.2 | Return period',
#  'G.2.1.1 | Electrical',
#  'G.2.1.2 | District cooling',
#  'G.2.1.3 | Telecommunications',
#  'G.3.5.1 | Essential reading',
#  'G.3.5.2 | Further reading',
#  'G.4.4.1 | General',
#  'G.4.4.2 | Switchgear locations',
#  'G.4.4.3 | Main electrical switchroom ',
#  'G.4.5.1 | Individual consumer premises',
#  'G.4.5.2 | Multiple consumer premises',
#  'G.4.5.3 | Metering cabinet arrangement',
#  'G.4.5.4 | CT metering requirements',
#  'G.4.7.1 | General',
#  'G.4.7.2 | Minimum size of conductors',
#  'G.4.7.3 | Current rating, size and voltage drop',
#  'G.4.7.4 | Cable colour identification',
#  'G.4.11.1 | Conduits and fittings',
#  'G.4.11.2 | Trunking',
#  'G.4.11.3 | Cable trays and supports',
#  'G.4.12.1 | Main and sub main distribution boards',
#  'G.4.12.2 | Final distribution boards',
#  'G.4.13.1 | Switches',
#  'G.4.13.3 | Arc fault detection devices (AFDDs)',
#  'G.4.13.2 | Plugs and socket outlets',
#  'G.4.13.4 | Surge protection devices (SPDs)',
#  'G.4.13.5 | Cooker control units',
#  'G.4.13.6 | Kitchen appliances',
#  'G.4.13.7 | Control of water heaters, saunas, | Jacuzzis and washing machines',
#  'G.4.13.8 | Control of air conditioning unit/| equipment',
#  'G.4.13.9 | Extra LV safety apparatus',
#  'G.4.16.1 | Lighting and small power circuits',
#  'G.4.16.2 | Maximum demand',
#  'G.4.17.1 | Trunking and conduits',
#  'G.4.17.2 | Flexible conduits',
#  'G.4.17.3 | Cable trays',
#  'G.4.18.1 | Armoured cables',
#  'G.4.18.2 | Distribution boards',
#  'G.4.18.3 | Busbar trunking systems (busways/bus | risers)',
#  'G.4.18.4 | Segregation of circuits, phases and | wiring systems',
#  'G.4.18.6 | Identification labels and notices',
#  'G.4.18.5 | Mounting heights of accessories',
#  'G.4.19.1 | General',
#  'G.4.19.2 | Consumer’s main earth electrode',
#  'G.4.19.3 | Earth continuity conductor (ECC)',
#  'G.4.19.4 | Earth leakage protection',
#  'G.4.19.5 | Equipotential bonding',
#  'G.4.20.1 | PF correction',
#  'G.4.20.2 | Harmonics and rapid voltage changes',
#  'G.4.20.3 | Undervoltage (UV) relays with auto | reset timer',
#  'G.4.21.1 | General',
#  'G.4.21.2 | Wiring systems and distribution boards',
#  'G.4.21.3 | Earth leakage protection',
#  'G.5.1.1 | General ',
#  'G.5.1.2 | Mode 1 charging',
#  'G.5.1.3 | Mode 2 charging',
#  'G.5.1.4 | Mode 3 charging',
#  'G.5.1.5 | Mode 4 charging',
#  'G.7.1.1 | General',
#  'G.7.1.2 | Reliability of supply',
#  'G.7.1.3 | Standard cable sizes',
#  'G.7.1.4 | Cable loads',
#  'G.7.1.5 | Parallel operation',
#  'G.7.1.6 | Harmonics',
#  'G.7.1.7 | Cable trenches',
#  'G.7.2.1 | General',
#  'G.7.2.2 | Substation location',
#  'G.7.2.3 | Substation parameters',
#  'G.7.2.4 | Earthing',
#  'G.7.5.1 | Single room substation (RMU and transformer in same room on  || ground floor)',
#  'G.7.5.2 | Split room substation (RMU and transformer in separate rooms on  || ground floor)',
#  'G.7.5.3 | Basement substation (RMU room in ground floor and transformer  || room at basement level)',
#  'G.7.5.4 | Open to sky dedicated substation with private panel',
#  'G.7.5.5 | Open to sky pocket substation',
#  'G.7.5.6 | DEWA control room requirements for direct 11 kV supply',
#  'G.7.6.1 | General',
#  'G.7.6.2 | Natural ventilation via two exterior walls',
#  'G.7.6.3 | Forced ventilation with no exterior walls',
#  'G.7.9.1 | Intake arrangement',
#  'G.7.9.2 | Protection requirements',
#  'G.11.1.1 | General requirements',
#  'G.11.1.2 | Telecoms service',
#  'G.11.1.3 | Reference architecture',
#  'G.11.3.1 | Lead-in ducts',
#  'G.11.3.2 | Meet-me-room (MMR)',
#  'G.11.4.1 | Telecom rooms',
#  'G.11.4.2 | Main telecom rooms (MTRs)',
#  'G.11.4.3 | Floor telecom rooms (FTRs)',
#  'G.11.4.4 | Mobile network services',
#  'G.11.4.5 | Apartment/office/retail consolidation | cabinets',
#  'G.11.4.6 | Labour accommodation consolidation cabinet',
#  'G.11.4.7 | Business consolidation cabinet – | Commercial shell and core',
#  'G.11.4.8 | Cable pathways',
#  'G.11.4.9 | Fibre termination components and | GPON splitters',
#  'H.2.1.1 | HVAC and occupant comfort',
#  'H.2.1.2 | Water supplies',
#  'H.2.1.3 | Drainage',
#  'H.2.1.4 | Acoustics',
#  'H.2.1.5 | Fire safety ',
#  'H.2.1.6 | Lighting',
#  'H.2.1.7 | Digital services enablement and ICT',
#  'H.3.1.1 | General ',
#  'H.3.1.2 | HVAC and occupant comfort ',
#  'H.3.1.3 | Water supplies',
#  'H.3.1.4 | Drainage',
#  'H.3.1.5 | Lighting',
#  'H.3.1.6 | Commissioning',
#  'H.3.1.7 | Acoustics',
#  'H.3.1.8 | Digital services enablement and ICT',
#  'H.3.2.1 | Water supplies and drainage',
#  'H.3.2.2 | Acoustics',
#  'H.3.2.3 | Digital services enablement and ICT',
#  'H.4.6.1 | General',
#  'H.4.6.2 | Outdoor design conditions ',
#  'H.4.6.3 | Indoor design conditions',
#  'H.4.6.4 | Outdoor air design conditions ',
#  'H.4.6.5 | Heat gain and loss calculations',
#  'H.4.6.6 | External load criteria',
#  'H.4.6.7 | Internal load criteria',
#  'H.4.6.7.1 | Occupancy',
#  'H.4.6.7.2 | Lighting',
#  'H.4.6.7.3 | Electrical equipment loads',
#  'H.4.8.1 | Minimum efficiency of HVAC systems',
#  'H.4.8.2 | Exhaust air energy recovery',
#  'H.4.8.3 | Demand controlled ventilation ',
#  'H.4.8.4 | Pipe and duct insulation ',
#  'H.4.9.1 | Performance',
#  'H.4.9.2 | Air loss from entrances/exits ',
#  'H.4.10.1 | General',
#  'H.4.10.2 | Minimum ventilation requirements for adequate indoor air quality',
#  'H.4.10.3 | Indoor air quality ',
#  'H.4.10.4 | Air inlets and exhausts ',
#  'H.4.10.5 | Isolation of pollutant sources ',
#  'H.4.10.6 | Pandemic air quality measures',
#  'H.4.12.1 | General',
#  'H.4.12.2 | Ducts and duct connectors',
#  'H.4.12.3 | Shafts as air ducts',
#  'H.4.12.4 | Plenums',
#  'H.4.12.5 | Air filters',
#  'H.4.12.6 | Ductwork air leakage',
#  'H.4.12.7 | Exhaust ventilation systems',
#  'H.4.12.8 | Mechanical ventilation in fire mode ',
#  'H.4.12.9 | Fire and smoke dampers',
#  'H.4.13.1 | General',
#  'H.4.13.2 | Materials',
#  'H.4.13.3 | Pipe joints and connections',
#  'H.4.13.4 | Valves',
#  'H.4.13.5 | Pipe installation',
#  'H.4.13.6 | Pipe design',
#  'H.4.13.7 | Pumped hydronic systems',
#  'H.4.13.8 | Pressure vessels',
#  'H.4.13.9 | Boilers',
#  'H.4.14.1 | Controls for HVAC systems ',
#  'H.4.14.2 | Building management system (BMS)',
#  'H.4.14.3 | H.4.14.3 Control systems for hotel rooms ',
#  'H.4.14.4 | Air-conditioning metering ',
#  'H.4.15.1 | General ',
#  'H.4.15.2 | Materials',
#  'H.4.15.3 | Joints and connections',
#  'H.4.15.4 | Piping support',
#  'H.4.16.1 | Gas-fired appliances',
#  'H.4.16.2 | Fireplace stoves and room heaters',
#  'H.4.16.3 | Cooling towers, evaporative condensers and fluid coolers',
#  'H.4.16.4 | Infrared radiant heaters',
#  'H.4.16.5 | Sauna heaters',
#  'H.4.16.6 | Engine and gas turbine-powered equipment and appliances',
#  'H.4.16.7 | Pool and spa heaters',
#  'H.4.16.8 | Cooking appliances',
#  'H.4.16.9 | Conversion burners',
#  'H.5.2.1 | Compliance methods ',
#  'H.5.2.2 | Water-efficient fittings ',
#  'H.5.2.5 | Water-efficient irrigation ',
#  'H.5.2.6 | Water metering',
#  'H.5.2.6.1 | Main meters',
#  'H.5.2.6.2 | Sub-meters',
#  'H.5.2.3 | Condensate drainage ',
#  'H.5.2.4 | Condensate reuse ',
#  'H.5.2.7 | Wastewater reuse ',
#  'H.5.2.8 | Cooling tower water supply ',
#  'H.5.4.1 | Cold water distribution',
#  'H.5.4.2 | Cooled water systems',
#  'H.5.4.3 | Water recycling systems',
#  'H.5.4.4 | Laboratory buildings',
#  'H.5.4.5 | Swimming pool cold water supply',
#  'H.5.4.6 | Irrigation water supply',
#  'H.5.5.1 | General',
#  'H.5.5.2 | Water tank locations',
#  'H.5.5.3 | Water storage tank sizing',
#  'H.5.5.4 | Water tank construction',
#  'H.5.5.5 | Tank pump room ',
#  'H.5.5.6 | Firefighting water tanks',
#  'H.5.5.7 | Combined firefighting and water storage',
#  'H.5.6.1 | Treatment against microbiological bacteria growth',
#  'H.5.6.2 | Water softening',
#  'H.6.2.1 | General',
#  'H.6.2.2 | Sanitation system disposal',
#  'H.6.2.3 | Drainage from mechanical plant',
#  'H.6.2.4 | Floor drains',
#  'H.6.2.5 | Ventilation pipework',
#  'H.6.2.6 | Sanitary plumbing acoustic requirements',
#  'H.6.2.7 | Rodding eyes',
#  'H.6.2.8 | Sanitation pipework',
#  'H.6.2.9 | Leak detection systems',
#  'H.6.3.1 | Drainage systems',
#  'H.6.3.2 | Access to drainage systems',
#  'H.6.3.3 | Sump pits',
#  'H.6.3.4 | Foul pumping stations',
#  'H.6.3.5 | Manholes',
#  'H.6.3.6 | Manhole construction',
#  'H.6.3.7 | Final inspection chamber and provision for future connection ',
#  'H.6.4.1 | General',
#  'H.6.4.2 | Siphonic rainwater disposal systems',
#  'H.6.4.3 | Rainwater disposal system acoustic requirements',
#  'H.6.4.4 | Drainage of hardstanding paved areas',
#  'H.6.4.5 | Miscellaneous rainwater drainage',
#  'H.10.3.1 | General',
#  'H.10.3.2 | Building services noise',
#  'H.10.3.3 | Sound insulation',
#  'H.10.3.4 | Control of reverberation',
#  'H.10.4.1 | Mosques',
#  'H.10.4.2 | Healthcare ',
#  'H.10.4.3 | Educational ',
#  'H.10.4.4 | Hotels',
#  'H.10.4.5 | Performing arts venues',
#  'H.11.2.1 | Digital building technology model',
#  'H.11.2.2 | Implementation requirements',
#  'H.11.2.3 | IoT protocols for digital services enablement',
#  'H.11.2.4 | Building control and operation communication protocols',
#  'H.11.2.5 | Device and data naming',
#  'H.11.2.6 | Data governance and privacy ',
#  'H.11.2.7 | Home automation in residential buildings',
#  'H.11.2.8 | Device requirements and security',
#  'H.11.2.9 | Data validation',
#  'H.11.3.1 | Overview',
#  'H.11.3.2 | Equipment rooms and cabling pathways',
#  'H.11.3.3 | Landlord and tenant cabling infrastructure',
#  'H.11.3.4 | Distribution techniques',
#  'H.11.3.5 | Connection topologies for digital services in buildings',
#  'H.11.3.6 | Landlord data network infrastructure',
#  'H.11.3.7 | Special safety monitoring requirements',
#  'H.11.3.8 | Wireless technology',
#  'H.11.7.1 | Context',
#  'H.11.7.2 | Conventional approach to digital services and smart functionality in  || buildings',
#  'H.11.7.3 | Digital services enabled approach',
#  'H.11.8.1 | General',
#  'H.11.8.2 | Star topology',
#  'H.11.8.3 | Ring topology',
#  'H.11.8.4 | Bus topology',
#  'H.11.8.5 | Mesh topology',
#  'K.2.6.1 | Electrical',
#  'K.2.6.2 | Telecommunications',
#  'K.2.7.1 | HVAC systems and occupant comfort',
#  'K.2.7.2 | Water',
#  'K.2.7.3 | Drainage',
#  'K.3.5.1 | General',
#  'K.3.5.2 | Concrete',
#  'K.3.5.3 | Steel',
#  'K.3.5.4 | Masonry',
#  'K.3.5.5 | Geotechnics',
#  'K.3.5.5.1 | Geotechnical investigation and testing',
#  'K.3.5.5.2 | Geotechnical design',
#  'K.3.5.5.3 | Execution of geotechnical works',
#  'K.3.6.1 | Electrical',
#  'K.3.6.2 | Telecommunications',
#  'K.3.7.1 | HVAC systems and occupant comfort',
#  'K.3.7.2 | Water',
#  'K.3.7.3 | Drainage',
#  'K.3.7.4 | Acoustics',
#  'K.5.2.1 | Gate level',
#  'K.5.2.2 | Building height',
#  'K.5.2.3 | Annexes',
#  'K.5.2.4 | Building setbacks',
#  'K.5.2.5 | Balconies, building projections and terraces',
#  'K.5.2.5.1 | Limitations',
#  'K.5.2.5.2 | Guardrails for fall protection',
#  'K.5.2.6 | Gross area (GA)',
#  'K.5.2.7 | Plot coverage',
#  'K.5.2.8 | Floors general requirements ',
#  'K.5.2.8.1 | Ground floor',
#  'K.5.2.8.2 | Basements',
#  'K.5.2.8.3 | Roof',
#  'K.5.3.1 | Minimum room sizes',
#  'K.5.3.2 | Minimum clear heights',
#  'K.5.4.1 | Doors',
#  'K.5.4.2 | Windows and daylighting',
#  'K.5.4.2.1 | Minimum area of windows',
#  'K.5.4.2.2 | Habitable room conditions for natural lighting',
#  'K.5.4.2.3 | Access to views',
#  'K.5.5.1 | Hallways and corridors',
#  'K.5.5.2 | Stairs',
#  'K.5.5.2.1 | General',
#  'K.5.5.2.2 | Stairway width',
#  'K.5.5.2.3 | Stair risers and treads',
#  'K.5.5.2.4 | Landings',
#  'K.5.5.2.5 | Handrails',
#  'K.5.5.2.6 | Guardrails',
#  'K.5.5.2.7 | Exterior stairways',
#  'K.5.5.2.8 | Spiral or curved stairs and winders',
#  'K.5.5.2.9 | Surfaces',
#  'K.5.5.3 | Ramps',
#  'K.5.5.4 | Elevators',
#  'K.5.5.5 | Means of egress',
#  'K.5.6.1 | Building access',
#  'K.5.6.2 | Firefighting vehicle access',
#  'K.5.6.3 | Vehicle access and movement',
#  'K.5.6.3.1 | General requirements',
#  'K.5.6.3.2 | Vehicular ramps',
#  'K.5.6.4 | Parking areas and garage ',
#  'K.5.6.5 | Maintenance ladders',
#  'K.5.7.1 | General requirements',
#  'K.5.7.2 | Fixture clearances',
#  'K.5.8.1 | Gymnasiums, exercise rooms',
#  'K.5.8.2 | Swimming pools',
#  'K.5.8.2.1 | General requirements',
#  'K.5.8.2.2 | Swimming pool floors',
#  'K.5.8.2.3 | Swimming pool fences',
#  'K.5.8.2.4 | Decks and walkways',
#  'K.5.9.1 | General',
#  'K.5.9.2 | Specification of waste storage areas',
#  'K.5.9.3 | Dimensions of waste storage areas',
#  'K.5.10.1 | Asbestos-containing materials',
#  'K.5.10.2 | Lead or heavy metals containing material',
#  'K.5.10.3 | Interior finishes',
#  'K.5.12.1 | Surfaces shading',
#  'K.5.12.2 | Exterior light pollution and controls ',
#  'K.7.1.1 | Strength and stability',
#  'K.7.1.1.1 | General',
#  'K.7.1.1.2 | Wind loads',
#  'K.7.1.1.3 | Load resistance and transmission',
#  'K.7.1.1.4 | Permanent fixture loading',
#  'K.7.1.1.5 | Operational forces',
#  'K.7.1.1.6 | Thermal movements',
#  'K.7.1.1.7 | Deflection',
#  'K.7.1.1.8 | Fixings',
#  'K.7.1.2 | Structural use of glass',
#  'K.7.1.3 | Structural use of silicone',
#  'K.7.1.4 | Materials',
#  'K.7.1.5 | Impact resistance',
#  'K.7.1.6 | Load combination',
#  'K.7.2.1 | Energy compliance method',
#  'K.7.2.2 | Building envelope performance',
#  'K.7.2.2.1 | Non-glazed elements',
#  'K.7.2.2.2 | Glazed elements – Fenestration ',
#  'K.7.2.3 | Shade effect calculation',
#  'K.7.2.4 | Thermal bridges',
#  'K.7.2.5 | Durability',
#  'K.7.2.6 | Sealing of windows and doors',
#  'K.7.2.7 | Heat island effect reduction',
#  'K.7.4.1 | General',
#  'K.7.4.2 | Ground moisture',
#  'K.7.4.3 | Precipitation including windblown spray ',
#  'K.7.4.3.1 | General',
#  'K.7.4.3.2 | Horizontal and inclined surfaces',
#  'K.7.4.3.3 | Vertical surfaces',
#  'K.7.4.3.4 | Flashing',
#  'K.7.4.4 | Risk of interstitial or surface condensation',
#  'K.7.6.1 | Protection against impact with glazing',
#  'K.7.6.2 | Containment',
#  'K.7.6.3 | Overhead glazing',
#  'K.7.7.1 | General',
#  'K.7.7.2 | Fire testing of non-fire-rated, non-load-bearing façades and aesthetic | features/mashrabiya',
#  'K.7.7.3 | Solid metal panels',
#  'K.7.7.4 | Roof assemblies',
#  'K.8.1.1 | General conditions',
#  'K.8.1.2 | Design life',
#  'K.8.1.3 | Design acceptance criteria',
#  'K.8.1.4 | Structural system and robustness',
#  'K.8.1.5 | Durability',
#  'K.8.4.1 | General',
#  'K.8.4.2 | Load combinations',
#  'K.8.4.3 | Dead loads ',
#  'K.8.4.4 | Superimposed dead loads',
#  'K.8.4.5 | Live loads',
#  'K.8.4.6 | Soil loads and hydrostatic pressure',
#  'K.8.4.7 | Construction load',
#  'K.8.4.8 | Accidental impact load',
#  'K.8.4.9 | Self-straining forces',
#  'K.8.4.10 | Thermally induced forces',
#  'K.8.4.11 | Design for wind loading effects',
#  'K.8.4.12 | Design for earthquake effects',
#  'K.8.5.1 | Design basis',
#  'K.8.5.2 | Strength',
#  'K.8.5.3 | Deflection control',
#  'K.8.5.4 | Crack control in concrete structure',
#  'K.8.5.5 | Drift and deformation',
#  'K.8.5.5.1 | General',
#  'K.8.5.5.2 | Drift and deformation due to wind',
#  'K.8.5.5.3 | Drift and deformation due to seismic',
#  'K.8.5.6 | Movement joints and building separation',
#  'K.8.5.7 | Vibration',
#  'K.8.5.8 | Fatigue',
#  'K.8.5.9 | Transfer elements',
#  'K.8.6.1 | General',
#  'K.8.6.2 | Standards',
#  'K.8.6.3 | Geotechnical site investigation',
#  'K.8.6.3.1 | General',
#  'K.8.6.3.2 | Geotechnical desk study',
#  'K.8.6.3.3 | Planning geotechnical investigation',
#  'K.8.6.3.4 | Geotechnical on-site investigations',
#  'K.8.6.3.5 | Geotechnical laboratory testing',
#  'K.8.6.3.6 | Geotechnical reporting',
#  'K.8.6.4 | Geotechnical design',
#  'K.8.6.4.1 | Earthworks (excavation and fill)',
#  'K.8.6.4.2 | Foundations design',
#  'K.8.6.4.3 | Shoring and retaining systems',
#  'K.8.6.4.4 | Groundwater control and dewatering',
#  'K.8.6.4.5 | Liquefaction',
#  'K.8.6.4.6 | Ground improvement',
#  'K.8.6.5 | Execution of geotechnical works',
#  'K.8.6.5.1 | General',
#  'K.8.6.5.2 | Earthworks (excavation and filling)',
#  'K.8.6.5.3 | Shoring retaining systems',
#  'K.8.6.5.4 | Foundations',
#  'K.8.6.5.5 | Groundwater control and dewatering',
#  'K.8.6.5.6 | Ground improvement',
#  'K.9.1.1 | General',
#  'K.9.1.2 | Electrical supply',
#  'K.9.1.3 | Incoming and metering',
#  'K.9.1.4 | Point of supply',
#  'K.9.1.4.1 | General',
#  'K.9.1.4.2 | Switchgear locations',
#  'K.9.1.5 | Tariff metering',
#  'K.9.1.5.1 | Individual consumers premises',
#  'K.9.1.5.2 | CT metering requirements',
#  'K.9.1.6 | Ambient design conditions',
#  'K.9.1.7 | Cables and conductors',
#  'K.9.1.7.1 | General',
#  'K.9.1.7.2 | Minimum size of conductors ',
#  'K.9.1.7.3 | Current rating, size and voltage drop',
#  'K.9.1.7.4 | Cable colour identification ',
#  'K.9.1.8 | Wiring installation exposed to high temperatures',
#  'K.9.1.9 | Wiring installations in hazardous areas',
#  'K.9.1.10 | Load balancing ',
#  'K.9.1.11 | Wiring accessories',
#  'K.9.1.12 | Distribution boards and consumer units ',
#  'K.9.1.13 | Apparatus and accessories',
#  'K.9.1.14 | Standby generators',
#  'K.9.1.15 | Assessment of connected load and | maximum demand ',
#  'K.9.1.16 | Design criteria for the installation of conduits, trunking, trays and | accessories',
#  'K.9.1.17 | Design criteria for the installation of cables, equipment, accessories | and wiring systems',
#  'K.9.1.18 | Earthing and earth leakage protection',
#  'K.9.3.1 | General',
#  'K.9.3.2 | System documentation requirements',
#  'K.9.3.3 | Wiring diagram datasheets',
#  'K.9.3.4 | Labelling and identification',
#  'K.9.3.5 | Metering and metering provision',
#  'K.9.5.1 | Water metering and water conservation',
#  'K.9.5.2 | Design and installation of water meters',
#  'K.9.7.1 | Design and installation of telecom infrastructure',
#  'K.9.7.1.1 | General requirements',
#  'K.9.7.1.2 | Telecoms service',
#  'K.9.7.1.3 | Reference architecture',
#  'K.9.7.2 | Responsibility matrix',
#  'K.9.7.3 | Outside plant (OSP) common infrastructure specifications',
#  'K.9.7.4 | Inside plant common infrastructure specifications (ISP)',
#  'K.9.7.4.1 | Telecom spaces',
#  'K.9.7.4.2 | Consolidation cabinets',
#  'K.9.7.4.3 | Cable pathways',
#  'K.9.7.4.4 | Cables and termination equipment',
#  'K.9.7.4.5 | Labelling scheme',
#  'K.10.1.1 | General',
#  'K.10.1.2 | Acoustic requirements and noise criteria',
#  'K.10.1.3 | Building HVAC energy load',
#  'K.10.1.4 | Thermal comfort criteria',
#  'K.10.1.5 | Energy conservation and efficiency: building systems',
#  'K.10.1.6 | Ventilation and air quality',
#  'K.10.1.7 | Natural ventilation',
#  'K.10.1.8 | Mechanical ventilation ',
#  'K.10.1.9 | Hydronic systems',
#  'K.10.2.1 | General',
#  'K.10.2.2 | Water conservation and reuse ',
#  'K.10.2.3 | Cold water services',
#  'K.10.2.4 | Tank pump-set installation',
#  'K.10.2.5 | Cold water storage tanks',
#  'K.10.2.6 | Combined firefighting and water storage ',
#  'K.10.2.7 | Servicing and isolation valves',
#  'K.10.2.8 | Backflow protection',
#  'K.10.2.9 | Hot water services',
#  'K.10.3.1 | General',
#  'K.10.3.2 | Sanitary plumbing systems',
#  'K.10.3.3 | Below ground drainage systems',
#  'K.10.3.4 | Rainwater disposal',
#  'K.10.3.5 | Swimming pools',
#  'K.10.3.6 | Septic tanks and sewage holding tanks',
#  'K.10.3.7 | Soakaways',
#  'K.10.4.1 | General ',
#  'K.10.4.2 | Lighting controls',
#  'K.10.5.1 | Emergency lighting',
#  'K.10.5.2 | Fire detection and alarm',
#  'K.10.5.3 | Sprinklers and hose reels',
#  'K.10.5.4 | Smart monitoring']

# %%
# l1 = ['F.6.3.1 | Design basis',
#  'F.6.3.2 | Additional design requirements for post-tensioned concrete',
#  'F.6.3.3 | Concrete',
#  'F.6.3.4 | Concrete mixes ']

# %%
# l2 = []
# l3 = []

# %%
# for i in l1:
#     w = i.split('|')
#     l2.append(w[0].strip())
#     l3.append(w[1].strip())

# %%
# l2

# %%
# l3

# %%
l1 = []
l2 = []
for i in subheadings:
    w = i.split('|')
    l1.append(w[0].strip())
    l2.append(w[1].strip())
